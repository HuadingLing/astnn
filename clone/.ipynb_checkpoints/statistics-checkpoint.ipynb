# %%
import os
import sys
sys.setrecursionlimit(10000)

language_name = {'C': 'c', 
                 'C++': 'cpp', 
                 'Java': 'java', 
                 'Python': 'python', 
                 'Go': 'golang', 
                 'C#': 'csharp', 
                 'PHP': 'php'}

cwd = os.getcwd()

def gen_files(root_folder):
    for path, folders, files in os.walk(root_folder):
        yield from (os.path.normpath(os.path.join(path,f)) for f in files)
        #print(path)
        #print(folders)
        #print(files)
        #print()

class fun_extracter():
    def __init__(self, processor):
        self.processor = processor
    
    def proj_to_funs(self, proj_folder):
        self.file_gun = gen_files(proj_folder)
        for file in self.file_gun:
            if self.processor.file_check(file):
                #print(file)
                code = self.processor.file_to_code(file)
                nodes, pos = self.processor.extract_functions(code)
                if pos is not None:
                    yield from ((n, pos[i])  for i, n in enumerate(nodes))
                
                
class node_statistic():
    def __init__(self, walker, threshold=5):
        self.walker = walker
        self.threshold = threshold
        self.info = {}
        #walker = Preprocessor_java.trans_to_sequences
        
    def add(self, token):
        if len(token) == 0 or token[0] == "'" or token[0] == "\"":
            token = "\"\""
        if token in self.info.keys():
            self.info[token] += 1
        else:
            self.info[token] = 1
        
    def add_info(self, node_token):
        if isinstance(node_token, str):
            self.add(node_token)
        else:
            for t in node_token:
                self.add(t)
            
    def walk(self, ast):
        node_token = self.walker(ast)
        self.add_info(node_token)
        
    def sort_info(self):
        keys = list(self.info.keys())
        for k in keys:
            if self.info[k] < self.threshold:
                del self.info[k]
        self.info = dict(sorted(self.info.items(), key=lambda d: d[1], reverse=True))

# %%
from Preprocessor import Preprocessor_c

lang = "C"
root = "database/" + language_name[lang] + "/"
abs_root = os.path.normpath(os.path.join(cwd, root))

f = fun_extracter(Preprocessor_c([None]))
node_stat = node_statistic(f.processor.trans_to_sequences)

for n, p in f.proj_to_funs(root):
    node_stat.walk(n)
node_stat.sort_info()
with open(os.path.normpath(os.path.join(cwd, 'node_stat_c.json')), 'w') as f:
    json.dump(node_stat.info, f, indent=4, separators=(',', ': '))

node_stat.info

# %%
from Preprocessor import Preprocessor_python

lang = "Python"
root = "database/" + language_name[lang] + "/"
abs_root = os.path.normpath(os.path.join(cwd, root))

f = fun_extracter(Preprocessor_python([None]))
node_stat = node_statistic(f.processor.trans_to_sequences)

for n, p in f.proj_to_funs(root):
    node_stat.walk(n)
node_stat.sort_info()
with open(os.path.normpath(os.path.join(cwd, 'node_stat_python.json')), 'w') as f:
    json.dump(node_stat.info, f, indent=4, separators=(',', ': '))

node_stat.info
# Out:
# {'Load': 30855948,
#  'Name': 23334088,
#  'Constant': 10242408,
#  'Attribute': 9591567,
#  'Call': 7643941,
#  'Store': 4835287,
#  'self': 4578809,
#  'Assign': 3917486,
#  'arg': 2849686,
#  'Expr': 2364127,
#  'keyword': 1848255,
#  'BinOp': 1782205,
#  'arguments': 1398426,
#  'Subscript': 1387729,
#  'FunctionDef': 1339023,
#  'Index': 1308377,
#  'If': 1104437,
#  'Compare': 1043479,
#  'Return': 861107,
#  '1': 722142,
#  'Tuple': 709843,
#  'List': 667566,
#  'Add': 578102,
#  'Mult': 576444,
#  'kwargs': 566716,
#  'Dict': 504578,
#  'Eq': 438823,
#  'x': 437042,
#  '2': 406668,
#  'UnaryOp': 406374,
#  'str': 325384,
#  'url': 313297,
#  'Assert': 309707,
#  'S': 307218,
#  'name': 303568,
#  'response': 301974,
#  'True': 298506,
#  'get': 275325,
#  '__init__': 244279,
#  'For': 225629,
#  'Pow': 222558,
#  'data': 221741,
#  'Not': 207706,
#  'BoolOp': 206039,
#  'cls': 203066,
#  'assertEqual': 200002,
#  'USub': 194271,
#  'a': 193863,
#  '_serialize': 189047,
#  'np': 188275,
#  '3': 183822,
#  'value': 182170,
#  'i': 176591,
#  'b': 174900,
#  'Raise': 172018,
#  'Div': 170384,
#  'request': 170275,
#  'c': 164827,
#  'result': 154645,
#  'Sub': 153618,
#  'pop': 151507,
#  'path': 149856,
#  'len': 148026,
#  'error_map': 137599,
#  'Mod': 137064,
#  'f': 136624,
#  'args': 135349,
#  'Is': 134333,
#  'pipeline_response': 131688,
#  'd': 129596,
#  '_client': 127941,
#  'In': 122617,
#  'comprehension': 118651,
#  'n': 118031,
#  'And': 117563,
#  'append': 116515,
#  's': 114841,
#  'p': 112803,
#  '4': 110946,
#  'query_parameters': 110937,
#  'super': 110776,
#  'status_code': 110668,
#  'Slice': 110543,
#  'withitem': 109927,
#  'e': 107653,
#  'With': 106583,
#  'key': 106472,
#  'id': 105841,
#  'header_parameters': 103667,
#  'os': 103112,
#  'format': 103045,
#  'IsNot': 98586,
#  'y': 97253,
#  'AugAssign': 95792,
#  'isinstance': 95562,
#  'Optional': 95340,
#  'Try': 94295,
#  'api_version': 92959,
#  'resource_group_name': 92698,
#  'ExceptHandler': 92343,
#  'Or': 90133,
#  'deserialized': 86751,
#  'client': 78980,
#  'next_link': 78286,
#  '5': 77608,
#  'ListComp': 75781,
#  'm': 75763,
#  'join': 75258,
#  'config': 75032,
#  'user': 74977,
#  'u': 74848,
#  'accept': 73814,
#  'v': 73565,
#  'list': 73343,
#  'type': 72726,
#  'path_format_arguments': 71822,
#  'ValueError': 69503,
#  'k': 67801,
#  'NotIn': 67442,
#  'query': 67023,
#  'NotEq': 66295,
#  'alias': 66195,
#  'ret': 63643,
#  'update': 62935,
#  'r': 62244,
#  'int': 60653,
#  'sqrt': 59395,
#  '_': 58964,
#  '_deserialize': 58875,
#  't': 58006,
#  '_config': 57486,
#  'log': 54860,
#  '10': 54302,
#  'text': 54187,
#  'property': 54170,
#  'pytest': 53834,
#  'error': 53341,
#  'item': 53257,
#  'index': 52705,
#  '200': 52631,
#  'g': 51989,
#  'expected': 51271,
#  'res': 51161,
#  'range': 51103,
#  'IfExp': 49605,
#  'msg': 49190,
#  'info': 49089,
#  'Gt': 48324,
#  'val': 47367,
#  'stream': 47247,
#  'objects': 46986,
#  'obj': 46950,
#  'line': 46221,
#  'dict': 45586,
#  'other': 45546,
#  'dtype': 45423,
#  'values': 44589,
#  'context': 44512,
#  'Lambda': 44164,
#  'list_of_elem': 43380,
#  'event': 42722,
#  'header': 42590,
#  'wx': 42207,
#  'WC': 41838,
#  'message': 41641,
#  'Starred': 41612,
#  'items': 41610,
#  '_v': 41533,
#  'Lt': 41484,
#  'run': 41246,
#  'db': 41032,
#  'ImportFrom': 40610,
#  'A': 40597,
#  'options': 40573,
#  'metadata': 40440,
#  'polling_method': 40053,
#  'set': 39992,
#  'size': 39932,
#  'FormattedValue': 39648,
#  'w': 39641,
#  'array': 39350,
#  '6': 39166,
#  'content_type': 38284,
#  '-1': 38243,
#  'content': 37563,
#  'node': 37230,
#  'start': 36956,
#  'status': 36912,
#  'model': 36450,
#  'X': 36357,
#  'out': 36059,
#  'Pass': 35162,
#  'filename': 34964,
#  'q': 34712,
#  'params': 34708,
#  'z': 34340,
#  'j': 34130,
#  'subscription_id': 34115,
#  'assertTrue': 34084,
#  'patch': 34035,
#  'Yield': 33940,
#  'headers': 33813,
#  'state': 33694,
#  'polling': 33480,
#  'title': 33292,
#  'parent': 33286,
#  'results': 33241,
#  'match': 32943,
#  'write': 32930,
#  'body': 32481,
#  'application/json': 32391,
#  'datetime': 31710,
#  'group': 31545,
#  'h': 31376,
#  'shape': 31292,
#  'split': 31225,
#  'print': 30655,
#  '7': 30616,
#  '1.0': 30520,
#  'session': 30431,
#  'version': 30365,
#  'GeneratorExp': 30146,
#  'sys': 30139,
#  'app': 30120,
#  '8': 29974,
#  'count': 29743,
#  'subscriptionId': 29673,
#  'prefix': 29632,
#  '404': 29526,
#  'location': 29394,
#  'method': 29211,
#  'self._config.subscription_id': 29150,
#  'time': 29034,
#  'Continue': 29024,
#  'TypeError': 28860,
#  'default': 28753,
#  'foo': 28693,
#  'df': 28481,
#  'debug': 28365,
#  'JoinedStr': 27880,
#  'frappe': 27876,
#  'json': 27819,
#  'settings': 27702,
#  'http_response': 27273,
#  'username': 27232,
#  'format_url': 27193,
#  'target': 27092,
#  'test': 26824,
#  '_pipeline': 26707,
#  'api-version': 26663,
#  'HttpResponseError': 26593,
#  'logger': 26474,
#  'cont_token': 26418,
#  '409': 26283,
#  'ResourceNotFoundError': 26248,
#  'map_error': 26210,
#  'ResourceExistsError': 26102,
#  '401': 26011,
#  'assertRaises': 26009,
#  'copy': 26001,
#  'create': 25908,
#  'backend': 25887,
#  'cmd': 25865,
#  'object': 25855,
#  'raises': 25833,
#  'Accept': 25775,
#  'resourceGroupName': 25511,
#  'field': 25491,
#  'action': 25466,
#  'error_format': 25344,
#  'add': 25322,
#  'ClientAuthenticationError': 25305,
#  'filter': 25277,
#  'open': 25228,
#  'parent_name': 25138,
#  'G': 25068,
#  'mode': 25012,
#  'plotly_name': 24939,
#  'B': 24883,
#  'ARMErrorFormat': 24828,
#  'return_value': 24563,
#  'x_': 23963,
#  'func': 23794,
#  'utils': 23704,
#  'timeout': 23688,
#  'module': 23679,
#  'output': 23653,
#  'parser': 23619,
#  'ExtSlice': 23314,
#  'bool': 23247,
#  'getattr': 23005,
#  'token': 22842,
#  'all': 22691,
#  'mock': 22655,
#  'opts': 22528,
#  'parameters': 22528,
#  're': 22507,
#  'label': 22505,
#  'spec': 22467,
#  'code': 22401,
#  'tags': 22330,
#  'mark': 22329,
#  '100': 22276,
#  'l': 22209,
#  'keys': 22066,
#  'get_next': 22009,
#  'replace': 21951,
#  'prepare_request': 21918,
#  'row': 21871,
#  'extract_data': 21761,
#  'post': 21709,
#  'password': 21705,
#  'While': 21444,
#  'description': 21080,
#  'root': 21079,
#  'close': 21046,
#  'Exception': 21015,
#  'source': 20922,
#  'read': 20839,
#  'expr': 20412,
#  'exp': 20373,
#  'T': 20322,
#  'pos': 20308,
#  'tag': 20259,
#  'end': 20167,
#  'idx': 20116,
#  'get_long_running_output': 20019,
#  'instance': 19948,
#  'errors': 19841,
#  'port': 19766,
#  'random': 19766,
#  'serializer': 19583,
#  'width': 19530,
#  'startswith': 19502,
#  'project': 19474,
#  'assert_equal': 19408,
#  '_lib': 19384,
#  'axis': 19365,
#  'strip': 19257,
#  'tuple': 19179,
#  'comment': 19148,
#  'doc': 19114,
#  'host': 19105,
#  'resp': 19096,
#  'socket': 19083,
#  'lower': 19073,
#  'role': 19070,
#  '_backend': 19018,
#  'kind': 18968,
#  'Break': 18873,
#  'C': 18865,
#  'tm': 18588,
#  'LtE': 18580,
#  '""': 18554,
#  'hasattr': 18537,
#  'stdout': 18466,
#  'offset': 18346,
#  'body_content_kwargs': 18316,
#  'color': 18315,
#  'conn': 18271,
#  'M': 18198,
#  'env': 18172,
#  'command': 18168,
#  ' ': 18104,
#  'GtE': 17904,
#  'float': 17892,
#  'file': 17881,
#  '0.5': 17777,
#  'salt': 17644,
#  'save': 17642,
#  '9': 17538,
#  'fields': 17219,
#  '\n': 17200,
#  'pk': 17069,
#  'style': 16993,
#  'payload': 16986,
#  'exists': 16762,
#  'ax': 16743,
#  'classmethod': 16739,
#  'entry': 16738,
#  'new': 16672,
#  'sin': 16599,
#  'form': 16551,
#  'delete': 16462,
#  'expand': 16142,
#  'err': 16102,
#  'setUp': 16085,
#  'lines': 16050,
#  '__name__': 15931,
#  'ctx': 15861,
#  'BitOr': 15736,
#  'max': 15696,
#  'decode': 15658,
#  'deserializer': 15656,
#  '20': 15619,
#  '/': 15593,
#  'pd': 15462,
#  'order': 15308,
#  'ClassDef': 15292,
#  'raw': 15277,
#  'encoding': 15235,
#  'length': 15234,
#  'attr': 15191,
#  'actual': 15159,
#  'encode': 15116,
#  'Del': 15024,
#  'email': 15013,
#  'pattern': 14925,
#  'bar': 14845,
#  'task': 14835,
#  'domain': 14808,
#  'base': 14793,
#  'Delete': 14756,
#  'sorted': 14754,
#  'image': 14720,
#  'cos': 14715,
#  'assertFalse': 14696,
#  'BitAnd': 14605,
#  'edit_type': 14565,
#  'category': 14552,
#  '12': 14469,
#  'src': 14380,
#  'fit': 14338,
#  'table': 14301,
#  'exc': 14286,
#  'sum': 14284,
#  'reverse': 14254,
#  '_ffi': 14246,
#  'MagicMock': 14208,
#  'min': 14183,
#  'parametrize': 14169,
#  'help': 14167,
#  '.': 14049,
#  'colorer': 14031,
#  'continuation_token': 13876,
#  'R': 13776,
#  'col': 13748,
#  'names': 13713,
#  'height': 13586,
#  'I': 13563,
#  'profile': 13518,
#  'extend': 13515,
#  'N': 13467,
#  'raw_result': 13456,
#  'page': 13439,
#  'body_content': 13439,
#  'models': 13438,
#  'server': 13412,
#  'lro_delay': 13400,
#  'polling_interval': 13398,
#  'utf-8': 13389,
#  'LROPoller': 13364,
#  'stderr': 13314,
#  'six': 13288,
#  'flags': 13174,
#  'cursor': 13147,
#  'attrs': 13137,
#  'course': 13135,
#  'op': 13091,
#  'o': 13080,
#  'dt': 13014,
#  'view': 13001,
#  'callback': 12982,
#  'columns': 12969,
#  'date': 12966,
#  'level': 12937,
#  'mod': 12894,
#  'files': 12840,
#  'F': 12752,
#  'children': 12745,
#  'NotImplementedError': 12684,
#  'enumerate': 12661,
#  'nan': 12426,
#  'string': 12343,
#  '__class__': 12281,
#  '__salt__': 12156,
#  'D': 12119,
#  'pi': 12045,
#  'now': 11985,
#  'address': 11976,
#  'search': 11949,
#  'min_length': 11947,
#  'execute': 11904,
#  'remove': 11901,
#  'find': 11878,
#  'assert_allclose': 11849,
#  'limit': 11819,
#  '16': 11807,
#  'cache': 11800,
#  'environ': 11756,
#  'check': 11696,
#  'child': 11690,
#  'setter': 11659,
#  'staticmethod': 11598,
#  'layout': 11545,
#  'assertIn': 11480,
#  'DataFrame': 11472,
#  'AsyncFunctionDef': 11400,
#  'handler': 11394,
#  'etag': 11378,
#  'KeyError': 11334,
#  'Set': 11282,
#  'frame': 11270,
#  'Q': 11270,
#  'connect': 11246,
#  'filters': 11228,
#  'dest': 11159,
#  'next': 11017,
#  'repr': 11012,
#  'attributes': 10983,
#  'nx': 10976,
#  'alpha': 10953,
#  'left': 10940,
#  'Union': 10901,
#  '11': 10867,
#  'store': 10755,
#  '2.0': 10695,
#  'connection': 10653,
#  'zip': 10614,
#  'mask': 10588,
#  'element': 10571,
#  'Import': 10562,
#  'buf': 10554,
#  'stats': 10546,
#  'verbose': 10504,
#  'max_length': 10472,
#  'AttributeError': 10468,
#  'loads': 10439,
#  'iter': 10427,
#  'html': 10370,
#  'client_id': 10336,
#  'logging': 10315,
#  'ds': 10299,
#  'req': 10285,
#  'stop': 10282,
#  '50': 10256,
#  'service': 10253,
#  'template': 10211,
#  'algorithm': 10198,
#  'changes': 10190,
#  '30': 10185,
#  'channel': 10144,
#  '15': 10047,
#  'provisioning_state': 10045,
#  'hass': 10034,
#  'conf': 10004,
#  'exception': 9940,
#  'Series': 9827,
#  'arange': 9759,
#  'right': 9757,
#  'fp': 9732,
#  '__repr__': 9630,
#  'GET': 9563,
#  'warning': 9555,
#  'unit': 9536,
#  'slug': 9510,
#  'parts': 9476,
#  'events': 9406,
#  'input': 9357,
#  'nodes': 9341,
#  'bytes': 9333,
#  'Content-Type': 9301,
#  'arr': 9292,
#  'first': 9268,
#  'reason': 9232,
#  'P': 9210,
#  'insert': 9117,
#  'abc': 9054,
#  'subprocess': 9051,
#  'uri': 9047,
#  'Mock': 9041,
#  'top': 9038,
#  'platform': 9015,
#  '0.1': 8992,
#  'fname': 8940,
#  'map': 8902,
#  'zeros': 8887,
#  'rv': 8850,
#  'any': 8834,
#  'protocol': 8816,
#  'device': 8807,
#  'L': 8806,
#  'plugin': 8787,
#  'variables': 8779,
#  'dumps': 8774,
#  'plot': 8715,
#  'parse': 8709,
#  'Rational': 8707,
#  'loc': 8685,
#  'block': 8682,
#  'load': 8682,
#  'timestamp': 8680,
#  'widget': 8494,
#  'img': 8458,
#  'number': 8454,
#  'organization': 8448,
#  'Y': 8440,
#  'diff': 8424,
#  'User': 8410,
#  'on_next': 8408,
#  'fn': 8398,
#  'Integral': 8386,
#  'sub': 8346,
#  'warn': 8287,
#  'container': 8287,
#  'abs': 8265,
#  'ex': 8259,
#  'sock': 8253,
#  'freq': 8237,
#  'render': 8235,
#  'tree': 8233,
#  'meta': 8231,
#  'sid': 8226,
#  'dirname': 8224,
#  'window': 8216,
#  'assert_almost_equal': 8215,
#  '_diff': 8188,
#  'properties': 8185,
#  'labels': 8185,
#  'K': 8180,
#  'assert_array_equal': 8162,
#  'credential': 8157,
#  'FloorDiv': 8150,
#  'DictComp': 8149,
#  'NULL': 8121,
#  'add_argument': 8109,
#  'scale': 8107,
#  'text_type': 8102,
#  'rubi_test': 8088,
#  'rubi_integrate': 8076,
#  'groups': 8067,
#  'openssl_assert': 8064,
#  '_numerical': 8057,
#  'im': 8048,
#  'sort': 8044,
#  'scope': 8027,
#  'doctype': 8024,
#  ',': 8009,
#  'seq': 7995,
#  'cfg': 7965,
#  'link': 7954,
#  'Half': 7942,
#  'delegate': 7937,
#  'num': 7936,
#  'var': 7934,
#  'QtWidgets': 7928,
#  'call': 7909,
#  'enabled': 7895,
#  'warnings': 7894,
#  'lib': 7865,
#  'fd': 7863,
#  'record': 7850,
#  'function': 7840,
#  'Int': 7825,
#  'inputs': 7802,
#  'font': 7748,
#  'commit': 7728,
#  'dot': 7718,
#  'schema': 7703,
#  'dc': 7689,
#  'endswith': 7661,
#  'select': 7647,
#  'OperationClass': 7642,
#  '1000': 7625,
#  'timedelta': 7608,
#  'tmpdir': 7597,
#  'rows': 7528,
#  'rule': 7521,
#  'fixture': 7519,
#  'namespace': 7516,
#  'kw': 7509,
#  '-': 7458,
#  'ext': 7436,
#  'option': 7431,
#  'repo': 7415,
#  'scheduler': 7406,
#  'queue': 7386,
#  'current': 7365,
#  'fig': 7330,
#  'Pattern': 7327,
#  'transport': 7300,
#  'points': 7291,
#  'ZZ': 7256,
#  'contents': 7226,
#  'put': 7221,
#  'H': 7214,
#  'column': 7202,
#  'messages': 7193,
#  'weight': 7143,
#  'click': 7131,
#  'ReplacementRule': 7131,
#  'param': 7111,
#  'region': 7091,
#  'course_id': 7077,
#  'provider': 7043,
#  'language': 7021,
#  ', ': 7013,
#  'policies': 7009,
#  'astype': 6986,
#  'api': 6977,
#  'hostname': 6950,
#  'course_key': 6920,
#  'clear': 6907,
#  '90': 6893,
#  '201': 6884,
#  '13': 6884,
#  'assert_': 6869,
#  'at_word_start': 6864,
#  'at_line_start': 6859,
#  'at_whitespace_end': 6859,
#  'send': 6828,
#  ':': 6777,
#  'auth': 6762,
#  '42': 6724,
#  'endpoint': 6714,
#  'base_url': 6714,
#  'NoPolling': 6707,
#  'RuntimeError': 6705,
#  'ARMPolling': 6675,
#  'deserialization_callback': 6672,
#  'defer': 6670,
#  'paths': 6663,
#  'resource': 6653,
#  'build': 6628,
#  'from_continuation_token': 6616,
#  'thread': 6610,
#  '32': 6574,
#  'step': 6571,
#  'Dist': 6566,
#  'POST': 6552,
#  '_solution': 6548,
#  'dim': 6535,
#  'p1': 6519,
#  'position': 6493,
#  'release': 6492,
#  '60': 6492,
#  'section': 6489,
#  'sleep': 6475,
#  'sa': 6472,
#  'indices': 6472,
#  'ans': 6468,
#  'upper': 6431,
#  'ip': 6422,
#  'E': 6421,
#  'cons2': 6419,
#  'master': 6410,
#  'buffer': 6400,
#  'family': 6393,
#  'subject': 6388,
#  'responses': 6371,
#  'setdefault': 6361,
#  '__opts__': 6345,
#  '__str__': 6343,
#  'argv': 6337,
#  'setattr': 6322,
#  'prop': 6314,
#  'modules': 6261,
#  'process': 6242,
#  'skip': 6233,
#  'assertIsInstance': 6228,
#  'mean': 6227,
#  'edges': 6218,
#  'ref': 6207,
#  'tz': 6198,
#  'Response': 6179,
#  'product': 6179,
#  'reshape': 6171,
#  'details': 6163,
#  'base_ring': 6147,
#  'sql': 6136,
#  'x1': 6114,
#  'seed': 6106,
#  'cons3': 6106,
#  '__dict__': 6101,
#  'fmt': 6087,
#  'transform': 6080,
#  'ssl': 6073,
#  'Await': 6057,
#  'ts': 6052,
#  'main': 6033,
#  'tan': 6026,
#  'dataset': 6009,
#  '202': 6003,
#  'user_id': 6000,
#  'axes': 5982,
#  'validate': 5980,
#  'operator': 5977,
#  'register': 5975,
#  'assert_frame_equal': 5936,
#  'graph': 5904,
#  'extra': 5881,
#  '0': 5855,
#  'plt': 5849,
#  'kwds': 5845,
#  'lang': 5837,
#  'side_effect': 5830,
#  '255': 5825,
#  '400': 5815,
#  'one': 5810,
#  'uuid': 5809,
#  'pack': 5789,
#  'elem': 5778,
#  '_version': 5768,
#  'OSError': 5760,
#  'total': 5753,
#  'collection': 5735,
#  'account': 5727,
#  'show': 5719,
#  'success': 5719,
#  'choices': 5714,
#  'QQ': 5710,
#  'dist': 5700,
#  'network_watcher_name': 5697,
#  'uid': 5685,
#  'org': 5667,
#  'gc': 5666,
#  'year': 5661,
#  'testing': 5639,
#  'http': 5614,
#  'part': 5611,
#  'ch': 5602,
#  'assert_raises': 5588,
#  'atol': 5582,
#  'duration': 5571,
#  'Any': 5571,
#  'inf': 5556,
#  'exc_info': 5551,
#  'st': 5542,
#  '14': 5537,
#  'AsyncItemPaged': 5523,
#  'users': 5514,
#  'fail': 5500,
#  '24': 5487,
#  '_state': 5486,
#  'ItemPaged': 5471,
#  'rtol': 5469,
#  'xs': 5466,
#  'stat': 5464,
#  'compile': 5464,
#  'vertices': 5457,
#  'unset': 5445,
#  'util': 5445,
#  '_id': 5441,
#  'entity': 5437,
#  'writer': 5431,
#  '_delete_initial': 5415,
#  'AsyncList': 5410,
#  'AsyncIterable': 5407,
#  'ndim': 5403,
#  'indent': 5396,
#  'display_name': 5381,
#  'job': 5380,
#  'endog': 5375,
#  'queryset': 5349,
#  'exog': 5343,
#  '_name': 5334,
#  'lineno': 5314,
#  'struct': 5289,
#  'tt': 5282,
#  'display': 5280,
#  'site': 5278,
#  'runner': 5277,
#  'ValidationError': 5274,
#  'v1': 5273,
#  'cons8': 5265,
#  'trace': 5255,
#  'tokens': 5251,
#  'assert_array_almost_equal': 5249,
#  'install': 5248,
#  'p2': 5245,
#  '1024': 5235,
#  'x0': 5218,
#  'tmp': 5216,
#  'addr': 5208,
#  'point': 5201,
#  'Image': 5198,
#  'dir': 5191,
#  'where': 5189,
#  'defaults': 5184,
#  'rect': 5181,
#  '25': 5176,
#  'signal': 5174,
#  'seek': 5173,
#  'login': 5153,
#  'gui': 5143,
#  'ids': 5137,
#  'coords': 5115,
#  'ones': 5113,
#  'author': 5109,
#  'abstractmethod': 5104,
#  'delta': 5103,
#  'environment': 5095,
#  'last': 5093,
#  'empty': 5093,
#  'mi': 5092,
#  'outputs': 5085,
#  'random_state': 5060,
#  'handle': 5047,
#  'box': 5038,
#  'chunk': 5030,
#  'center': 5016,
#  'desc': 5012,
#  '500': 5008,
#  'cons29': 5008,
#  'direction': 5006,
#  'amount': 5006,
#  'exceptions': 4991,
#  '_data': 4991,
#  'rb': 4979,
#  'get_value': 4978,
#  'opt': 4978,
#  'engine': 4976,
#  'sep': 4969,
#  'hash': 4967,
#  'V': 4967,
#  'unittest': 4964,
#  'days': 4962,
#  'component': 4945,
#  '_meta': 4941,
#  'required': 4938,
#  'evt': 4925,
#  'tearDown': 4921,
#  'ignore': 4917,
#  'basename': 4905,
#  'wait': 4904,
#  'gen': 4904,
#  'qs': 4903,
#  'sf': 4903,
#  '_create_or_update_initial': 4900,
#  'vals': 4899,
#  'mu': 4898,
#  'Qt': 4896,
#  'addWidget': 4896,
#  'rng': 4894,
#  'old': 4892,
#  'local': 4885,
#  'word': 4881,
#  'system': 4877,
#  '_properties': 4871,
#  'interval': 4863,
#  'signature': 4859,
#  '*': 4855,
#  'kb': 4834,
#  'norm': 4832,
#  'manager': 4829,
#  'account_name': 4814,
#  'scheme': 4809,
#  'numpy': 4809,
#  'types': 4796,
#  'exclude': 4787,
#  'prec': 4761,
#  'match_seq': 4760,
#  'decimal': 4758,
#  'priority': 4745,
#  's1': 4733,
#  'Integer': 4732,
#  'factory': 4724,
#  '40': 4717,
#  'asarray': 4697,
#  'directory': 4694,
#  'suffix': 4686,
#  'force': 4677,
#  'seconds': 4669,
#  'vars': 4668,
#  'owner': 4668,
#  'rules': 4665,
#  'stack': 4664,
#  '_models': 4663,
#  'x2': 4635,
#  'reactor': 4627,
#  'assertEquals': 4619,
#  'none': 4618,
#  'Timestamp': 4615,
#  '__call__': 4609,
#  'shell': 4605,
#  'pid': 4599,
#  'setup': 4597,
#  'rc': 4567,
#  'matches': 4534,
#  'flush': 4533,
#  'builder': 4517,
#  'resource_name': 4511,
#  'iteritems': 4511,
#  'beta': 4501,
#  'assert_called_once_with': 4498,
#  'note': 4484,
#  'assertIsNotNone': 4474,
#  'start_time': 4461,
#  'getvalue': 4456,
#  'klass': 4449,
#  'origin': 4448,
#  'oo': 4442,
#  'keyid': 4440,
#  'custom_headers': 4437,
#  '3.0': 4433,
#  'Z': 4425,
#  'database': 4416,
#  'series': 4399,
#  '0.2': 4394,
#  'requests': 4394,
#  ...}

# %%
from Preprocessor import Preprocessor_java

lang = "Java"
root = "database/" + language_name[lang] + "/"
abs_root = os.path.normpath(os.path.join(cwd, root))

f = fun_extracter(Preprocessor_java([None]))
node_stat = node_statistic(f.processor.trans_to_sequences)

for n, p in f.proj_to_funs(root):
    node_stat.walk(n)
node_stat.sort_info()

# %%
import json

with open(os.path.normpath(os.path.join(cwd, 'node_stat_java.json')), 'w') as f:
    json.dump(node_stat.info, f, indent=4, separators=(',', ': '))

# %%
node_stat.info
# Out:
# {'MethodInvocation': 17288460,
#  'MemberReference': 16563433,
#  'ReferenceType': 14197134,
#  'Literal': 10327876,
#  'StatementExpression': 8283707,
#  '""': 5026509,
#  'FormalParameter': 4968128,
#  'Modifier': 4651638,
#  'MethodDeclaration': 3936800,
#  'BinaryOperation': 3653271,
#  'VariableDeclarator': 3544995,
#  'public': 3370188,
#  'LocalVariableDeclaration': 3185658,
#  'BasicType': 3092864,
#  'Annotation': 2758406,
#  'ReturnStatement': 2452349,
#  'BlockStatement': 2240054,
#  'End': 2153114,
#  'ClassCreator': 2082952,
#  'Assignment': 2010972,
#  'String': 1952514,
#  '=': 1919528,
#  'TypeArgument': 1912770,
#  'IfStatement': 1710226,
#  'int': 1487655,
#  'null': 1213890,
#  '+': 1212371,
#  'This': 1202719,
#  'Override': 1148200,
#  '0': 916030,
#  'Cast': 812231,
#  'final': 675436,
#  '1': 655322,
#  'i': 620048,
#  '==': 597321,
#  'long': 595200,
#  'ClassReference': 557708,
#  'static': 553647,
#  'boolean': 520545,
#  'get': 514938,
#  '!=': 498120,
#  'assertEquals': 476884,
#  'true': 429857,
#  'Test': 426240,
#  'add': 411853,
#  'false': 410596,
#  'assertThat': 387032,
#  'List': 384853,
#  'Object': 384358,
#  'ConstructorDeclaration': 382686,
#  'value': 378160,
#  'e': 359826,
#  'private': 357850,
#  'Exception': 351404,
#  'ForStatement': 346458,
#  'append': 338371,
#  'VariableDeclaration': 338369,
#  'ArraySelector': 335975,
#  'name': 298742,
#  'sb': 286446,
#  'ThrowStatement': 280496,
#  'TryStatement': 273976,
#  'result': 273538,
#  'size': 261090,
#  '-': 255601,
#  'protected': 247750,
#  '&&': 247611,
#  '2': 246462,
#  'length': 244723,
#  '!': 241027,
#  'CatchClause': 235108,
#  'CatchClauseParameter': 234959,
#  'native': 230782,
#  'put': 223796,
#  'toString': 210955,
#  'equals': 210545,
#  'EnhancedForControl': 203874,
#  'ArrayCreator': 202096,
#  '<': 201853,
#  'T': 201361,
#  'Integer': 198299,
#  '++': 193531,
#  'Assert': 192941,
#  'Map': 190191,
#  'SuperConstructorInvocation': 188826,
#  'byte': 184454,
#  'IOException': 180354,
#  'LambdaExpression': 179633,
#  'ArrayInitializer': 177058,
#  'SwitchStatementCase': 176523,
#  'getName': 175961,
#  'key': 166493,
#  'context': 161400,
#  'type': 155211,
#  'builder': 152590,
#  'ElementValuePair': 150674,
#  '?': 149287,
#  'assertTrue': 146610,
#  '||': 143225,
#  'ForControl': 142499,
#  'TernaryExpression': 139401,
#  'Const': 139075,
#  '3': 137222,
#  'start': 134816,
#  'id': 131307,
#  'index': 130467,
#  'orderByComparator': 128289,
#  'instanceof': 125727,
#  '*': 125375,
#  'double': 122346,
#  'BreakStatement': 122181,
#  'com': 121430,
#  'request': 121299,
#  'float': 118263,
#  'Long': 116948,
#  '4': 115991,
#  'list': 115634,
#  'build': 114894,
#  'isEqualTo': 114347,
#  '>': 114113,
#  's': 113529,
#  'map': 110802,
#  'data': 110114,
#  'ByVal': 102957,
#  'of': 102789,
#  'source': 101089,
#  'response': 100644,
#  'c': 98588,
#  'entry': 97901,
#  'session': 96486,
#  'Class': 96138,
#  'x': 95751,
#  'end': 95342,
#  'model': 93886,
#  'isEmpty': 93126,
#  'count': 91387,
#  'ArrayList': 90118,
#  'SuperMethodInvocation': 89387,
#  'message': 88858,
#  'logger': 88236,
#  'groupId': 87986,
#  'n': 87151,
#  'liferay': 86432,
#  'set': 84589,
#  'exception': 84250,
#  'File': 84087,
#  'getValue': 83460,
#  'j': 82966,
#  'java': 82539,
#  'Builder': 81678,
#  'TypeParameter': 81411,
#  'node': 81402,
#  'contains': 79936,
#  'field': 79699,
#  'config': 79357,
#  'create': 79307,
#  'query': 78575,
#  'p': 78098,
#  'out': 78095,
#  'b': 76998,
#  'values': 76725,
#  'getId': 76622,
#  'NativeType': 76053,
#  't': 75714,
#  'path': 75548,
#  'a': 75450,
#  'event': 73996,
#  'is': 73958,
#  'expected': 72118,
#  'input': 71459,
#  'format': 71096,
#  'address': 70216,
#  '5': 70182,
#  'V': 70078,
#  'MethodReference': 69372,
#  'target': 69343,
#  'Set': 69209,
#  '10': 68972,
#  'companyId': 68418,
#  'o': 67038,
#  'info': 66638,
#  'next': 66539,
#  'close': 66126,
#  'getClass': 65811,
#  'getString': 65531,
#  'position': 65500,
#  'Collections': 65065,
#  'game': 64500,
#  'ex': 63357,
#  'in': 63058,
#  'args': 62286,
#  'file': 62071,
#  'util': 61130,
#  '+=': 61060,
#  'IllegalArgumentException': 60966,
#  'status': 60867,
#  'sql': 60840,
#  'error': 60701,
#  'buffer': 60097,
#  'execute': 59672,
#  'other': 59389,
#  'v': 59054,
#  'client': 58476,
#  'kernel': 58020,
#  'item': 57204,
#  'valueOf': 56997,
#  'Nullable': 56939,
#  'iterator': 56591,
#  'println': 56511,
#  'Throwable': 56065,
#  'm': 56055,
#  'portal': 55768,
#  'WhileStatement': 55711,
#  'Arrays': 55172,
#  'K': 55045,
#  'card': 55045,
#  'OrderByComparator': 54996,
#  'listener': 54609,
#  'when': 54578,
#  'getMessage': 54396,
#  'cards': 54124,
#  'filter': 54058,
#  '&': 53906,
#  'assertFalse': 53893,
#  'remove': 53368,
#  'getInstance': 53142,
#  'stream': 53049,
#  'val': 52444,
#  'state': 52399,
#  'uuid': 52300,
#  'offset': 51592,
#  'log': 51516,
#  'hashCode': 51432,
#  'Rarity': 50738,
#  'SetCardInfo': 50610,
#  'method': 50509,
#  'getKey': 50337,
#  'debug': 50209,
#  'obj': 48961,
#  'r': 48726,
#  'Boolean': 48711,
#  'Path': 48519,
#  'params': 48388,
#  'asList': 48123,
#  'write': 48080,
#  'StringBuilder': 47838,
#  'parser': 47639,
#  'System': 47592,
#  'y': 47525,
#  'copy': 47490,
#  '/': 47215,
#  'Collection': 46952,
#  'extends': 46824,
#  'array': 45757,
#  'UUID': 45628,
#  'verify': 45587,
#  'url': 45524,
#  'thenReturn': 45263,
#  'Date': 45146,
#  'equalTo': 44576,
#  'writer': 44548,
#  'run': 44473,
#  'IntBuffer': 44467,
#  'text': 44316,
#  'f': 44201,
#  'CardType': 44151,
#  'ByteBuffer': 44026,
#  'apply': 43964,
#  'object': 43911,
#  'Entry': 43836,
#  'HashMap': 43628,
#  'getType': 43511,
#  'RuntimeException': 43477,
#  'ownerId': 43362,
#  'user': 43307,
#  '>=': 43017,
#  'reader': 42364,
#  'test': 41965,
#  'setInfo': 41951,
#  'Objects': 41841,
#  'output': 41727,
#  'content': 41678,
#  'Optional': 41603,
#  'fail': 41563,
#  'IntPointer': 41494,
#  'StringBundler': 41094,
#  'service': 40707,
#  'clazz': 40675,
#  'mock': 39960,
#  'TryResource': 39612,
#  'userId': 39510,
#  'parent': 39311,
#  'options': 39141,
#  'record': 39135,
#  'abstract': 39115,
#  'db': 38934,
#  'assertNotNull': 38635,
#  'd': 38485,
#  'SuppressWarnings': 38424,
#  'command': 38182,
#  'properties': 38096,
#  'InferredFormalParameter': 37775,
#  'System.out': 37666,
#  '100': 37552,
#  'ctx': 37126,
#  'buf': 37059,
#  'NppiSize': 36861,
#  'PortalException': 36844,
#  'description': 36840,
#  'Pointer': 36769,
#  'pos': 36768,
#  'element': 36743,
#  'clear': 36139,
#  '6': 36138,
#  'getPersistence': 35676,
#  'SwitchStatement': 35653,
#  'group': 35331,
#  'dynamicQuery': 35192,
#  'Locale': 35133,
#  'that': 35116,
#  'read': 34759,
#  'msg': 34743,
#  'accept': 34607,
#  'container': 34387,
#  'E': 34325,
#  'token': 34294,
#  'Thread': 33800,
#  'char': 33791,
#  'instance': 33619,
#  'parameters': 33603,
#  'from': 33561,
#  'BytePointer': 33557,
#  'settings': 33537,
#  'bytes': 33383,
#  'ability': 33298,
#  '8': 33207,
#  'setText': 32829,
#  'capacity': 32785,
#  'parse': 32551,
#  'connection': 32506,
#  'version': 32395,
#  'attributes': 32177,
#  'InterruptedException': 32057,
#  'protobuf': 32054,
#  'factory': 31598,
#  'Math': 31503,
#  'check': 31287,
#  'View': 31284,
#  '<=': 31162,
#  'Double': 31131,
#  'addAbility': 31116,
#  'struct': 31100,
#  'ByRef': 30941,
#  'IllegalStateException': 30936,
#  'Buffer': 30855,
#  'handler': 30565,
#  'short': 30481,
#  'FloatBuffer': 30293,
#  'line': 30227,
#  'substring': 30099,
#  'hasNext': 29839,
#  'ContinueStatement': 29834,
#  'BigDecimal': 29819,
#  'channel': 29761,
#  'ImmutableList': 29730,
#  'delegate': 29608,
#  'className': 29469,
#  'Node': 29452,
#  'UnsupportedOperationException': 28924,
#  'serviceContext': 28899,
#  'ExplicitConstructorInvocation': 28749,
#  'k': 28733,
#  'isTrue': 28681,
#  'ClientMessage': 28313,
#  'SQLException': 28061,
#  'addAll': 27955,
#  'FloatPointer': 27857,
#  'actual': 27819,
#  'wrap': 27621,
#  'metadata': 27587,
#  'matcher': 27578,
#  'TimeUnit': 27573,
#  'Zone': 27420,
#  'getService': 27280,
#  'queryPos': 27154,
#  'view': 27144,
#  'Type': 26951,
#  'visitor': 26865,
#  'props': 26851,
#  'visit': 26777,
#  'org': 26663,
#  'effect': 26330,
#  'Context': 26219,
#  'l': 26188,
#  'root': 25918,
#  'LOG': 25880,
#  'hash': 25819,
#  'entrySet': 25796,
#  'fileClientMessageIndex': 25772,
#  'Iterator': 25723,
#  'uri': 25715,
#  'action': 25640,
#  'google': 25499,
#  'DoubleBuffer': 25420,
#  'oSizeROI': 25401,
#  'fromFile': 25283,
#  'super': 25157,
#  'database': 25120,
#  'allocate': 25087,
#  'doc': 25075,
#  'stack': 25072,
#  'RandomTestUtil': 25052,
#  'DoublePointer': 25005,
#  'json': 24988,
#  'configuration': 24815,
#  'arg': 24745,
#  'LOGGER': 24617,
#  'R': 24609,
#  'assertNull': 24582,
#  'project': 24516,
#  'startsWith': 24501,
#  'setName': 24413,
#  'lang': 24343,
#  'locale': 24238,
#  '7': 24078,
#  'width': 23974,
#  'MageInt': 23943,
#  'CardIdentity': 23927,
#  'cubeCards': 23926,
#  'R.string': 23904,
#  'FormAttachment': 23882,
#  'table': 23863,
#  'Function': 23804,
#  'server': 23737,
#  'len': 23702,
#  'containsKey': 23675,
#  'res': 23519,
#  'update': 23518,
#  'left': 23422,
#  'code': 23198,
#  'playerA': 23146,
#  'first': 23064,
#  'max': 23034,
#  'newInstance': 23009,
#  'str': 22972,
#  'task': 22936,
#  'Message': 22796,
#  'mode': 22761,
#  '|': 22606,
#  'callback': 22592,
#  'Element': 22519,
#  'fields': 22476,
#  'cursor': 22448,
#  'getProperty': 22386,
#  'bitField0_': 22305,
#  'finderArgs': 22299,
#  'useFinderCache': 22296,
#  'SWT': 22237,
#  'StringUtils': 22217,
#  '0L': 22162,
#  'title': 22156,
#  'HashSet': 22136,
#  'Session': 22091,
#  'SubType': 22061,
#  'cache': 22055,
#  'NonNull': 22022,
#  'Deprecated': 21953,
#  'InputStream': 21948,
#  'schema': 21866,
#  'Serializable': 21857,
#  'call': 21778,
#  'stmt': 21698,
#  'env': 21545,
#  'R.id': 21488,
#  'height': 21464,
#  'right': 21463,
#  'getText': 21451,
#  'row': 21385,
#  '_log': 21333,
#  'any': 21318,
#  'document': 21270,
#  'child': 21246,
#  'Settings': 21226,
#  'isNotNull': 21114,
#  'A': 21069,
#  'empty': 21066,
#  'subtype': 21065,
#  'w': 21011,
#  'warn': 20989,
#  'entity': 20928,
#  'CardSetInfo': 20898,
#  'Void': 20897,
#  'BaseMessages': 20875,
#  'PKG': 20770,
#  'label': 20767,
#  'finderPath': 20486,
#  'init': 20470,
#  'INSTANCE': 20444,
#  'Calendar': 20378,
#  'to': 20233,
#  'matches': 20191,
#  'collect': 20140,
#  'headers': 20088,
#  'mapper': 20069,
#  'invoke': 19975,
#  'classNameId': 19974,
#  'keys': 19952,
#  'ElementArrayValue': 19942,
#  'string': 19915,
#  'provider': 19910,
#  'results': 19907,
#  'min': 19730,
#  'tag': 19641,
#  'port': 19572,
#  'fileName': 19552,
#  'QueryUtil': 19522,
#  'setProperty': 19360,
#  'classPK': 19323,
#  'Response': 19277,
#  'pSrc': 19168,
#  'Ability': 19126,
#  'openSession': 19065,
#  'layout': 19049,
#  'BATTLEFIELD': 19038,
#  'com.liferay.portal.kernel.exception.PortalException': 19025,
#  'pDst': 19007,
#  'meta': 18990,
#  'location': 18983,
#  '1000': 18979,
#  'getGroupId': 18950,
#  'Duration': 18921,
#  'AssertStatement': 18889,
#  'resolve': 18877,
#  'httpServletRequest': 18831,
#  '20': 18713,
#  'User': 18648,
#  'Iterable': 18637,
#  'split': 18526,
#  'Request': 18512,
#  'delete': 18493,
#  'lock': 18492,
#  'header': 18470,
#  'getPath': 18419,
#  'URL': 18264,
#  '1L': 18264,
#  'setter': 18190,
#  'exists': 18183,
#  'param': 18139,
#  'Method': 18137,
#  'charAt': 18044,
#  'currentTimeMillis': 17958,
#  'getBytes': 17896,
#  'resource': 17848,
#  'trace': 17848,
#  'Log': 17775,
#  'print': 17729,
#  'fieldName': 17721,
#  'sum': 17667,
#  'items': 17654,
#  'MAX_VALUE': 17643,
#  'pattern': 17542,
#  'isNull': 17499,
#  'body': 17498,
#  'keySet': 17428,
#  'Expression': 17423,
#  '__functionAddress': 17386,
#  'account': 17361,
#  'NppStreamContext': 17271,
#  'lexer': 17257,
#  'nppStreamCtx': 17253,
#  'ImmutableMap': 17223,
#  'property': 17217,
#  'src': 17190,
#  'Query': 17184,
#  'registry': 17171,
#  'HttpServletRequest': 17165,
#  'q': 17139,
#  'timeout': 17123,
#  '<<': 17111,
#  'controller': 17105,
#  'exec': 17094,
#  'ret': 17078,
#  'Runnable': 17060,
#  'cause': 17021,
#  'limit': 17010,
#  'indexOf': 16996,
#  'Token': 16945,
#  'rs': 16934,
#  'g': 16891,
#  'nSrcStep': 16884,
#  '_persistence': 16862,
#  'throwable': 16857,
#  'current': 16829,
#  'setUp': 16817,
#  'operation': 16817,
#  'compareTo': 16813,
#  'reset': 16782,
#  'replace': 16741,
#  'nDstStep': 16740,
#  'getStatus': 16725,
#  'setValue': 16698,
#  'now': 16615,
#  'column': 16546,
#  'ALL_POS': 16534,
#  'elements': 16507,
#  'QueryPos': 16497,
#  'commit': 16407,
#  'ref': 16395,
#  'Label': 16370,
#  'tx': 16343,
#  'send': 16255,
#  'toArray': 16230,
#  'eq': 16226,
#  'function': 16219,
#  'lda': 16176,
#  'clone': 16162,
#  'Game': 16148,
#  'COMMON': 16106,
#  'random': 16018,
#  'store': 15987,
#  'find': 15955,
#  'encoded': 15931,
#  'scope': 15926,
#  'SIZEOF': 15904,
#  'repository': 15892,
#  'newBuilder': 15842,
#  'prefix': 15809,
#  'getAttribute': 15797,
#  'SynchronizedStatement': 15760,
#  'statement': 15729,
#  'setId': 15623,
#  'z': 15620,
#  'arguments': 15501,
#  'Level': 15496,
#  'username': 15486,
#  'executor': 15388,
#  'expression': 15386,
#  '9': 15376,
#  'Criteria': 15349,
#  'synchronized': 15307,
#  'dataSource': 15295,
#  'getCompanyId': 15290,
#  'C': 15276,
#  'Bundle': 15207,
#  'Mockito': 15199,
#  'getInt': 15160,
#  'top': 15110,
#  'page': 15097,
#  'previous': 15096,
#  'future': 15090,
#  'RARE': 15062,
#  '16': 15054,
#  'indices': 15049,
#  'Field': 15011,
#  'getUserId': 14994,
#  'forEach': 14988,
#  'expr': 14962,
#  'Before': 14933,
#  'equalsIgnoreCase': 14925,
#  'time': 14894,
#  'rule': 14867,
#  '_columnOriginalValues': 14838,
#  'order': 14809,
#  'apache': 14805,
#  'save': 14804,
#  'ch': 14795,
#  'singletonList': 14757,
#  'desc': 14750,
#  'intValue': 14743,
#  'isEqual': 14728,
#  'date': 14710,
#  'h': 14674,
#  'Files': 14636,
#  'sleep': 14589,
#  'entries': 14544,
#  'findViewById': 14542,
#  'password': 14454,
#  'host': 14449,
#  'handle': 14444,
#  'StringUtil': 14435,
#  'flags': 14369,
#  'readOnly': 14369,
#  'ImmutableSet': 14367,
#  'NullPointerException': 14340,
#  'stats': 14340,
#  'matrix_layout': 14334,
#  'job': 14314,
#  'conf': 14274,
#  'it': 14268,
#  'createQuery': 14176,
#  'protocol': 14145,
#  'idx': 14122,
#  'isFalse': 14097,
#  'Transactional': 14096,
#  'app': 14085,
#  'dir': 14081,
#  'player': 14060,
#  'Intent': 14033,
#  'Event': 13989,
#  'trim': 13971,
#  'JSON': 13920,
#  '12': 13913,
#  'UNCOMMON': 13886,
#  '--': 13863,
#  'register': 13854,
#  'load': 13847,
#  'assertSame': 13756,
#  'CountDownLatch': 13744,
#  'DynamicQuery': 13732,
#  'NAME': 13730,
#  'bean': 13709,
#  'SECONDS': 13698,
#  '|=': 13696,
#  'JSONObject': 13676,
#  'image': 13588,
#  'req': 13578,
#  'range': 13514,
#  'number': 13476,
#  'Properties': 13434,
#  'commerce': 13422,
#  'activity': 13403,
#  'stop': 13385,
#  'compare': 13371,
#  'power': 13347,
#  'Config': 13345,
#  'getState': 13341,
#  '31': 13329,
#  'ModelNode': 13329,
#  'counter': 13328,
#  'errors': 13327,
#  'margin': 13322,
#  'validate': 13301,
#  'uplo': 13236,
#  'getSpellAbility': 13231,
#  'Document': 13186,
#  'defaultValue': 13168,
#  'Collectors': 13111,
#  'getSimpleName': 13070,
#  'match': 13062,
#  'Input': 13058,
#  'getResult': 13046,
#  'parameter': 13020,
#  'getLong': 13019,
#  'op': 13009,
#  'URI': 12999,
#  'StringPool': 12998,
#  'times': 12991,
#  'ServiceContext': 12953,
#  'toLowerCase': 12916,
#  'nodes': 12886,
#  'predicate': 12841,
#  'nextInt': 12801,
#  'getDescription': 12801,
#  'intent': 12761,
#  'graph': 12756,
#  'DraftCube': 12747,
#  'collection': 12725,
#  'Float': 12653,
#  'FinderPath': 12649,
#  'pipeline': 12629,
#  'CharSequence': 12622,
#  'join': 12603,
#  'Stream': 12577,
#  'var': 12570,
#  'Status': 12537,
#  'attribute': 12529,
#  'addCard': 12505,
#  'systemException': 12451,
#  'ODocument': 12438,
#  'nextLong': 12433,
#  'clientMessages': 12428,
#  '^': 12414,
#  'underTest': 12397,
#  'conn': 12389,
#  'level': 12378,
#  'ByPtrPtr': 12357,
#  'toughness': 12348,
#  'addComponent': 12343,
#  'toList': 12342,
#  'Pair': 12324,
#  'parseInt': 12314,
#  'select': 12281,
#  '30': 12280,
#  'onError': 12261,
#  'JsonProperty': 12248,
#  'shell': 12245,
#  'filename': 12220,
#  'Number': 12214,
#  'emptyList': 12201,
#  'process': 12182,
#  'NULL': 12144,
#  'propagation': 12134,
#  'setEnabled': 12106,
#  'newValue': 12097,
#  'getData': 12093,
#  'CREATURE': 12081,
#  'timestamp': 12068,
#  'printStackTrace': 12063,
#  'color': 12038,
#  'nodeId': 12015,
#  'Propagation': 12006,
#  'default': 11919,
#  'block': 11913,
#  'unit': 11894,
#  'sort': 11883,
#  'columnName': 11863,
#  '%': 11861,
#  'BigInteger': 11776,
#  'template': 11772,
#  'as': 11757,
#  'hasSize': 11746,
#  'base': 11736,
#  'SUPPORTS': 11734,
#  'names': 11730,
#  'countDown': 11730,
#  'onNext': 11727,
#  'dao': 11671,
#  'Character': 11623,
#  'annotation': 11602,
#  'latch': 11590,
#  'soapModel': 11566,
#  'httpInvoker': 11551,
#  'original': 11515,
#  'getPrimaryKey': 11492,
#  'dialog': 11486,
#  'work': 11480,
#  'getContext': 11477,
#  'Schema': 11461,
#  'open': 11449,
#  'tmp': 11427,
#  'foo': 11397,
#  'isPresent': 11374,
#  'userName': 11334,
#  'nextToken': 11318,
#  'inputStream': 11315,
#  'descriptor': 11292,
#  'tableName': 11288,
#  'endsWith': 11285,
#  'queue': 11272,
#  'actionRequest': 11267,
#  'notNull': 11238,
#  'insert': 11221,
#  'swigCPtr': 11215,
#  'containsString': 11194,
#  'cancel': 11162,
#  'State': 11143,
#  'addEffect': 11124,
#  'ts': 11123,
#  'isDebugEnabled': 11122,
#  'Constants': 11092,
#  'await': 11077,
#  'randomString': 11074,
#  'ModelPackage': 11074,
#  'device': 11019,
#  'expect': 10997,
#  'Utils': 10989,
#  'attrs': 10980,
#  'endObject': 10970,
#  'evt': 10964,
#  'setAttribute': 10956,
#  'orderByConditionFields': 10944,
#  'arg0': 10938,
#  'shutdown': 10925,
#  'children': 10923,
#  'permanent': 10917,
#  'types': 10834,
#  'HttpServletResponse': 10833,
#  'Configuration': 10830,
#  'closeSession': 10827,
#  'EMPTY': 10825,
#  '0.0f': 10742,
#  'mapping': 10717,
#  'randomBoolean': 10714,
#  'Name': 10699,
#  'finderCache': 10692,
#  'iter': 10691,
#  'requireNonNull': 10688,
#  'DateTime': 10687,
#  'u': 10678,
#  'getTime': 10667,
#  'rows': 10648,
#  'themeDisplay': 10644,
#  'sqlQuery': 10589,
#  'propertyName': 10581,
#  'LocalDate': 10568,
#  'B': 10550,
#  'findAll': 10523,
#  'startObject': 10519,
#  'Flowable': 10505,
#  'processException': 10482,
#  'frame': 10443,
#  'success': 10434,
#  'flush': 10428,
#  'Version': 10404,
#  'io': 10396,
#  'getAbsolutePath': 10384,
#  'chain': 10376,
#  'addTarget': 10340,
#  'Opcodes': 10317,
#  'em': 10294,
#  'active': 10260,
#  'workspace': 10260,
#  'files': 10252,
#  'tokens': 10249,
#  'Observable': 10236,
#  'getBean': 10191,
#  'getParent': 10166,
#  'FormData': 10148,
#  'UTF_8': 10135,
#  'Result': 10131,
#  'primaryKey': 10125,
#  'rep': 10119,
#  'retval': 10103,
#  'ActionListener': 10099,
#  'Predicate': 10087,
#  'getUuid': 10081,
#  'cluster': 10063,
#  'condition': 10061,
#  '15': 10045,
#  '11': 10041,
#  'col': 10041,
#  'enabled': 10034,
#  'dispose': 10031,
#  'Group': 10021,
#  'memAddress': 10007,
#  'TAG': 10000,
#  '200': 9994,
#  'AssertionError': 9974,
#  'getMethod': 9967,
#  'ByteString': 9966,
#  'transaction': 9950,
#  'Nonnull': 9884,
#  'methodName': 9874,
#  'getClassLoader': 9874,
#  'getVersion': 9869,
#  'Mat': 9826,
#  'bucket': 9822,
#  'XMLHandler': 9812,
#  'Connection': 9806,
#  'payload': 9779,
#  'convert': 9776,
#  'containsExactly': 9750,
#  'Validator': 9744,
#  'checkNotNull': 9742,
#  'NONE': 9702,
#  'owner': 9657,
#  'CHECKS': 9616,
#  'proto': 9585,
#  'events': 9583,
#  'U': 9571,
#  'subscribe': 9568,
#  'siddhiAppRuntime': 9537,
#  'main': 9526,
#  'currentThread': 9523,
#  'pk': 9485,
#  'Person': 9476,
#  'component': 9475,
#  'adapter': 9468,
#  'show': 9467,
#  'PhaseStep': 9422,
#  'consumer': 9400,
#  'inOrder': 9395,
#  'Bean': 9388,
#  'MILLISECONDS': 9385,
#  'setup': 9362,
#  'product': 9348,
#  'decode': 9338,
#  'setParameter': 9330,
#  'clusterState': 9318,
#  'getBoolean': 9285,
#  'bind': 9283,
#  'extensionRegistry': 9245,
#  'primaryKeys': 9234,
#  'bundle': 9210,
#  'encode': 9204,
#  'getCause': 9193,
#  'Namespace': 9188,
#  'getCheckMessage': 9168,
#  '50': 9145,
#  'ldb': 9132,
#  'isAscending': 9096,
#  'second': 9067,
#  'ByteArrayOutputStream': 9022,
#  're': 9001,
#  'classLoader': 8997,
#  'role': 8986,
#  'ClusterState': 8968,
#  'duration': 8963,
#  'cmd': 8891,
#  'Outcome': 8891,
#  'orderByFields': 8890,
#  'Pattern': 8886,
#  'Memory': 8878,
#  'jsonObject': 8872,
#  'folderId': 8859,
#  'toByteArray': 8856,
#  'driver': 8846,
#  'invocation': 8835,
#  'jarg1': 8833,
#  'search': 8825,
#  ...}

# %%
from Preprocessor import *

f = fun_extracter(Preprocessor_java([None]))
get_fun_name_function = f.processor.get_function_name

i = 100
for n, p in f.proj_to_funs(root+'9GAG/'):
    if i == 0:
        break
    print(p, get_fun_name_function(n))
    i -= 1
# Out:
# database\java\9GAG\app\src\main\java\me\storm\ninegag\App.java
# (19, 23) onCreate
# (25, 27) getContext
# (30, 38) initImageLoader
# database\java\9GAG\app\src\main\java\me\storm\ninegag\api\GagApi.java
# database\java\9GAG\app\src\main\java\me\storm\ninegag\dao\BaseDataHelper.java
# (15, 17) BaseDataHelper
# (19, 21) getContext
# (23, 23) getContentUri
# (25, 27) notifyChange
# (29, 29) query
# (35, 35) query
# (41, 43) insert
# (45, 47) bulkInsert
# (49, 51) update
# (53, 55) delete
# (57, 57) getList
# (63, 65) getCursorLoader
# (67, 67) getCursorLoader
# database\java\9GAG\app\src\main\java\me\storm\ninegag\dao\DataProvider.java
# (49, 54) getDBHelper
# (57, 59) onCreate
# (62, 80) query
# (85, 92) getType
# (95, 116) insert
# (119, 134) delete
# (138, 153) update
# (156, 166) matchTable
# database\java\9GAG\app\src\main\java\me\storm\ninegag\dao\DBHelper.java
# (17, 19) DBHelper
# (22, 24) onCreate
# (27, 28) onUpgrade
# database\java\9GAG\app\src\main\java\me\storm\ninegag\dao\FeedsDataHelper.java
# (25, 28) FeedsDataHelper
# (85, 86) FeedsDBInfo
# (31, 33) getContentUri
# (35, 41) getContentValues
# (43, 54) query
# (56, 64) bulkInsert
# (66, 75) deleteAll
# (77, 82) getCursorLoader
# database\java\9GAG\app\src\main\java\me\storm\ninegag\data\BitmapLruCache.java
# (15, 17) BitmapLruCache
# (20, 26) sizeOf
# (29, 31) getBitmap
# (34, 36) putBitmap
# database\java\9GAG\app\src\main\java\me\storm\ninegag\data\GsonRequest.java
# (26, 28) GsonRequest
# (30, 30) GsonRequest
# (39, 41) getHeaders
# (44, 46) deliverResponse
# (49, 59) parseNetworkResponse
# database\java\9GAG\app\src\main\java\me\storm\ninegag\data\ImageCacheManager.java
# (26, 27) ImageCacheManager
# (30, 30) loadImage
# (35, 35) loadImage
# (40, 40) getImageListener
# (44, 48) onErrorResponse
# (51, 70) onResponse
# database\java\9GAG\app\src\main\java\me\storm\ninegag\data\RequestManager.java
# (24, 26) RequestManager
# (28, 33) addRequest
# (35, 37) cancelAll
# database\java\9GAG\app\src\main\java\me\storm\ninegag\model\BaseModel.java
# (9, 11) toJson
# database\java\9GAG\app\src\main\java\me\storm\ninegag\model\Category.java
# (10, 12) Category
# (14, 16) getDisplayName
# database\java\9GAG\app\src\main\java\me\storm\ninegag\model\Feed.java
# (35, 37) addToCache
# (39, 41) getFromCache
# (43, 45) fromJson
# (47, 58) fromCursor
# (64, 66) getPage
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\BaseActivity.java
# (27, 30) onCreate
# (32, 43) initActionBar
# (45, 47) setTitle
# (49, 51) setTitle
# (54, 65) onOptionsItemSelected
# (68, 71) onDestroy
# (73, 75) executeRequest
# (77, 84) errorListener
# (80, 82) onErrorResponse
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\ImageViewActivity.java
# (34, 61) onCreate
# (44, 46) onPhotoTap
# (54, 57) onLoadingComplete
# (60, 62) onProgressUpdate
# (67, 72) onDestroy
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\MainActivity.java
# (45, 71) onCreate
# (54, 58) onDrawerOpened
# (61, 67) onDrawerClosed
# (78, 81) onPostCreate
# (84, 87) onConfigurationChanged
# (89, 92) replaceFragment
# (95, 99) onCreateOptionsMenu
# (102, 113) onOptionsItemSelected
# (115, 124) setCategory
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\PreferenceActivity.java
# (16, 21) onCreate
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\adapter\CardsAnimationAdapter.java
# (25, 27) CardsAnimationAdapter
# (30, 32) getAnimationDelayMillis
# (35, 37) getAnimationDurationMillis
# (40, 45) getAnimators
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\adapter\DrawerAdapter.java
# (20, 22) DrawerAdapter
# (25, 27) getCount
# (30, 32) getItem
# (35, 37) getItemId
# (40, 48) getView
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\adapter\FeedsAdapter.java
# (42, 47) FeedsAdapter
# (95, 97) Holder
# (50, 53) getItem
# (56, 58) newView
# (61, 73) bindView
# (77, 84) getHolder
# database\java\9GAG\app\src\main\java\me\storm\ninegag\ui\fragment\BaseFragment.java
