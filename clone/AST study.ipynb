# %%
import pandas as pd
from pycparser import c_parser
from prepare_data import get_sequences as func

root = 'data/'
language = 'c'
#source = pd.read_pickle(root + language + '/programs.pkl')
#source.columns = ['id', 'code', 'label']

# %%
parser = c_parser.CParser()
#source['parsed code'] = source['code'].apply(parser.parse)
#source.to_pickle(root + language + '/source_1.pkl')
source.read_pickle(root + language + '/source_1.pkl')

# %%
pairs = pd.read_pickle(root + language + '/oj_clone_ids.pkl')
clone_pair = pairs[['id1', 'id2']][pairs['label']==1]
not_clone_pair = pairs[['id1', 'id2']][pairs['label']==0]

def show_code_pair(source, pair):
    for _, row in pair.iterrows():
        print('-'*50, 'Code A', '-'*50)
        print(source['code'][row['id1']])
        print('-'*50, 'Code B', '-'*50)
        print(source['code'][row['id2']])

# %%
show_code_pair(source, clone_pair.iloc[[0,4,5,6,7]])
# Out:
# -------------------------------------------------- Code A --------------------------------------------------
# int main(){
# 	int array[1000],n,k,i,j,flag=0,m;
# 	scanf("%d%d",&n,&k);
# 	for(i=0;i<n;i++){
# 		scanf("%d",&array[i]);
# 	}
#
# 	for(i=0;i<n-1;i++){
# 			m=i;
# 			for(j=i+1;j<n;j++){
# 				if(array[j]<array[m]){
# 					m=j;
# 				}
# 			}
# 			int temp=array[i];
# 			array[i]=array[m];
# 			array[m]=temp;
# 	}
#
# 	for(i=0,j=n-1;i<j;){
# 		int temp=array[i]+array[j];
# 		if(temp==k){
# 			flag=1;
# 			break;
# 		}else if(temp>k){
# 			j--;
# 		}else{
# 			i++;
# 		}
# 	}
# 	if(flag){
# 		printf("yes");
# 	}else{
# 		printf("no");
# 	}
# 	return 0;
# }
# -------------------------------------------------- Code B --------------------------------------------------
# int main()
# {
# 	int n,k,i,j,flag;
# 	int a[1000];
# 	cin>>n>>k;
# 	flag=0;
# 	for (i=0;i<n;i++)
# 	{
# 		cin>>a[i];
# 		for(j=0;j<i;j++)
# 			if (a[j]+a[i]==k) flag=1;
# 	}
# 	if (flag==1) cout<<"yes"<<endl;
# 	else cout<<"no"<<endl;
# 	return 0;
# }
# -------------------------------------------------- Code A --------------------------------------------------
# int main()
# {
# 	int *a[100];
# 	int k,*m,*n,i,plus=0,j,l;
# 	scanf("%d",&k);
# 	m=(int*)malloc(100*sizeof(int));
# 	n=(int*)malloc(100*sizeof(int));
# 	for(i=0;i<k;i++)
# 	{
# 		scanf("%d",m+i);
# 		scanf("%d",n+i);
# 		a[i]=(int*)malloc(((*(m+i))*(*(n+i)))*sizeof(int));
# 		for(j=0;j<*(m+i);j++)
# 		{
# 			for(l=0;l<*(n+i);l++)
# 				scanf("%d",a[i]+(j*(*(n+i))+l));
# 		}
# 	}
# 	for(i=0;i<k;i++)
# 	{
# 		for(j=0;j<*(m+i);j++)
# 		{
# 			plus=plus+(*(a[i]+(j*(*(n+i)))));
# 			plus=plus+(*(a[i]+((j+1)*(*(n+i))-1)));
# 		}
# 		for(l=1;l<(*(n+i))-1;l++)
# 		{
# 			plus=plus+(*(a[i]+l));
# 			plus=plus+(*(a[i]+l+(*(m+i)-1)*(*(n+i))));
# 		}
# 		printf("%d\n",plus);
# 		plus=0;
# 	}
# 	return 0;
# }
# -------------------------------------------------- Code B --------------------------------------------------
# int main()
# {
# 	int a[100][100],n,i,j,k;
# 	scanf("%d",&n);
# 	for(i=1;i<=n;i++)
# 	{
# 		int a[100][100],r,l,sum=0;
# 		scanf("%d%d",&r,&l);
# 		for(j=0;j<=r-1;j++)
# 			for(k=0;k<=l-1;k++)
# 				scanf("%d",*(a+j)+k);
# 		for(j=0;j<=r-1;j++)
# 		{
# 			for(k=0;k<=l-1;k++)
# 			{
# 				if(j==r-1||j==0||k==l-1||k==0)
# 					sum+=*(*(a+j)+k);
# 			}
# 		}printf("%d\n",sum);
# 	}
# 	return 0;
# }
#
# -------------------------------------------------- Code A --------------------------------------------------
# struct stu
# {
# 	int num;
# 	int score1;
# 	int score2;
# }
# main()
# {
# 	struct stu damn[4];
# 	int n,i,j,total;
# 	scanf("%d",&n);
# 	for(i=0;i<3;i++) scanf("%d %d %d",&damn[i].num,&damn[i].score1,&damn[i].score2);
# 	for(i=0;i<2;i++)
# 	{
# 		for(j=0;j<2-i;j++)
# 		{
# 			if(damn[j].score1+damn[j].score2<damn[j+1].score1+damn[j+1].score2)
# 			{
# 				damn[3]=damn[j];
# 				damn[j]=damn[j+1];
# 				damn[j+1]=damn[3];
# 			}
# 		}
# 	}
# 	for(i=0;i<n-3;i++)
# 	{
# 		scanf("%d %d %d",&damn[3].num,&damn[3].score1,&damn[3].score2);
# 		if(damn[3].score1+damn[3].score2<damn[2].score1+damn[2].score2) continue;
# 		else if(damn[3].score1+damn[3].score2<=damn[1].score1+damn[1].score2&&damn[3].score1+damn[3].score2>damn[2].score1+damn[2].score2)
# 		{
# 			damn[2]=damn[3];
# 		}
# 		else if(damn[3].score1+damn[3].score2<=damn[0].score1+damn[0].score2&&damn[3].score1+damn[3].score2>damn[1].score1+damn[1].score2)
# 		{
# 			damn[2]=damn[1];
# 			damn[1]=damn[3];
# 		}
# 		else if(damn[3].score1+damn[3].score2>damn[0].score1+damn[0].score2)
# 		{
# 			damn[2]=damn[1];
# 			damn[1]=damn[0];
# 			damn[0]=damn[3];
# 		}
#
# 	}
# 	for(i=0;i<2;i++)
# 	{
# 		total=damn[i].score1+damn[i].score2;
# 		printf("%d %d\n",damn[i].num,total);
# 	}
# 	total=damn[i].score1+damn[i].score2;
# 	printf("%d %d",damn[i].num,total);
# }
#
# -------------------------------------------------- Code B --------------------------------------------------
# struct student
# 	{
# 		char number[20];
# 		int chinese;
# 		int math;
# 		int sum;
# 		struct student *next;
# 	}stu[100000],*s1,*s2,*s3;
#
# int n,max1=0,max2=0,max3=0;
#
#
# struct student *creat(void)
# {
# 	int i;
# 	struct student *head,*p1,*p2;
#     p1=p2=(struct student*)malloc(LEN);
# 	for(i=0;i<n;i++)
# 	{
# 		scanf("%s%d%d",&p1->number,&p1->chinese,&p1->math);
# 		p2=p1;
# 		p1->sum=p1->chinese+p1->math;
# 		if(p1->sum>max1)
# 		{max3=max2;s3=s2;max2=max1;s2=s1;max1=p1->sum;s1=p1;}
# 		else if(p1->sum>max2)
# 		{max3=max2;s3=s2;max2=p1->sum;s2=p1;}
# 		else if(p1->sum>max3)
# 		{max3=p1->sum;s3=p1;}
# 		if(i==0)head=p1;
# 		else p2->next=p1;
#
# 		p1=(struct student*)malloc(LEN);
# 	}
# 	p1=NULL;
# 	return(head);
# }
#
# void main()
# {
# 	struct student *p;
# 	scanf("%d",&n);
# 	p=creat();
#     printf("%s %d\n",s1->number,s1->sum);
# 	printf("%s %d\n",s2->number,s2->sum);
# 	printf("%s %d",s3->number,s3->sum);
# }
#
# -------------------------------------------------- Code A --------------------------------------------------
# int main()
# {
# 	int n, i;
# 	cin >> n;
# 	int num, count[100] = {0};
# 	cin >> num;
# 	count[num]++;
# 	cout << num;
# 	for(i = 2; i <= n; i++)
# 	{
# 		cin >> num;
# 		count[num]++;
# 		if(count[num] == 1)
# 			cout << " " << num;
# 	}
# 	return 0;
# }
# -------------------------------------------------- Code B --------------------------------------------------
#
#
# int main()
# {
# 	int n;
# 	int a[91];
# 	int i;
# 	for( i=0 ; i<91 ; i++ )
# 	{
# 		a[i]=0;
# 	}
# 	cin>>n;
# 	cin>>i;
# 	cout<<i;
# 	a[i-10]=1;
# 	while( n>0 )
# 	{
# 		n--;
# 		int b;
# 		cin>>b;
# 		if( a[b-10]==0 )
# 		{
# 			cout<<' '<<b;
# 			a[b-10]=1;
# 		}
# 	}
# }
# -------------------------------------------------- Code A --------------------------------------------------
# int max(int x,int y);
# int max(int x,int y)
# {
# 	int z;
# 	if(x>y)
# 		z=x;
# 	else
# 		z=y;
# 	return(z);
# }
#
# int main()
# {
# 	int a[25]={0};
# 	int c[25];
# 	int Height,k;
# 	int n;
# 	scanf("%d",&k);
# 	{
# 		for(n=0;n<k;n++)
# 		{
# 			scanf("%d",&Height);
# 			a[n]=Height;
# 			c[n]=1;
# 		}
# 	}
# 	int i,j;
# 	for(i=k-2;i>=0;i--)
# 	{
# 		for(j=i+1;j<=k-1;j++)
# 		{
# 			if((a[j]<=a[i]) && (c[i]<c[j]+1))
# 				c[i]=c[j]+1;
# 		}
# 	}
#
# 	int cMax=c[0];
# 	{
# 		for(i=0;i<=k-1;i++)
# 		{
# 			cMax=cMax>c[i]?cMax:c[i];
# 		}
# 		printf("%d",cMax);
# 	}
# 	return 0;
# }
#
#
#
# -------------------------------------------------- Code B --------------------------------------------------
# int main(void)
# {
#  int num,max=0;
#  scanf("%d",&num);
#  int a[num],flag[num];
#  for (int i = 0; i < num; i ++)
#  {
#   scanf("%d",&a[i]);
#   flag[i] = 1;
#  }
#  for (int i = 0; i < num; i ++)
#  {
#   for (int j = 0; j < i; j ++)
#   {
#    if (a[j] >= a[i])
#    {
#     flag[i] = flag[j] + 1 > flag[i] ? flag[j] + 1 : flag[i];
#    }
#   }
#   if(flag[i]>max) max = flag[i];
#  }
#  printf("%d\n",max);
#  return 0;
# }

# %%
show_code_pair(source, not_clone_pair.iloc[[0,4,5,6,7]])
# Out:
# -------------------------------------------------- Code A --------------------------------------------------
# void main()
# {
# 	int x,y,i,j,t;
# 	int a[100],b[100];
# 	scanf("%d%d",&x,&y);
# 	for(i=0;i<x;i++)
# 		scanf("%d",&a[i]);
# 	for(i=0;i<y;i++)
# 		scanf("%d",&b[i]);
# 	for(j=0;j<=x-1;j++)
# 		for(i=0;i<x-j-1;i++)
# 		if(a[i]>a[i+1])
# 		{	t=a[i];a[i]=a[i+1];a[i+1]=t;}
#     for(j=0;j<=y-1;j++)
# 		for(i=0;i<y-j-1;i++)
# 		if(b[i]>b[i+1])
# 		{	t=b[i];b[i]=b[i+1];b[i+1]=t;}
# 		for(i=0;i<x;i++)
# 				printf("%d ",a[i]);
#             for(i=0;i<y-1;i++)
# 			{	printf("%d ",b[i]);}
# 			printf("%d",b[y-1]);
# }
# -------------------------------------------------- Code B --------------------------------------------------
# int main()
# {
# 	int i,a[12]={31,28,31,30,31,30,31,31,30,31,30,31};
# 	int sum=0,days,year,month;
# 	scanf("%d%d%d",&year,&month,&days);
#     for(i=0;i<month-1;i++)
# 	{	sum=sum+a[i];}
# 	sum=sum+days;
# 	if((month==2&&days>=28)||(month>2))
# 	{
# 	     if((year%4==0&&year%100!=0)||(year%400==0))
# 	          sum=sum+1;
# 	}
# 	printf("%d\n",sum);
# 	return 0;
# }
#
#
# -------------------------------------------------- Code A --------------------------------------------------
# void main()
# {
# 	int row,col,n=0,i,j,a[100][100];
# 	scanf("%d%d",&row,&col);
# 	for(i=0;i<row;i++)
# 	{
# 		for(j=0;j<col;j++) scanf("%d",&a[i][j]);
# 	}
# 	i=0;j=0;
# 	while(n<row+col-1)
# 	{
# 		printf("%d\n",a[i][j]);
# 		if(j==0||(i==row-1&&j!=0)) {n++;j=n;i=0;}
# 		else {i++;j--;}
# 		while(j>col-1) {j--;i++;}
# 		if(i==row-1&&j==col-1) {printf("%d\n",a[i][j]);break;}
# 	}
# }
# -------------------------------------------------- Code B --------------------------------------------------
# int main(int argc, char* argv[])
# {
# 	int year,month,day,n,mday=0,i=1;
#     int p[13]={0,31,28,31,30,31,30,31,31,30,31,30,31};
# 	scanf("%d %d %d\n",&year,&month,&day);
#     for(i=1;i<month+1;i++){
# 			mday=mday+p[i-1];
# 	   }
# 	if((year%4==0&&year%100!=0)||year%400==0){
# 		if(month>=3){
# 			mday=mday+1;}
# 		else {
# 			mday=mday;
# 		}
# 	}
# 	n=mday+day;
# 	printf("%d",n);
# 	return 0;
# }
#
# -------------------------------------------------- Code A --------------------------------------------------
# int main()
# {
# 	int k,m,n;
# 	int sum1,sum2,sum3,sum4;
# 	int i,j,l;
# 	int a[100][100],b[100];
#
# 	scanf("%d",&k);
# 	for(l=1;l<=k;l++)
# 	{
# 		sum1=0;
# 		sum2=0;
# 		sum3=0;
# 		sum4=0;
# 		scanf("%d %d",&m,&n);
# 		for(i=0;i<m;i++)
# 		{
# 			for(j=0;j<n;j++)
# 				scanf("%d",&a[i][j]);
# 		}
# 		for(j=0;j<n;j++)
# 			sum1=sum1+a[0][j];
# 		for(i=1;i<m;i++)
# 			sum2=sum2+a[i][n-1];
# 		for(j=0;j<n-1;j++)
# 			sum3=sum3+a[i-1][j];
# 		for(i=1;i<m-1;i++)
# 			sum4=sum4+a[i][0];
# 		b[l]=sum1+sum2+sum3+sum4;
# 	}
# 	for(l=1;l<=k;l++)
# 		printf("%d\n",b[l]);
# 	return 0;
#
#
# }
# -------------------------------------------------- Code B --------------------------------------------------
#
# int str1[50]={1},str2[50]={1};
# int length1,length2;
# void input_string(void)
# {
# 	cin >> length1 >> length2;
# 	for (int i=0;i<length1;i++)
# 		cin >> str1[i];
# 	for (int i=0;i<length2;i++)
# 		cin >> str2[i];
# }
# void rank_string(void)
# {
# 	int temp;
# 	for (int i=0;i<length1-1;i++)
# 		for (int j=i+1;j<length1;j++)
# 			if (str1[i]>str1[j])
# 			{
# 			    temp = str1[i];
# 			    str1[i] = str1[j];
# 			    str1[j] = temp;
# 			}
# 	for (int i=0;i<length2-1;i++)
# 	    for(int j=i+1;j<length2;j++)
# 	    	if (str2[i]>str2[j])
# 	    	{
# 	    		temp = str2[i];
# 	    		str2[i] = str2[j];
# 	    		str2[j] = temp;
# 	    	}
# }
# void combine_string(void)
# {
# 	for (int i=length1;i<length1+length2;i++)
# 		str1[i] = str2[i-length1];
# }
# void output_string(void)
# {
# 	cout << str1[0];
# 	for (int i=1;i<length1+length2;i++)
# 		cout << ' ' << str1[i];
# }
# int main()
# {
# 	input_string();
# 	rank_string();
# 	combine_string();
# 	output_string();
# 	return 0;
# }
#
# -------------------------------------------------- Code A --------------------------------------------------
# int main()
# {
# 	int lin, col;
# 	cin >> lin >> col;
# 	int i, j;
# 	int num[100][100];
# 	for(i = 0; i < lin; i++)
# 	{
# 		for(j = 0; j < col; j++)
# 			cin >> num[i][j];
# 	}
# 	if(lin <= col)
# 	{
# 		for(j = 0; j < col; j++)
# 		{
# 			for(i = 0; i <= j && i < lin; i++)
# 				cout << num[i][j - i] << endl;
# 		}
# 		for(i = 1; i < lin; i++)
# 		{
# 			for(j = col - 1; j >= i && col + i - 1 - j < lin; j--)
# 				cout << num[col + i - 1 - j][j] << endl;
# 		}
# 	}
# 	else
# 	{
# 		for(j = 0; j < col; j++)
# 		{
# 			for(i = 0; i <= j; i++)
# 				cout << num[i][j - i] << endl;
# 		}
# 		for(i = 1; i < lin; i++)
# 		{
# 			for(j = col - 1;col - 1 + i - j < lin && j >= 0 ; j--)
# 				cout << num[col + i - 1 - j][j] << endl;
# 		}
# 	}
#
# 	return 0;
# }
#
#
# -------------------------------------------------- Code B --------------------------------------------------
#
# struct stu* create();
# int compare (const void * a, const void * b);
# int main()
# {
# 	int i,j=0,n;
# 	scanf("%d", &n);
# 	struct stu{
# 			int num;
# 			int chi;
# 			int math;
# 			int total;
# 	};
# 	struct stu *p=(struct stu*)calloc( n,sizeof(struct stu) );
# 	struct stu *a=p;
# 	int *tot=(int *)calloc( n, sizeof(int) );
# 	for(i=0;i<n;i++){
# 		scanf("%d %d %d", &p->num, &p->chi, &p->math);
# 		*(tot+i) = p->total = p->chi + p->math;
# 		p++;
# 	}
# 	qsort(tot, n, sizeof(int), compare);
# 	for(i=0;i<3;i++,j=0){
# 		while( (a+(j++))->total != *(tot+i) )
# 			;
# 		printf("%d %d\n", (a+j-1)->num, (a+j-1)->total);
# 		(a+j-1)->total=-1;
# 	}
#
# 	return 0;
#
# }
#
# int compare (const void * a, const void * b)
# {
#   return ( *(int*)b - *(int*)a );
# }
# -------------------------------------------------- Code A --------------------------------------------------
#
# struct student{
# 	int id;
# 	int chi;
# 	int math;
# };
# struct maxer{
# 	int id;
# 	int mark;
# };
# int main(){
# 	int n,i,j;
# 	struct student a[100001],temp;
# 	struct maxer max,top[3];
# 	cin>>n;
# 	for (i=1;i<=n;i++){
# 		cin>>a[i].id>>a[i].chi>>a[i].math;
# 	}
# 	for (i=1;i<=3;i++){
# 		max.mark=0;
# 		for (j=i;j<=n;j++){
# 		if 	(a[j].chi+a[j].math>max.mark){
# 			max.id=a[j].id;
# 			max.mark=a[j].chi+a[j].math;
# 		}
# 		}
# 		top[i-1]=max;
# 		temp=a[i];
# 		a[i]=a[max.id];
# 		a[max.id]=temp;
# 	}
# 	for (i=0;i<=2;i++){
# 		cout<<top[i].id<<' '<<top[i].mark;
# 		if (i!=2)cout<<endl;
# 	}
# return 0;
# }
#
# -------------------------------------------------- Code B --------------------------------------------------
# int main(){
# 	char mubiao[N];
# 	char zichuan[N];
# 	char replace[N];
# 	int i;
# 	int j=0;
# 	int flag;
# 	scanf("%s",mubiao);
#     scanf("%s",zichuan);
# 	scanf("%s",replace);
# 	int a=strlen(mubiao);
# 	int b=strlen(zichuan);
# 	for(i=0;i<a;i++){
# 		if(mubiao[i]==zichuan[j]){
# 			j++;
# 		}else {
# 			j=0;
# 		}
# 		if(j==b){
# 		    flag=1;
# 			break;
# 		}
# 	}
# 	if(flag==1){
# 	for(j=b-1;j>=0;j--){
# 		mubiao[i]=replace[j];
#
#
# 		i--;
# 	}
# 	}
# 	printf("%s\n",mubiao);
# 	return 0;
# }

# %%
#print(source.iloc[3241]['code'])
print(source['code'][3241])
print('-'*30)
print(source['parsed code'][3241])
# Out:
# int N, M;
# int method(int N, int M)
# {
# 	if (N == 1 || (N == 0 && M == 0))
# 		return 1;
# 	if (N > M)
# 		return method(N - 1, M);
#
#
# 		return method(N - 1, M) + method(N, M - N);
# }
# int main()
# {
# 	int t, i, K;
# 	cin >> t;
# 	for (i = 0;	i < t; i++)
# 	{
# 		cin >> M >> N;
# 		K = method(N, M);
# 		cout << K << endl;
# 	}
# 	return 0;
# }
# ------------------------------
# FileAST(ext=[Decl(name='N',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='N',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=None,
#                   bitsize=None
#                   ),
#              Decl(name='M',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='M',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=None,
#                   bitsize=None
#                   ),
#              FuncDef(decl=Decl(name='method',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=ParamList(params=[Decl(name='N',
#                                                                          quals=[
#                                                                                ],
#                                                                          storage=[
#                                                                                  ],
#                                                                          funcspec=[
#                                                                                   ],
#                                                                          type=TypeDecl(declname='N',
#                                                                                        quals=[
#                                                                                              ],
#                                                                                        type=IdentifierType(names=['int'
#                                                                                                                  ]
#                                                                                                            )
#                                                                                        ),
#                                                                          init=None,
#                                                                          bitsize=None
#                                                                          ),
#                                                                     Decl(name='M',
#                                                                          quals=[
#                                                                                ],
#                                                                          storage=[
#                                                                                  ],
#                                                                          funcspec=[
#                                                                                   ],
#                                                                          type=TypeDecl(declname='M',
#                                                                                        quals=[
#                                                                                              ],
#                                                                                        type=IdentifierType(names=['int'
#                                                                                                                  ]
#                                                                                                            )
#                                                                                        ),
#                                                                          init=None,
#                                                                          bitsize=None
#                                                                          )
#                                                                    ]
#                                                             ),
#                                              type=TypeDecl(declname='method',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['int'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[If(cond=BinaryOp(op='||',
#                                                                  left=BinaryOp(op='==',
#                                                                                left=ID(name='N'
#                                                                                        ),
#                                                                                right=Constant(type='int',
#                                                                                               value='1'
#                                                                                               )
#                                                                                ),
#                                                                  right=BinaryOp(op='&&',
#                                                                                 left=BinaryOp(op='==',
#                                                                                               left=ID(name='N'
#                                                                                                       ),
#                                                                                               right=Constant(type='int',
#                                                                                                              value='0'
#                                                                                                              )
#                                                                                               ),
#                                                                                 right=BinaryOp(op='==',
#                                                                                                left=ID(name='M'
#                                                                                                        ),
#                                                                                                right=Constant(type='int',
#                                                                                                               value='0'
#                                                                                                               )
#                                                                                                )
#                                                                                 )
#                                                                  ),
#                                                    iftrue=Return(expr=Constant(type='int',
#                                                                                value='1'
#                                                                                )
#                                                                  ),
#                                                    iffalse=None
#                                                    ),
#                                                 If(cond=BinaryOp(op='>',
#                                                                  left=ID(name='N'
#                                                                          ),
#                                                                  right=ID(name='M'
#                                                                           )
#                                                                  ),
#                                                    iftrue=Return(expr=FuncCall(name=ID(name='method'
#                                                                                        ),
#                                                                                args=ExprList(exprs=[BinaryOp(op='-',
#                                                                                                              left=ID(name='N'
#                                                                                                                      ),
#                                                                                                              right=Constant(type='int',
#                                                                                                                             value='1'
#                                                                                                                             )
#                                                                                                              ),
#                                                                                                     ID(name='M'
#                                                                                                        )
#                                                                                                    ]
#                                                                                              )
#                                                                                )
#                                                                  ),
#                                                    iffalse=None
#                                                    ),
#                                                 Return(expr=BinaryOp(op='+',
#                                                                      left=FuncCall(name=ID(name='method'
#                                                                                            ),
#                                                                                    args=ExprList(exprs=[BinaryOp(op='-',
#                                                                                                                  left=ID(name='N'
#                                                                                                                          ),
#                                                                                                                  right=Constant(type='int',
#                                                                                                                                 value='1'
#                                                                                                                                 )
#                                                                                                                  ),
#                                                                                                         ID(name='M'
#                                                                                                            )
#                                                                                                        ]
#                                                                                                  )
#                                                                                    ),
#                                                                      right=FuncCall(name=ID(name='method'
#                                                                                             ),
#                                                                                     args=ExprList(exprs=[ID(name='N'
#                                                                                                             ),
#                                                                                                          BinaryOp(op='-',
#                                                                                                                   left=ID(name='M'
#                                                                                                                           ),
#                                                                                                                   right=ID(name='N'
#                                                                                                                            )
#                                                                                                                   )
#                                                                                                         ]
#                                                                                                   )
#                                                                                     )
#                                                                      )
#                                                        )
#                                                ]
#                                    )
#                      ),
#              FuncDef(decl=Decl(name='main',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='main',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['int'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[Decl(name='t',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='t',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 Decl(name='i',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='i',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 Decl(name='K',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='K',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 BinaryOp(op='>>',
#                                                          left=ID(name='cin'
#                                                                  ),
#                                                          right=ID(name='t'
#                                                                   )
#                                                          ),
#                                                 For(init=Assignment(op='=',
#                                                                     lvalue=ID(name='i'
#                                                                               ),
#                                                                     rvalue=Constant(type='int',
#                                                                                     value='0'
#                                                                                     )
#                                                                     ),
#                                                     cond=BinaryOp(op='<',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=ID(name='t'
#                                                                            )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[BinaryOp(op='>>',
#                                                                                         left=BinaryOp(op='>>',
#                                                                                                       left=ID(name='cin'
#                                                                                                               ),
#                                                                                                       right=ID(name='M'
#                                                                                                                )
#                                                                                                       ),
#                                                                                         right=ID(name='N'
#                                                                                                  )
#                                                                                         ),
#                                                                                Assignment(op='=',
#                                                                                           lvalue=ID(name='K'
#                                                                                                     ),
#                                                                                           rvalue=FuncCall(name=ID(name='method'
#                                                                                                                   ),
#                                                                                                           args=ExprList(exprs=[ID(name='N'
#                                                                                                                                   ),
#                                                                                                                                ID(name='M'
#                                                                                                                                   )
#                                                                                                                               ]
#                                                                                                                         )
#                                                                                                           )
#                                                                                           ),
#                                                                                BinaryOp(op='<<',
#                                                                                         left=BinaryOp(op='<<',
#                                                                                                       left=ID(name='cout'
#                                                                                                               ),
#                                                                                                       right=ID(name='K'
#                                                                                                                )
#                                                                                                       ),
#                                                                                         right=ID(name='endl'
#                                                                                                  )
#                                                                                         )
#                                                                               ]
#                                                                   )
#                                                     ),
#                                                 Return(expr=Constant(type='int',
#                                                                      value='0'
#                                                                      )
#                                                        )
#                                                ]
#                                    )
#                      )
#             ]
#         )

# %%
ratio = '3:1:1'
ratios = [int(r) for r in ratio.split(':')]
data_num = len(pairs)
train_split = int(ratios[0]/sum(ratios)*data_num)
#val_split = train_split + int(ratios[1]/sum(ratios)*data_num)

#data = data.sample(frac=1, random_state=666)
train_pairs = pairs.sample(frac=1, random_state=666).iloc[:train_split]
#dev = data.iloc[train_split:val_split]
#test = data.iloc[val_split:]

train_ids = train_pairs['id1'].append(train_pairs['id2']).unique()

# %%
trees = source.set_index('id',drop=False).loc[train_ids]

# %%
from prepare_data import get_sequences

def trans_to_sequences(ast):
    sequence = []
    get_sequences(ast, sequence)
    return sequence

# %%
corpus = trees['parsed code'].apply(trans_to_sequences) # type = Series(list(str))

# %%
print(source['code'][9566])
print('-'*30)
print(source['parsed code'][9566])
print('-'*30)
corpus[9566]
# Out:
# int a[200];
# int b[100];
# int lena = 0;
# int lenb = 0;
# void Input() {
# 	cin >> lena >> lenb;
# 	for (int i = 0; i < lena; i++) {
# 		cin >> a[i];
# 	}
# 	for (int i = 0; i < lenb; i++) {
# 		cin >> b[i];
# 	}
# }
# void Sort() {
# 	for (int i = 1; i <= lena - 1; i++) {
# 		for (int j = 0; j <= lena - 1 - i; j++) {
# 			if (a[j] > a[j + 1]) {
# 				int temp = a[j];
# 				a[j] = a[j + 1];
# 				a[j + 1] = temp;
# 			}
# 		}
# 	}
# 	for (int i = 1; i <= lenb - 1; i++) {
# 		for (int j = 0; j <= lenb - 1 - i; j++) {
# 			if (b[j] > b[j + 1]) {
# 				int temp = b[j];
# 				b[j] = b[j + 1];
# 				b[j + 1] = temp;
# 			}
# 		}
# 	}
# }
# void Catenate() {
# 	for (int i = 0; i <= lenb - 1; i++) {
# 		a[lena + i] = b[i];
# 	}
# }
# void Output() {
# 	cout << a[0];
# 	for (int i = 1; i <= lena + lenb - 1; i++) {
# 		cout << ' ' << a[i];
# 	}
# }
# int main() {
# 	Input();
# 	Sort();
# 	Catenate();
# 	Output();
# 	return 0;
# }
#
# ------------------------------
# FileAST(ext=[Decl(name='a',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=ArrayDecl(type=TypeDecl(declname='a',
#                                                quals=[
#                                                      ],
#                                                type=IdentifierType(names=['int'
#                                                                          ]
#                                                                    )
#                                                ),
#                                  dim=Constant(type='int',
#                                               value='200'
#                                               ),
#                                  dim_quals=[
#                                            ]
#                                  ),
#                   init=None,
#                   bitsize=None
#                   ),
#              Decl(name='b',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=ArrayDecl(type=TypeDecl(declname='b',
#                                                quals=[
#                                                      ],
#                                                type=IdentifierType(names=['int'
#                                                                          ]
#                                                                    )
#                                                ),
#                                  dim=Constant(type='int',
#                                               value='100'
#                                               ),
#                                  dim_quals=[
#                                            ]
#                                  ),
#                   init=None,
#                   bitsize=None
#                   ),
#              Decl(name='lena',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='lena',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=Constant(type='int',
#                                 value='0'
#                                 ),
#                   bitsize=None
#                   ),
#              Decl(name='lenb',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='lenb',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=Constant(type='int',
#                                 value='0'
#                                 ),
#                   bitsize=None
#                   ),
#              FuncDef(decl=Decl(name='Input',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='Input',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['void'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[BinaryOp(op='>>',
#                                                          left=BinaryOp(op='>>',
#                                                                        left=ID(name='cin'
#                                                                                ),
#                                                                        right=ID(name='lena'
#                                                                                 )
#                                                                        ),
#                                                          right=ID(name='lenb'
#                                                                   )
#                                                          ),
#                                                 For(init=DeclList(decls=[Decl(name='i',
#                                                                               quals=[
#                                                                                     ],
#                                                                               storage=[
#                                                                                       ],
#                                                                               funcspec=[
#                                                                                        ],
#                                                                               type=TypeDecl(declname='i',
#                                                                                             quals=[
#                                                                                                   ],
#                                                                                             type=IdentifierType(names=['int'
#                                                                                                                       ]
#                                                                                                                 )
#                                                                                             ),
#                                                                               init=Constant(type='int',
#                                                                                             value='0'
#                                                                                             ),
#                                                                               bitsize=None
#                                                                               )
#                                                                         ]
#                                                                   ),
#                                                     cond=BinaryOp(op='<',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=ID(name='lena'
#                                                                            )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[BinaryOp(op='>>',
#                                                                                         left=ID(name='cin'
#                                                                                                 ),
#                                                                                         right=ArrayRef(name=ID(name='a'
#                                                                                                                ),
#                                                                                                        subscript=ID(name='i'
#                                                                                                                     )
#                                                                                                        )
#                                                                                         )
#                                                                               ]
#                                                                   )
#                                                     ),
#                                                 For(init=DeclList(decls=[Decl(name='i',
#                                                                               quals=[
#                                                                                     ],
#                                                                               storage=[
#                                                                                       ],
#                                                                               funcspec=[
#                                                                                        ],
#                                                                               type=TypeDecl(declname='i',
#                                                                                             quals=[
#                                                                                                   ],
#                                                                                             type=IdentifierType(names=['int'
#                                                                                                                       ]
#                                                                                                                 )
#                                                                                             ),
#                                                                               init=Constant(type='int',
#                                                                                             value='0'
#                                                                                             ),
#                                                                               bitsize=None
#                                                                               )
#                                                                         ]
#                                                                   ),
#                                                     cond=BinaryOp(op='<',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=ID(name='lenb'
#                                                                            )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[BinaryOp(op='>>',
#                                                                                         left=ID(name='cin'
#                                                                                                 ),
#                                                                                         right=ArrayRef(name=ID(name='b'
#                                                                                                                ),
#                                                                                                        subscript=ID(name='i'
#                                                                                                                     )
#                                                                                                        )
#                                                                                         )
#                                                                               ]
#                                                                   )
#                                                     )
#                                                ]
#                                    )
#                      ),
#              FuncDef(decl=Decl(name='Sort',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='Sort',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['void'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[For(init=DeclList(decls=[Decl(name='i',
#                                                                               quals=[
#                                                                                     ],
#                                                                               storage=[
#                                                                                       ],
#                                                                               funcspec=[
#                                                                                        ],
#                                                                               type=TypeDecl(declname='i',
#                                                                                             quals=[
#                                                                                                   ],
#                                                                                             type=IdentifierType(names=['int'
#                                                                                                                       ]
#                                                                                                                 )
#                                                                                             ),
#                                                                               init=Constant(type='int',
#                                                                                             value='1'
#                                                                                             ),
#                                                                               bitsize=None
#                                                                               )
#                                                                         ]
#                                                                   ),
#                                                     cond=BinaryOp(op='<=',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=BinaryOp(op='-',
#                                                                                  left=ID(name='lena'
#                                                                                          ),
#                                                                                  right=Constant(type='int',
#                                                                                                 value='1'
#                                                                                                 )
#                                                                                  )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[For(init=DeclList(decls=[Decl(name='j',
#                                                                                                              quals=[
#                                                                                                                    ],
#                                                                                                              storage=[
#                                                                                                                      ],
#                                                                                                              funcspec=[
#                                                                                                                       ],
#                                                                                                              type=TypeDecl(declname='j',
#                                                                                                                            quals=[
#                                                                                                                                  ],
#                                                                                                                            type=IdentifierType(names=['int'
#                                                                                                                                                      ]
#                                                                                                                                                )
#                                                                                                                            ),
#                                                                                                              init=Constant(type='int',
#                                                                                                                            value='0'
#                                                                                                                            ),
#                                                                                                              bitsize=None
#                                                                                                              )
#                                                                                                        ]
#                                                                                                  ),
#                                                                                    cond=BinaryOp(op='<=',
#                                                                                                  left=ID(name='j'
#                                                                                                          ),
#                                                                                                  right=BinaryOp(op='-',
#                                                                                                                 left=BinaryOp(op='-',
#                                                                                                                               left=ID(name='lena'
#                                                                                                                                       ),
#                                                                                                                               right=Constant(type='int',
#                                                                                                                                              value='1'
#                                                                                                                                              )
#                                                                                                                               ),
#                                                                                                                 right=ID(name='i'
#                                                                                                                          )
#                                                                                                                 )
#                                                                                                  ),
#                                                                                    next=UnaryOp(op='p++',
#                                                                                                 expr=ID(name='j'
#                                                                                                         )
#                                                                                                 ),
#                                                                                    stmt=Compound(block_items=[If(cond=BinaryOp(op='>',
#                                                                                                                                left=ArrayRef(name=ID(name='a'
#                                                                                                                                                      ),
#                                                                                                                                              subscript=ID(name='j'
#                                                                                                                                                           )
#                                                                                                                                              ),
#                                                                                                                                right=ArrayRef(name=ID(name='a'
#                                                                                                                                                       ),
#                                                                                                                                               subscript=BinaryOp(op='+',
#                                                                                                                                                                  left=ID(name='j'
#                                                                                                                                                                          ),
#                                                                                                                                                                  right=Constant(type='int',
#                                                                                                                                                                                 value='1'
#                                                                                                                                                                                 )
#                                                                                                                                                                  )
#                                                                                                                                               )
#                                                                                                                                ),
#                                                                                                                  iftrue=Compound(block_items=[Decl(name='temp',
#                                                                                                                                                    quals=[
#                                                                                                                                                          ],
#                                                                                                                                                    storage=[
#                                                                                                                                                            ],
#                                                                                                                                                    funcspec=[
#                                                                                                                                                             ],
#                                                                                                                                                    type=TypeDecl(declname='temp',
#                                                                                                                                                                  quals=[
#                                                                                                                                                                        ],
#                                                                                                                                                                  type=IdentifierType(names=['int'
#                                                                                                                                                                                            ]
#                                                                                                                                                                                      )
#                                                                                                                                                                  ),
#                                                                                                                                                    init=ArrayRef(name=ID(name='a'
#                                                                                                                                                                          ),
#                                                                                                                                                                  subscript=ID(name='j'
#                                                                                                                                                                               )
#                                                                                                                                                                  ),
#                                                                                                                                                    bitsize=None
#                                                                                                                                                    ),
#                                                                                                                                               Assignment(op='=',
#                                                                                                                                                          lvalue=ArrayRef(name=ID(name='a'
#                                                                                                                                                                                  ),
#                                                                                                                                                                          subscript=ID(name='j'
#                                                                                                                                                                                       )
#                                                                                                                                                                          ),
#                                                                                                                                                          rvalue=ArrayRef(name=ID(name='a'
#                                                                                                                                                                                  ),
#                                                                                                                                                                          subscript=BinaryOp(op='+',
#                                                                                                                                                                                             left=ID(name='j'
#                                                                                                                                                                                                     ),
#                                                                                                                                                                                             right=Constant(type='int',
#                                                                                                                                                                                                            value='1'
#                                                                                                                                                                                                            )
#                                                                                                                                                                                             )
#                                                                                                                                                                          )
#                                                                                                                                                          ),
#                                                                                                                                               Assignment(op='=',
#                                                                                                                                                          lvalue=ArrayRef(name=ID(name='a'
#                                                                                                                                                                                  ),
#                                                                                                                                                                          subscript=BinaryOp(op='+',
#                                                                                                                                                                                             left=ID(name='j'
#                                                                                                                                                                                                     ),
#                                                                                                                                                                                             right=Constant(type='int',
#                                                                                                                                                                                                            value='1'
#                                                                                                                                                                                                            )
#                                                                                                                                                                                             )
#                                                                                                                                                                          ),
#                                                                                                                                                          rvalue=ID(name='temp'
#                                                                                                                                                                    )
#                                                                                                                                                          )
#                                                                                                                                              ]
#                                                                                                                                  ),
#                                                                                                                  iffalse=None
#                                                                                                                  )
#                                                                                                              ]
#                                                                                                  )
#                                                                                    )
#                                                                               ]
#                                                                   )
#                                                     ),
#                                                 For(init=DeclList(decls=[Decl(name='i',
#                                                                               quals=[
#                                                                                     ],
#                                                                               storage=[
#                                                                                       ],
#                                                                               funcspec=[
#                                                                                        ],
#                                                                               type=TypeDecl(declname='i',
#                                                                                             quals=[
#                                                                                                   ],
#                                                                                             type=IdentifierType(names=['int'
#                                                                                                                       ]
#                                                                                                                 )
#                                                                                             ),
#                                                                               init=Constant(type='int',
#                                                                                             value='1'
#                                                                                             ),
#                                                                               bitsize=None
#                                                                               )
#                                                                         ]
#                                                                   ),
#                                                     cond=BinaryOp(op='<=',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=BinaryOp(op='-',
#                                                                                  left=ID(name='lenb'
#                                                                                          ),
#                                                                                  right=Constant(type='int',
#                                                                                                 value='1'
#                                                                                                 )
#                                                                                  )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[For(init=DeclList(decls=[Decl(name='j',
#                                                                                                              quals=[
#                                                                                                                    ],
#                                                                                                              storage=[
#                                                                                                                      ],
#                                                                                                              funcspec=[
#                                                                                                                       ],
#                                                                                                              type=TypeDecl(declname='j',
#                                                                                                                            quals=[
#                                                                                                                                  ],
#                                                                                                                            type=IdentifierType(names=['int'
#                                                                                                                                                      ]
#                                                                                                                                                )
#                                                                                                                            ),
#                                                                                                              init=Constant(type='int',
#                                                                                                                            value='0'
#                                                                                                                            ),
#                                                                                                              bitsize=None
#                                                                                                              )
#                                                                                                        ]
#                                                                                                  ),
#                                                                                    cond=BinaryOp(op='<=',
#                                                                                                  left=ID(name='j'
#                                                                                                          ),
#                                                                                                  right=BinaryOp(op='-',
#                                                                                                                 left=BinaryOp(op='-',
#                                                                                                                               left=ID(name='lenb'
#                                                                                                                                       ),
#                                                                                                                               right=Constant(type='int',
#                                                                                                                                              value='1'
#                                                                                                                                              )
#                                                                                                                               ),
#                                                                                                                 right=ID(name='i'
#                                                                                                                          )
#                                                                                                                 )
#                                                                                                  ),
#                                                                                    next=UnaryOp(op='p++',
#                                                                                                 expr=ID(name='j'
#                                                                                                         )
#                                                                                                 ),
#                                                                                    stmt=Compound(block_items=[If(cond=BinaryOp(op='>',
#                                                                                                                                left=ArrayRef(name=ID(name='b'
#                                                                                                                                                      ),
#                                                                                                                                              subscript=ID(name='j'
#                                                                                                                                                           )
#                                                                                                                                              ),
#                                                                                                                                right=ArrayRef(name=ID(name='b'
#                                                                                                                                                       ),
#                                                                                                                                               subscript=BinaryOp(op='+',
#                                                                                                                                                                  left=ID(name='j'
#                                                                                                                                                                          ),
#                                                                                                                                                                  right=Constant(type='int',
#                                                                                                                                                                                 value='1'
#                                                                                                                                                                                 )
#                                                                                                                                                                  )
#                                                                                                                                               )
#                                                                                                                                ),
#                                                                                                                  iftrue=Compound(block_items=[Decl(name='temp',
#                                                                                                                                                    quals=[
# ...
#                                                                           ),
#                                                                   right=BinaryOp(op='-',
#                                                                                  left=ID(name='lenb'
#                                                                                          ),
#                                                                                  right=Constant(type='int',
#                                                                                                 value='1'
#                                                                                                 )
#                                                                                  )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[Assignment(op='=',
#                                                                                           lvalue=ArrayRef(name=ID(name='a'
#                                                                                                                   ),
#                                                                                                           subscript=BinaryOp(op='+',
#                                                                                                                              left=ID(name='lena'
#                                                                                                                                      ),
#                                                                                                                              right=ID(name='i'
#                                                                                                                                       )
#                                                                                                                              )
#                                                                                                           ),
#                                                                                           rvalue=ArrayRef(name=ID(name='b'
#                                                                                                                   ),
#                                                                                                           subscript=ID(name='i'
#                                                                                                                        )
#                                                                                                           )
#                                                                                           )
#                                                                               ]
#                                                                   )
#                                                     )
#                                                ]
#                                    )
#                      ),
#              FuncDef(decl=Decl(name='Output',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='Output',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['void'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[BinaryOp(op='<<',
#                                                          left=ID(name='cout'
#                                                                  ),
#                                                          right=ArrayRef(name=ID(name='a'
#                                                                                 ),
#                                                                         subscript=Constant(type='int',
#                                                                                            value='0'
#                                                                                            )
#                                                                         )
#                                                          ),
#                                                 For(init=DeclList(decls=[Decl(name='i',
#                                                                               quals=[
#                                                                                     ],
#                                                                               storage=[
#                                                                                       ],
#                                                                               funcspec=[
#                                                                                        ],
#                                                                               type=TypeDecl(declname='i',
#                                                                                             quals=[
#                                                                                                   ],
#                                                                                             type=IdentifierType(names=['int'
#                                                                                                                       ]
#                                                                                                                 )
#                                                                                             ),
#                                                                               init=Constant(type='int',
#                                                                                             value='1'
#                                                                                             ),
#                                                                               bitsize=None
#                                                                               )
#                                                                         ]
#                                                                   ),
#                                                     cond=BinaryOp(op='<=',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=BinaryOp(op='-',
#                                                                                  left=BinaryOp(op='+',
#                                                                                                left=ID(name='lena'
#                                                                                                        ),
#                                                                                                right=ID(name='lenb'
#                                                                                                         )
#                                                                                                ),
#                                                                                  right=Constant(type='int',
#                                                                                                 value='1'
#                                                                                                 )
#                                                                                  )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[BinaryOp(op='<<',
#                                                                                         left=BinaryOp(op='<<',
#                                                                                                       left=ID(name='cout'
#                                                                                                               ),
#                                                                                                       right=Constant(type='char',
#                                                                                                                      value="' '"
#                                                                                                                      )
#                                                                                                       ),
#                                                                                         right=ArrayRef(name=ID(name='a'
#                                                                                                                ),
#                                                                                                        subscript=ID(name='i'
#                                                                                                                     )
#                                                                                                        )
#                                                                                         )
#                                                                               ]
#                                                                   )
#                                                     )
#                                                ]
#                                    )
#                      ),
#              FuncDef(decl=Decl(name='main',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='main',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['int'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[FuncCall(name=ID(name='Input'
#                                                                  ),
#                                                          args=None
#                                                          ),
#                                                 FuncCall(name=ID(name='Sort'
#                                                                  ),
#                                                          args=None
#                                                          ),
#                                                 FuncCall(name=ID(name='Catenate'
#                                                                  ),
#                                                          args=None
#                                                          ),
#                                                 FuncCall(name=ID(name='Output'
#                                                                  ),
#                                                          args=None
#                                                          ),
#                                                 Return(expr=Constant(type='int',
#                                                                      value='0'
#                                                                      )
#                                                        )
#                                                ]
#                                    )
#                      )
#             ]
#         )
# ------------------------------
# ['FileAST',
#  'Decl',
#  'ArrayDecl',
#  'a',
#  'int',
#  '200',
#  'Decl',
#  'ArrayDecl',
#  'b',
#  'int',
#  '100',
#  'Decl',
#  'lena',
#  'int',
#  '0',
#  'Decl',
#  'lenb',
#  'int',
#  '0',
#  'FuncDef',
#  'Decl',
#  'FuncDecl',
#  'Input',
#  'void',
#  'Compound',
#  '>>',
#  '>>',
#  'cin',
#  'lena',
#  'lenb',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '0',
#  '<',
#  'i',
#  'lena',
#  '++',
#  'i',
#  'Compound',
#  '>>',
#  'cin',
#  'ArrayRef',
#  'a',
#  'i',
#  'End',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '0',
#  '<',
#  'i',
#  'lenb',
#  '++',
#  'i',
#  'Compound',
#  '>>',
#  'cin',
#  'ArrayRef',
#  'b',
#  'i',
#  'End',
#  'End',
#  'FuncDef',
#  'Decl',
#  'FuncDecl',
#  'Sort',
#  'void',
#  'Compound',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '1',
#  '<=',
#  'i',
#  '-',
#  'lena',
#  '1',
#  '++',
#  'i',
#  'Compound',
#  'For',
#  'DeclList',
#  'Decl',
#  'j',
#  'int',
#  '0',
#  '<=',
#  'j',
#  '-',
#  '-',
#  'lena',
#  '1',
#  'i',
#  '++',
#  'j',
#  'Compound',
#  'If',
#  '>',
#  'ArrayRef',
#  'a',
#  'j',
#  'ArrayRef',
#  'a',
#  '+',
#  'j',
#  '1',
#  'Compound',
#  'Decl',
#  'temp',
#  'int',
#  'ArrayRef',
#  'a',
#  'j',
#  '=',
#  'ArrayRef',
#  'a',
#  'j',
#  'ArrayRef',
#  'a',
#  '+',
#  'j',
#  '1',
#  '=',
#  'ArrayRef',
#  'a',
#  '+',
#  'j',
#  '1',
#  'temp',
#  'End',
#  'End',
#  'End',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '1',
#  '<=',
#  'i',
#  '-',
#  'lenb',
#  '1',
#  '++',
#  'i',
#  'Compound',
#  'For',
#  'DeclList',
#  'Decl',
#  'j',
#  'int',
#  '0',
#  '<=',
#  'j',
#  '-',
#  '-',
#  'lenb',
#  '1',
#  'i',
#  '++',
#  'j',
#  'Compound',
#  'If',
#  '>',
#  'ArrayRef',
#  'b',
#  'j',
#  'ArrayRef',
#  'b',
#  '+',
#  'j',
#  '1',
#  'Compound',
#  'Decl',
#  'temp',
#  'int',
#  'ArrayRef',
#  'b',
#  'j',
#  '=',
#  'ArrayRef',
#  'b',
#  'j',
#  'ArrayRef',
#  'b',
#  '+',
#  'j',
#  '1',
#  '=',
#  'ArrayRef',
#  'b',
#  '+',
#  'j',
#  '1',
#  'temp',
#  'End',
#  'End',
#  'End',
#  'End',
#  'FuncDef',
#  'Decl',
#  'FuncDecl',
#  'Catenate',
#  'void',
#  'Compound',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '0',
#  '<=',
#  'i',
#  '-',
#  'lenb',
#  '1',
#  '++',
#  'i',
#  'Compound',
#  '=',
#  'ArrayRef',
#  'a',
#  '+',
#  'lena',
#  'i',
#  'ArrayRef',
#  'b',
#  'i',
#  'End',
#  'End',
#  'FuncDef',
#  'Decl',
#  'FuncDecl',
#  'Output',
#  'void',
#  'Compound',
#  '<<',
#  'cout',
#  'ArrayRef',
#  'a',
#  '0',
#  'For',
#  'DeclList',
#  'Decl',
#  'i',
#  'int',
#  '1',
#  '<=',
#  'i',
#  '-',
#  '+',
#  'lena',
#  'lenb',
#  '1',
#  '++',
#  'i',
#  'Compound',
#  '<<',
#  '<<',
#  'cout',
#  "' '",
#  'ArrayRef',
#  'a',
#  'i',
#  'End',
#  'End',
#  'FuncDef',
#  'Decl',
#  'FuncDecl',
#  'main',
#  'int',
#  'Compound',
#  'FuncCall',
#  'input',
#  'FuncCall',
#  'sort',
#  'FuncCall',
#  'catenate',
#  'FuncCall',
#  'output',
#  'Return',
#  '0',
#  'End']

# %%
str_corpus = [' '.join(c) for c in corpus]  # type = list(str)

# %%
from gensim.models.word2vec import Word2Vec
w2v = Word2Vec(corpus, size=128, workers=16, sg=1, max_final_vocab=3000)

# %%
#word2vec = Word2Vec.load(root+language+'/train/embedding/node_w2v_128').wv
word2vec = w2v.wv
vocab = word2vec.vocab  # type = dict
max_token = word2vec.vectors.shape[0]
# word2vec['i'] 就是 'i' 的嵌入向量

# %%
del train_ids, trees, corpus, str_corpus  # This only serve for computing w2v

# %%
from prepare_data import get_blocks

def tree_to_index(node):
    token = node.token
    result = [vocab[token].index if token in vocab else max_token]
    children = node.children
    for child in children:
        result.append(tree_to_index(child))
    return result

def trans2seq(r):
    blocks = []
    get_blocks(r, blocks)
    tree = []
    for b in blocks:
        btree = tree_to_index(b)
        tree.append(btree)
    return tree


def tree_to_token(node):
    token = node.token
    result = [token if token in vocab else 'max_token']
    children = node.children
    for child in children:
        result.append(tree_to_token(child))
    return result

def trans2tokenseq(r):
    blocks = []
    get_blocks(r, blocks)
    tree = []
    for b in blocks:
        btree = tree_to_token(b)
        tree.append(btree)
    return tree

# %%
blocks = pd.DataFrame(source, copy=True)
blocks['code seq'] = blocks['parsed code'].apply(trans2seq)
if 'label' in blocks.columns:
    blocks.drop('label', axis=1, inplace=True)

# %%
tokenblocks = pd.DataFrame(source, copy=True)
tokenblocks['token seq'] = tokenblocks['parsed code'].apply(trans2tokenseq)
if 'label' in tokenblocks.columns:
    tokenblocks.drop('label', axis=1, inplace=True)

# %%
print(type(blocks['code seq'][3241]))  # list
print(len(blocks['code seq'][3241]))
print(tokenblocks['token seq'][3241])
print(blocks['code seq'][3241])
print(blocks['parsed code'][3241])
print(blocks['code'][3241])
# Out:
# <class 'list'>
# 22
# [['FuncDef', ['Decl', ['FuncDecl', ['ParamList', ['Decl', ['N', ['int']]], ['Decl', ['M', ['int']]]], ['max_token', ['int']]]]], ['Compound'], ['If', ['||', ['==', ['n'], ['1']], ['&&', ['==', ['n'], ['0']], ['==', ['m'], ['0']]]]], ['Return', ['1']], ['If', ['>', ['n'], ['m']]], ['Return', ['FuncCall', ['max_token'], ['ExprList', ['-', ['n'], ['1']], ['m']]]], ['Return', ['+', ['FuncCall', ['max_token'], ['ExprList', ['-', ['n'], ['1']], ['m']]], ['FuncCall', ['max_token'], ['ExprList', ['n'], ['-', ['m'], ['n']]]]]], ['End'], ['FuncDef', ['Decl', ['FuncDecl', ['main', ['int']]]]], ['Compound'], ['Decl', ['t', ['int']]], ['Decl', ['i', ['int']]], ['Decl', ['K', ['int']]], ['>>', ['cin'], ['t']], ['For', ['=', ['i'], ['0']], ['<', ['i'], ['t']], ['++', ['i']]], ['Compound'], ['>>', ['>>', ['cin'], ['m']], ['n']], ['=', ['k'], ['FuncCall', ['max_token'], ['ExprList', ['n'], ['m']]]], ['<<', ['<<', ['cout'], ['k']], ['endl']], ['End'], ['Return', ['0']], ['End']]
# [[30, [1, [29, [63, [1, [285, [2]]], [1, [575, [2]]]], [2015, [2]]]]], [6], [18, [78, [22, [13], [14]], [44, [22, [13], [5]], [22, [25], [5]]]]], [35, [14]], [18, [56, [13], [25]]], [35, [9, [2015], [10, [23, [13], [14]], [25]]]], [35, [16, [9, [2015], [10, [23, [13], [14]], [25]]], [9, [2015], [10, [13], [23, [25], [13]]]]]], [7], [30, [1, [29, [40, [2]]]]], [6], [1, [43, [2]]], [1, [0, [2]]], [1, [951, [2]]], [54, [59], [43]], [15, [4, [0], [5]], [17, [0], [43]], [11, [0]]], [6], [54, [54, [59], [25]], [13]], [4, [19], [9, [2015], [10, [13], [25]]]], [51, [51, [67], [19]], [89]], [7], [35, [5]], [7]]
# FileAST(ext=[Decl(name='N',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='N',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=None,
#                   bitsize=None
#                   ),
#              Decl(name='M',
#                   quals=[
#                         ],
#                   storage=[
#                           ],
#                   funcspec=[
#                            ],
#                   type=TypeDecl(declname='M',
#                                 quals=[
#                                       ],
#                                 type=IdentifierType(names=['int'
#                                                           ]
#                                                     )
#                                 ),
#                   init=None,
#                   bitsize=None
#                   ),
#              FuncDef(decl=Decl(name='method',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=ParamList(params=[Decl(name='N',
#                                                                          quals=[
#                                                                                ],
#                                                                          storage=[
#                                                                                  ],
#                                                                          funcspec=[
#                                                                                   ],
#                                                                          type=TypeDecl(declname='N',
#                                                                                        quals=[
#                                                                                              ],
#                                                                                        type=IdentifierType(names=['int'
#                                                                                                                  ]
#                                                                                                            )
#                                                                                        ),
#                                                                          init=None,
#                                                                          bitsize=None
#                                                                          ),
#                                                                     Decl(name='M',
#                                                                          quals=[
#                                                                                ],
#                                                                          storage=[
#                                                                                  ],
#                                                                          funcspec=[
#                                                                                   ],
#                                                                          type=TypeDecl(declname='M',
#                                                                                        quals=[
#                                                                                              ],
#                                                                                        type=IdentifierType(names=['int'
#                                                                                                                  ]
#                                                                                                            )
#                                                                                        ),
#                                                                          init=None,
#                                                                          bitsize=None
#                                                                          )
#                                                                    ]
#                                                             ),
#                                              type=TypeDecl(declname='method',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['int'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[If(cond=BinaryOp(op='||',
#                                                                  left=BinaryOp(op='==',
#                                                                                left=ID(name='N'
#                                                                                        ),
#                                                                                right=Constant(type='int',
#                                                                                               value='1'
#                                                                                               )
#                                                                                ),
#                                                                  right=BinaryOp(op='&&',
#                                                                                 left=BinaryOp(op='==',
#                                                                                               left=ID(name='N'
#                                                                                                       ),
#                                                                                               right=Constant(type='int',
#                                                                                                              value='0'
#                                                                                                              )
#                                                                                               ),
#                                                                                 right=BinaryOp(op='==',
#                                                                                                left=ID(name='M'
#                                                                                                        ),
#                                                                                                right=Constant(type='int',
#                                                                                                               value='0'
#                                                                                                               )
#                                                                                                )
#                                                                                 )
#                                                                  ),
#                                                    iftrue=Return(expr=Constant(type='int',
#                                                                                value='1'
#                                                                                )
#                                                                  ),
#                                                    iffalse=None
#                                                    ),
#                                                 If(cond=BinaryOp(op='>',
#                                                                  left=ID(name='N'
#                                                                          ),
#                                                                  right=ID(name='M'
#                                                                           )
#                                                                  ),
#                                                    iftrue=Return(expr=FuncCall(name=ID(name='method'
#                                                                                        ),
#                                                                                args=ExprList(exprs=[BinaryOp(op='-',
#                                                                                                              left=ID(name='N'
#                                                                                                                      ),
#                                                                                                              right=Constant(type='int',
#                                                                                                                             value='1'
#                                                                                                                             )
#                                                                                                              ),
#                                                                                                     ID(name='M'
#                                                                                                        )
#                                                                                                    ]
#                                                                                              )
#                                                                                )
#                                                                  ),
#                                                    iffalse=None
#                                                    ),
#                                                 Return(expr=BinaryOp(op='+',
#                                                                      left=FuncCall(name=ID(name='method'
#                                                                                            ),
#                                                                                    args=ExprList(exprs=[BinaryOp(op='-',
#                                                                                                                  left=ID(name='N'
#                                                                                                                          ),
#                                                                                                                  right=Constant(type='int',
#                                                                                                                                 value='1'
#                                                                                                                                 )
#                                                                                                                  ),
#                                                                                                         ID(name='M'
#                                                                                                            )
#                                                                                                        ]
#                                                                                                  )
#                                                                                    ),
#                                                                      right=FuncCall(name=ID(name='method'
#                                                                                             ),
#                                                                                     args=ExprList(exprs=[ID(name='N'
#                                                                                                             ),
#                                                                                                          BinaryOp(op='-',
#                                                                                                                   left=ID(name='M'
#                                                                                                                           ),
#                                                                                                                   right=ID(name='N'
#                                                                                                                            )
#                                                                                                                   )
#                                                                                                         ]
#                                                                                                   )
#                                                                                     )
#                                                                      )
#                                                        )
#                                                ]
#                                    )
#                      ),
#              FuncDef(decl=Decl(name='main',
#                                quals=[
#                                      ],
#                                storage=[
#                                        ],
#                                funcspec=[
#                                         ],
#                                type=FuncDecl(args=None,
#                                              type=TypeDecl(declname='main',
#                                                            quals=[
#                                                                  ],
#                                                            type=IdentifierType(names=['int'
#                                                                                      ]
#                                                                                )
#                                                            )
#                                              ),
#                                init=None,
#                                bitsize=None
#                                ),
#                      param_decls=None,
#                      body=Compound(block_items=[Decl(name='t',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='t',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 Decl(name='i',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='i',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 Decl(name='K',
#                                                      quals=[
#                                                            ],
#                                                      storage=[
#                                                              ],
#                                                      funcspec=[
#                                                               ],
#                                                      type=TypeDecl(declname='K',
#                                                                    quals=[
#                                                                          ],
#                                                                    type=IdentifierType(names=['int'
#                                                                                              ]
#                                                                                        )
#                                                                    ),
#                                                      init=None,
#                                                      bitsize=None
#                                                      ),
#                                                 BinaryOp(op='>>',
#                                                          left=ID(name='cin'
#                                                                  ),
#                                                          right=ID(name='t'
#                                                                   )
#                                                          ),
#                                                 For(init=Assignment(op='=',
#                                                                     lvalue=ID(name='i'
#                                                                               ),
#                                                                     rvalue=Constant(type='int',
#                                                                                     value='0'
#                                                                                     )
#                                                                     ),
#                                                     cond=BinaryOp(op='<',
#                                                                   left=ID(name='i'
#                                                                           ),
#                                                                   right=ID(name='t'
#                                                                            )
#                                                                   ),
#                                                     next=UnaryOp(op='p++',
#                                                                  expr=ID(name='i'
#                                                                          )
#                                                                  ),
#                                                     stmt=Compound(block_items=[BinaryOp(op='>>',
#                                                                                         left=BinaryOp(op='>>',
#                                                                                                       left=ID(name='cin'
#                                                                                                               ),
#                                                                                                       right=ID(name='M'
#                                                                                                                )
#                                                                                                       ),
#                                                                                         right=ID(name='N'
#                                                                                                  )
#                                                                                         ),
#                                                                                Assignment(op='=',
#                                                                                           lvalue=ID(name='K'
#                                                                                                     ),
#                                                                                           rvalue=FuncCall(name=ID(name='method'
#                                                                                                                   ),
#                                                                                                           args=ExprList(exprs=[ID(name='N'
#                                                                                                                                   ),
#                                                                                                                                ID(name='M'
#                                                                                                                                   )
#                                                                                                                               ]
#                                                                                                                         )
#                                                                                                           )
#                                                                                           ),
#                                                                                BinaryOp(op='<<',
#                                                                                         left=BinaryOp(op='<<',
#                                                                                                       left=ID(name='cout'
#                                                                                                               ),
#                                                                                                       right=ID(name='K'
#                                                                                                                )
#                                                                                                       ),
#                                                                                         right=ID(name='endl'
#                                                                                                  )
#                                                                                         )
#                                                                               ]
#                                                                   )
#                                                     ),
#                                                 Return(expr=Constant(type='int',
#                                                                      value='0'
#                                                                      )
#                                                        )
#                                                ]
#                                    )
#                      )
#             ]
#         )
#
#
#
#
#
#
# int N, M;
# int method(int N, int M)
# {
# 	if (N == 1 || (N == 0 && M == 0))
# 		return 1;
# 	if (N > M)
# 		return method(N - 1, M);
#
#
# 		return method(N - 1, M) + method(N, M - N);
# }
# int main()
# {
# 	int t, i, K;
# 	cin >> t;
# 	for (i = 0;	i < t; i++)
# 	{
# 		cin >> M >> N;
# 		K = method(N, M);
# 		cout << K << endl;
# 	}
# 	return 0;
# }

# %%
blocks.to_pickle(root + language + '/blocks_1.pkl')

# %%
#print(ast)
#print(ast.children())
print(ast.children()[0][0])
print(ast.children()[0][1].name)
print(ast.children()[0][1].__class__)
print(ast.children()[0][1].__class__.__name__)
print(ast.children()[0][1].children())
print(ast.children()[0][1].children()[0][1])
print(ast.children()[0][1].children()[0][0])
print(ast.children()[0][1].children()[0][1].__class__.__name__)

print(ast.children()[0][1].bitsize)
print(ast.children()[0][1].children()[0][1])
# Out:
# ext[0]
# N
# <class 'pycparser.c_ast.Decl'>
# Decl
# (('type', TypeDecl(declname='N',
#          quals=[
#                ],
#          type=IdentifierType(names=['int'
#                                    ]
#                              )
#          )),)
# TypeDecl(declname='N',
#          quals=[
#                ],
#          type=IdentifierType(names=['int'
#                                    ]
#                              )
#          )
# type
# TypeDecl
# None
# TypeDecl(declname='N',
#          quals=[
#                ],
#          type=IdentifierType(names=['int'
#                                    ]
#                              )
#          )

# %%
def get_token(node, lower=True):
    if isinstance(node, str):
        return node
    name = node.__class__.__name__
    token = name
    is_name = False
    if len(node.children()) == 0:
        attr_names = node.attr_names
        if attr_names:
            if 'names' in attr_names:
                token = node.names[0]
            elif 'name' in attr_names:
                token = node.name
                is_name = True
            else:
                token = node.value
        else:
            token = name
    else:
        if name == 'TypeDecl':
            token = node.declname
        if node.attr_names:
            attr_names = node.attr_names
            if 'op' in attr_names:
                if node.op[0] == 'p':
                    token = node.op[1:]
                else:
                    token = node.op
    if token is None:
        token = name
    if lower and is_name:
        token = token.lower()
    return token
def visit(ast, l=0):
    for c, child in ast.children():
        print(' '*l, c, child.__class__.__name__, get_token(child))
        #print()
        visit(child, l+4)
visit(ast, 0)
# Out:
#  ext[0] Decl Decl
#      type TypeDecl N
#          type IdentifierType int
#  ext[1] Decl Decl
#      type TypeDecl M
#          type IdentifierType int
#  ext[2] FuncDef FuncDef
#      decl Decl Decl
#          type FuncDecl FuncDecl
#              args ParamList ParamList
#                  params[0] Decl Decl
#                      type TypeDecl N
#                          type IdentifierType int
#                  params[1] Decl Decl
#                      type TypeDecl M
#                          type IdentifierType int
#              type TypeDecl method
#                  type IdentifierType int
#      body Compound Compound
#          block_items[0] If If
#              cond BinaryOp ||
#                  left BinaryOp ==
#                      left ID n
#                      right Constant 1
#                  right BinaryOp &&
#                      left BinaryOp ==
#                          left ID n
#                          right Constant 0
#                      right BinaryOp ==
#                          left ID m
#                          right Constant 0
#              iftrue Return Return
#                  expr Constant 1
#          block_items[1] If If
#              cond BinaryOp >
#                  left ID n
#                  right ID m
#              iftrue Return Return
#                  expr FuncCall FuncCall
#                      name ID method
#                      args ExprList ExprList
#                          exprs[0] BinaryOp -
#                              left ID n
#                              right Constant 1
#                          exprs[1] ID m
#          block_items[2] Return Return
#              expr BinaryOp +
#                  left FuncCall FuncCall
#                      name ID method
#                      args ExprList ExprList
#                          exprs[0] BinaryOp -
#                              left ID n
#                              right Constant 1
#                          exprs[1] ID m
#                  right FuncCall FuncCall
#                      name ID method
#                      args ExprList ExprList
#                          exprs[0] ID n
#                          exprs[1] BinaryOp -
#                              left ID m
#                              right ID n
#  ext[3] FuncDef FuncDef
#      decl Decl Decl
#          type FuncDecl FuncDecl
#              type TypeDecl main
#                  type IdentifierType int
#      body Compound Compound
#          block_items[0] Decl Decl
#              type TypeDecl t
#                  type IdentifierType int
#          block_items[1] Decl Decl
#              type TypeDecl i
#                  type IdentifierType int
#          block_items[2] Decl Decl
#              type TypeDecl K
#                  type IdentifierType int
#          block_items[3] BinaryOp >>
#              left ID cin
#              right ID t
#          block_items[4] For For
#              init Assignment =
#                  lvalue ID i
#                  rvalue Constant 0
#              cond BinaryOp <
#                  left ID i
#                  right ID t
#              next UnaryOp ++
#                  expr ID i
#              stmt Compound Compound
#                  block_items[0] BinaryOp >>
#                      left BinaryOp >>
#                          left ID cin
#                          right ID m
#                      right ID n
#                  block_items[1] Assignment =
#                      lvalue ID k
#                      rvalue FuncCall FuncCall
#                          name ID method
#                          args ExprList ExprList
#                              exprs[0] ID n
#                              exprs[1] ID m
#                  block_items[2] BinaryOp <<
#                      left BinaryOp <<
#                          left ID cout
#                          right ID k
#                      right ID endl
#          block_items[5] Return Return
#              expr Constant 0
