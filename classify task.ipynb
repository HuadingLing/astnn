# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

class BatchTreeEncoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, encode_dim, batch_size, use_gpu, pretrained_weight=None):
        super(BatchTreeEncoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.encode_dim = encode_dim
        self.W_c = nn.Linear(embedding_dim, encode_dim)
        self.W_l = nn.Linear(encode_dim, encode_dim)
        self.W_r = nn.Linear(encode_dim, encode_dim)
        self.activation = F.relu
        self.stop = -1
        self.batch_size = batch_size
        self.use_gpu = use_gpu
        self.node_list = []
        self.th = torch.cuda if use_gpu else torch
        self.batch_node = None
        # pretrained  embedding
        if pretrained_weight is not None:
            self.embedding.weight.data.copy_(torch.from_numpy(pretrained_weight))
            # self.embedding.weight.requires_grad = False

    def create_tensor(self, tensor):
        if self.use_gpu:
            return tensor.cuda()
        return tensor

    def traverse_mul(self, node, batch_index):
        size = len(node)
        if not size:
            return None
        batch_current = self.create_tensor(Variable(torch.zeros(size, self.encode_dim)))

        index, children_index = [], []
        current_node, children = [], []
        for i in range(size):
            if node[i][0] != -1:
                index.append(i)
                current_node.append(node[i][0])
                temp = node[i][1:]
                c_num = len(temp)
                for j in range(c_num):
                    if temp[j][0] != -1:
                        if len(children_index) <= j:
                            children_index.append([i])
                            children.append([temp[j]])
                        else:
                            children_index[j].append(i)
                            children[j].append(temp[j])
            else:
                batch_index[i] = -1

        batch_current = self.W_c(batch_current.index_copy(0, Variable(self.th.LongTensor(index)),
                                                          self.embedding(Variable(self.th.LongTensor(current_node)))))

        for c in range(len(children)):
            zeros = self.create_tensor(Variable(torch.zeros(size, self.encode_dim)))
            batch_children_index = [batch_index[i] for i in children_index[c]]
            tree = self.traverse_mul(children[c], batch_children_index)
            if tree is not None:
                batch_current += zeros.index_copy(0, Variable(self.th.LongTensor(children_index[c])), tree)
        # batch_current = F.tanh(batch_current)
        batch_index = [i for i in batch_index if i != -1]
        b_in = Variable(self.th.LongTensor(batch_index))
        self.node_list.append(self.batch_node.index_copy(0, b_in, batch_current))
        return batch_current

    def forward(self, x, bs):
        self.batch_size = bs
        self.batch_node = self.create_tensor(Variable(torch.zeros(self.batch_size, self.encode_dim)))
        self.node_list = []
        self.traverse_mul(x, list(range(self.batch_size)))
        self.node_list = torch.stack(self.node_list)
        return torch.max(self.node_list, 0)[0]


class BatchProgramClassifier(nn.Module):
    # def __init__(self, embedding_dim, hidden_dim, vocab_size, encode_dim, label_size, batch_size, use_gpu=True, pretrained_weight=None):
    def __init__(self, embedding_dim, hidden_dim, vocab_size, encode_dim, label_size, batch_size, use_gpu=True, pretrained_weight=None):
        super(BatchProgramClassifier, self).__init__()
        self.stop = [vocab_size-1]
        self.hidden_dim = hidden_dim
        self.num_layers = 1
        self.gpu = use_gpu
        self.batch_size = batch_size
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.encode_dim = encode_dim
        self.label_size = label_size
        #class "BatchTreeEncoder"
        self.encoder = BatchTreeEncoder(self.vocab_size, self.embedding_dim, self.encode_dim,
                                        self.batch_size, self.gpu, pretrained_weight)
        self.root2label = nn.Linear(self.encode_dim, self.label_size)
        # gru
        self.bigru = nn.GRU(self.encode_dim, self.hidden_dim, num_layers=self.num_layers, bidirectional=True,
                            batch_first=True)
        # linear
        self.hidden2label = nn.Linear(self.hidden_dim * 2, self.label_size)
        # hidden
        self.hidden = self.init_hidden()
        self.dropout = nn.Dropout(0.2)

    def init_hidden(self):
        if self.gpu is True:
            if isinstance(self.bigru, nn.LSTM):
                h0 = Variable(torch.zeros(self.num_layers * 2, self.batch_size, self.hidden_dim).cuda())
                c0 = Variable(torch.zeros(self.num_layers * 2, self.batch_size, self.hidden_dim).cuda())
                return h0, c0
            return Variable(torch.zeros(self.num_layers * 2, self.batch_size, self.hidden_dim)).cuda()
        else:
            return Variable(torch.zeros(self.num_layers * 2, self.batch_size, self.hidden_dim))

    def get_zeros(self, num):
        zeros = Variable(torch.zeros(num, self.encode_dim))
        if self.gpu:
            return zeros.cuda()
        return zeros

    def forward(self, x):
        lens = [len(item) for item in x]
        max_len = max(lens)

        encodes = []
        for i in range(self.batch_size):
            for j in range(lens[i]):
                encodes.append(x[i][j])

        encodes = self.encoder(encodes, sum(lens))
        seq, start, end = [], 0, 0
        for i in range(self.batch_size):
            end += lens[i]
            if max_len-lens[i]:
                seq.append(self.get_zeros(max_len-lens[i]))
            seq.append(encodes[start:end])
            start = end
        encodes = torch.cat(seq)
        encodes = encodes.view(self.batch_size, max_len, -1)

        # gru
        gru_out, hidden = self.bigru(encodes, self.hidden)

        gru_out = torch.transpose(gru_out, 1, 2)
        # pooling
        gru_out = F.max_pool1d(gru_out, gru_out.size(2)).squeeze(2)
        # gru_out = gru_out[:,-1]

        # linear
        y = self.hidden2label(gru_out)
        return y
    
def get_batch(dataset, idx, bs):
    tmp = dataset.iloc[idx: idx+bs]
    data, labels = [], []
    for _, item in tmp.iterrows():
        data.append(item[1])
        labels.append(item[2]-1)  # from [1, 104] to [0, 103]
    return data, torch.LongTensor(labels)

# %% [markdown]
# # Training

# %%
import torch

def get_device():
    if torch.cuda.is_available():
        if torch.cuda.get_device_name(0) == 'GeForce GT 730':
            device = 'cpu'
        else:
            device = 'cuda'
    else:
        device = 'cpu'
    return torch.device(device)

device = get_device()
# Out:
# C:\Users\A1\anaconda3\envs\pytorch\lib\site-packages\torch\cuda\__init__.py:102: UserWarning:
#     Found GPU0 GeForce GT 730 which is of cuda capability 3.0.
#     PyTorch no longer supports this GPU because it is too old.
#     The minimum cuda capability that we support is 3.5.
#
#   warnings.warn(old_gpu_warn % (d, name, major, capability[1]))
# C:\Users\A1\anaconda3\envs\pytorch\lib\site-packages\torch\cuda\__init__.py:125: UserWarning:
# GeForce GT 730 with CUDA capability sm_30 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 compute_37.
# If you want to use the GeForce GT 730 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))

# %%
import random
import time
import numpy as np
from torch.utils.data import DataLoader
import os
import sys
import pandas as pd
from gensim.models.word2vec import Word2Vec

root = 'data/'
train_data = pd.read_pickle(root+'train/blocks.pkl')
val_data = pd.read_pickle(root + 'dev/blocks.pkl')
test_data = pd.read_pickle(root+'test/blocks.pkl')

word2vec = Word2Vec.load(root+"train/embedding/node_w2v_128").wv

embeddings = np.zeros((word2vec.vectors.shape[0] + 1, word2vec.vectors.shape[1]), dtype="float32")
embeddings[:word2vec.vectors.shape[0]] = word2vec.vectors

# %%
USE_GPU = False
HIDDEN_DIM = 100
ENCODE_DIM = 128
LABELS = 104
EPOCHS = 15
BATCH_SIZE = 128
MAX_TOKENS = word2vec.vectors.shape[0]
EMBEDDING_DIM = word2vec.vectors.shape[1]

model = BatchProgramClassifier(EMBEDDING_DIM,HIDDEN_DIM,MAX_TOKENS+1,ENCODE_DIM,LABELS,BATCH_SIZE,
                               USE_GPU, embeddings)
if USE_GPU:
    model.cuda()
    
parameters = model.parameters()
optimizer = torch.optim.Adamax(parameters)
loss_function = torch.nn.CrossEntropyLoss()

# %%
train_loss_ = []
val_loss_ = []
train_acc_ = []
val_acc_ = []
best_acc = 0.0
print('Start training...')
# training procedure
best_model = model
for epoch in range(EPOCHS):
    start_time = time.time()

    total_acc = 0.0
    total_loss = 0.0
    total = 0.0
    i = 0
    model.train()
    while i < len(train_data):
        train_inputs, train_labels = get_batch(train_data, i, BATCH_SIZE)
        i += BATCH_SIZE
        if USE_GPU:
            train_inputs, train_labels = train_inputs.cuda(), train_labels.cuda()

        model.zero_grad()
        model.batch_size = len(train_labels)
        model.hidden = model.init_hidden()
        output = model(train_inputs)

        loss = loss_function(output, Variable(train_labels))
        loss.backward()
        optimizer.step()
        
        print('[Epoch: %3d/%3d] [data: %d/%d] Training Loss: %.4f'
          % (epoch + 1, EPOCHS, i, len(train_data), loss))

        # calc training acc
        _, predicted = torch.max(output.data, 1)
        total_acc += (predicted == train_labels).sum()
        total += len(train_labels)
        total_loss += loss.item()*len(train_inputs)

    train_loss_.append(total_loss / total)
    train_acc_.append(total_acc.item() / total)
    
    # validation epoch
    total_acc = 0.0
    total_loss = 0.0
    total = 0.0
    i = 0
    model.eval()
    with torch.no_grad():
        while i < len(val_data):
            val_inputs, val_labels = get_batch(val_data, i, BATCH_SIZE)
            i += BATCH_SIZE
            if USE_GPU:
                val_inputs, val_labels = val_inputs.cuda(), val_labels.cuda()

            model.batch_size = len(val_labels)
            model.hidden = model.init_hidden()
            output = model(val_inputs)

            loss = loss_function(output, Variable(val_labels))

            # calc valing acc
            _, predicted = torch.max(output.data, 1)
            total_acc += (predicted == val_labels).sum()
            total += len(val_labels)
            total_loss += loss.item()*len(val_inputs)
    val_loss_.append(total_loss / total)
    val_acc_.append(total_acc.item() / total)
    end_time = time.time()
    if total_acc/total > best_acc:
        best_model = model
    print('[Epoch: %3d/%3d] Training Loss: %.4f, Validation Loss: %.4f,'
          ' Training Acc: %.3f, Validation Acc: %.3f, Time Cost: %.3f s'
          % (epoch + 1, EPOCHS, train_loss_[epoch], val_loss_[epoch],
             train_acc_[epoch], val_acc_[epoch], end_time - start_time))
# Out:
# Start training...
# [Epoch:   1/ 15] [data: 128/31200] Training Loss: 4.6677
# [Epoch:   1/ 15] [data: 256/31200] Training Loss: 4.6522
# [Epoch:   1/ 15] [data: 384/31200] Training Loss: 4.6492
# [Epoch:   1/ 15] [data: 512/31200] Training Loss: 4.6613
# [Epoch:   1/ 15] [data: 640/31200] Training Loss: 4.6094
# [Epoch:   1/ 15] [data: 768/31200] Training Loss: 4.6266
# [Epoch:   1/ 15] [data: 896/31200] Training Loss: 4.6145
# [Epoch:   1/ 15] [data: 1024/31200] Training Loss: 4.5881
# [Epoch:   1/ 15] [data: 1152/31200] Training Loss: 4.6344
# [Epoch:   1/ 15] [data: 1280/31200] Training Loss: 4.6222
# [Epoch:   1/ 15] [data: 1408/31200] Training Loss: 4.5870
# [Epoch:   1/ 15] [data: 1536/31200] Training Loss: 4.5669
# [Epoch:   1/ 15] [data: 1664/31200] Training Loss: 4.5778
# [Epoch:   1/ 15] [data: 1792/31200] Training Loss: 4.5783
# [Epoch:   1/ 15] [data: 1920/31200] Training Loss: 4.5096
# [Epoch:   1/ 15] [data: 2048/31200] Training Loss: 4.5499
# [Epoch:   1/ 15] [data: 2176/31200] Training Loss: 4.5186
# [Epoch:   1/ 15] [data: 2304/31200] Training Loss: 4.5144
# [Epoch:   1/ 15] [data: 2432/31200] Training Loss: 4.5444
# [Epoch:   1/ 15] [data: 2560/31200] Training Loss: 4.5093
# [Epoch:   1/ 15] [data: 2688/31200] Training Loss: 4.4973
# [Epoch:   1/ 15] [data: 2816/31200] Training Loss: 4.4937
# [Epoch:   1/ 15] [data: 2944/31200] Training Loss: 4.4802
# [Epoch:   1/ 15] [data: 3072/31200] Training Loss: 4.4568
# [Epoch:   1/ 15] [data: 3200/31200] Training Loss: 4.3995
# [Epoch:   1/ 15] [data: 3328/31200] Training Loss: 4.4227
# [Epoch:   1/ 15] [data: 3456/31200] Training Loss: 4.4514
# [Epoch:   1/ 15] [data: 3584/31200] Training Loss: 4.4170
# [Epoch:   1/ 15] [data: 3712/31200] Training Loss: 4.4186
# [Epoch:   1/ 15] [data: 3840/31200] Training Loss: 4.4175
# [Epoch:   1/ 15] [data: 3968/31200] Training Loss: 4.4002
# [Epoch:   1/ 15] [data: 4096/31200] Training Loss: 4.2930
# [Epoch:   1/ 15] [data: 4224/31200] Training Loss: 4.3665
# [Epoch:   1/ 15] [data: 4352/31200] Training Loss: 4.3658
# [Epoch:   1/ 15] [data: 4480/31200] Training Loss: 4.2567
# [Epoch:   1/ 15] [data: 4608/31200] Training Loss: 4.3133
# [Epoch:   1/ 15] [data: 4736/31200] Training Loss: 4.3089
# [Epoch:   1/ 15] [data: 4864/31200] Training Loss: 4.3128
# [Epoch:   1/ 15] [data: 4992/31200] Training Loss: 4.2596
# [Epoch:   1/ 15] [data: 5120/31200] Training Loss: 4.3085
# [Epoch:   1/ 15] [data: 5248/31200] Training Loss: 4.2711
# [Epoch:   1/ 15] [data: 5376/31200] Training Loss: 4.2851
# [Epoch:   1/ 15] [data: 5504/31200] Training Loss: 4.2607
# [Epoch:   1/ 15] [data: 5632/31200] Training Loss: 4.2008
# [Epoch:   1/ 15] [data: 5760/31200] Training Loss: 4.2821
# [Epoch:   1/ 15] [data: 5888/31200] Training Loss: 4.2140
# [Epoch:   1/ 15] [data: 6016/31200] Training Loss: 4.1480
# [Epoch:   1/ 15] [data: 6144/31200] Training Loss: 4.1582
# [Epoch:   1/ 15] [data: 6272/31200] Training Loss: 4.1378
# [Epoch:   1/ 15] [data: 6400/31200] Training Loss: 4.0914
# [Epoch:   1/ 15] [data: 6528/31200] Training Loss: 4.1276
# [Epoch:   1/ 15] [data: 6656/31200] Training Loss: 4.0472
# [Epoch:   1/ 15] [data: 6784/31200] Training Loss: 4.0706
# [Epoch:   1/ 15] [data: 6912/31200] Training Loss: 4.0711
# [Epoch:   1/ 15] [data: 7040/31200] Training Loss: 3.9386
# [Epoch:   1/ 15] [data: 7168/31200] Training Loss: 4.1218
# [Epoch:   1/ 15] [data: 7296/31200] Training Loss: 3.9125
# [Epoch:   1/ 15] [data: 7424/31200] Training Loss: 3.9876
# [Epoch:   1/ 15] [data: 7552/31200] Training Loss: 3.8478
# [Epoch:   1/ 15] [data: 7680/31200] Training Loss: 3.9299
# [Epoch:   1/ 15] [data: 7808/31200] Training Loss: 3.9231
# [Epoch:   1/ 15] [data: 7936/31200] Training Loss: 3.9014
# [Epoch:   1/ 15] [data: 8064/31200] Training Loss: 3.8522
# [Epoch:   1/ 15] [data: 8192/31200] Training Loss: 3.8581
# [Epoch:   1/ 15] [data: 8320/31200] Training Loss: 3.8513
# [Epoch:   1/ 15] [data: 8448/31200] Training Loss: 3.8581
# [Epoch:   1/ 15] [data: 8576/31200] Training Loss: 3.7838
# [Epoch:   1/ 15] [data: 8704/31200] Training Loss: 3.8390
# [Epoch:   1/ 15] [data: 8832/31200] Training Loss: 3.7454
# [Epoch:   1/ 15] [data: 8960/31200] Training Loss: 3.7985
# [Epoch:   1/ 15] [data: 9088/31200] Training Loss: 3.7980
# [Epoch:   1/ 15] [data: 9216/31200] Training Loss: 3.7802
# [Epoch:   1/ 15] [data: 9344/31200] Training Loss: 3.6777
# [Epoch:   1/ 15] [data: 9472/31200] Training Loss: 3.7473
# [Epoch:   1/ 15] [data: 9600/31200] Training Loss: 3.6085
# [Epoch:   1/ 15] [data: 9728/31200] Training Loss: 3.6181
# [Epoch:   1/ 15] [data: 9856/31200] Training Loss: 3.5850
# [Epoch:   1/ 15] [data: 9984/31200] Training Loss: 3.5754
# [Epoch:   1/ 15] [data: 10112/31200] Training Loss: 3.5593
# [Epoch:   1/ 15] [data: 10240/31200] Training Loss: 3.5509
# [Epoch:   1/ 15] [data: 10368/31200] Training Loss: 3.4096
# [Epoch:   1/ 15] [data: 10496/31200] Training Loss: 3.4645
# [Epoch:   1/ 15] [data: 10624/31200] Training Loss: 3.4801
# [Epoch:   1/ 15] [data: 10752/31200] Training Loss: 3.4164
# [Epoch:   1/ 15] [data: 10880/31200] Training Loss: 3.4692
# [Epoch:   1/ 15] [data: 11008/31200] Training Loss: 3.4229
# [Epoch:   1/ 15] [data: 11136/31200] Training Loss: 3.5140
# [Epoch:   1/ 15] [data: 11264/31200] Training Loss: 3.4373
# [Epoch:   1/ 15] [data: 11392/31200] Training Loss: 3.3362
# [Epoch:   1/ 15] [data: 11520/31200] Training Loss: 3.3831
# [Epoch:   1/ 15] [data: 11648/31200] Training Loss: 3.3723
# [Epoch:   1/ 15] [data: 11776/31200] Training Loss: 3.4118
# [Epoch:   1/ 15] [data: 11904/31200] Training Loss: 3.3984
# [Epoch:   1/ 15] [data: 12032/31200] Training Loss: 3.2176
# [Epoch:   1/ 15] [data: 12160/31200] Training Loss: 3.2116
# [Epoch:   1/ 15] [data: 12288/31200] Training Loss: 3.2060
# [Epoch:   1/ 15] [data: 12416/31200] Training Loss: 3.2065
# [Epoch:   1/ 15] [data: 12544/31200] Training Loss: 3.2854
# [Epoch:   1/ 15] [data: 12672/31200] Training Loss: 3.2682
# [Epoch:   1/ 15] [data: 12800/31200] Training Loss: 3.2288
# [Epoch:   1/ 15] [data: 12928/31200] Training Loss: 3.1947
# [Epoch:   1/ 15] [data: 13056/31200] Training Loss: 3.0794
# [Epoch:   1/ 15] [data: 13184/31200] Training Loss: 3.1490
# [Epoch:   1/ 15] [data: 13312/31200] Training Loss: 3.1648
# [Epoch:   1/ 15] [data: 13440/31200] Training Loss: 3.0882
# [Epoch:   1/ 15] [data: 13568/31200] Training Loss: 3.1757
# [Epoch:   1/ 15] [data: 13696/31200] Training Loss: 3.0544
# [Epoch:   1/ 15] [data: 13824/31200] Training Loss: 3.0694
# [Epoch:   1/ 15] [data: 13952/31200] Training Loss: 3.0831
# [Epoch:   1/ 15] [data: 14080/31200] Training Loss: 2.9115
# [Epoch:   1/ 15] [data: 14208/31200] Training Loss: 2.9204
# [Epoch:   1/ 15] [data: 14336/31200] Training Loss: 2.8974
# [Epoch:   1/ 15] [data: 14464/31200] Training Loss: 2.9426
# [Epoch:   1/ 15] [data: 14592/31200] Training Loss: 2.9190
# [Epoch:   1/ 15] [data: 14720/31200] Training Loss: 2.9221
# [Epoch:   1/ 15] [data: 14848/31200] Training Loss: 2.8651
# [Epoch:   1/ 15] [data: 14976/31200] Training Loss: 2.7505
# [Epoch:   1/ 15] [data: 15104/31200] Training Loss: 2.8380
# [Epoch:   1/ 15] [data: 15232/31200] Training Loss: 2.8287
# [Epoch:   1/ 15] [data: 15360/31200] Training Loss: 2.7119
# [Epoch:   1/ 15] [data: 15488/31200] Training Loss: 2.6833
# [Epoch:   1/ 15] [data: 15616/31200] Training Loss: 2.8007
# [Epoch:   1/ 15] [data: 15744/31200] Training Loss: 2.7015
# [Epoch:   1/ 15] [data: 15872/31200] Training Loss: 2.6431
# [Epoch:   1/ 15] [data: 16000/31200] Training Loss: 2.7431
# [Epoch:   1/ 15] [data: 16128/31200] Training Loss: 2.8726
# [Epoch:   1/ 15] [data: 16256/31200] Training Loss: 2.6648
# [Epoch:   1/ 15] [data: 16384/31200] Training Loss: 2.5712
# [Epoch:   1/ 15] [data: 16512/31200] Training Loss: 2.7105
# [Epoch:   1/ 15] [data: 16640/31200] Training Loss: 2.5802
# [Epoch:   1/ 15] [data: 16768/31200] Training Loss: 2.6831
# [Epoch:   1/ 15] [data: 16896/31200] Training Loss: 2.5417
# [Epoch:   1/ 15] [data: 17024/31200] Training Loss: 2.5869
# [Epoch:   1/ 15] [data: 17152/31200] Training Loss: 2.4361
# [Epoch:   1/ 15] [data: 17280/31200] Training Loss: 2.4968
# [Epoch:   1/ 15] [data: 17408/31200] Training Loss: 2.4654
# [Epoch:   1/ 15] [data: 17536/31200] Training Loss: 2.3930
# [Epoch:   1/ 15] [data: 17664/31200] Training Loss: 2.4858
# [Epoch:   1/ 15] [data: 17792/31200] Training Loss: 2.5431
# [Epoch:   1/ 15] [data: 17920/31200] Training Loss: 2.4247
# [Epoch:   1/ 15] [data: 18048/31200] Training Loss: 2.4059
# [Epoch:   1/ 15] [data: 18176/31200] Training Loss: 2.2714
# [Epoch:   1/ 15] [data: 18304/31200] Training Loss: 2.2058
# [Epoch:   1/ 15] [data: 18432/31200] Training Loss: 2.3676
# [Epoch:   1/ 15] [data: 18560/31200] Training Loss: 2.2991
# [Epoch:   1/ 15] [data: 18688/31200] Training Loss: 2.4477
# [Epoch:   1/ 15] [data: 18816/31200] Training Loss: 2.2919
# [Epoch:   1/ 15] [data: 18944/31200] Training Loss: 2.3330
# [Epoch:   1/ 15] [data: 19072/31200] Training Loss: 2.3934
# [Epoch:   1/ 15] [data: 19200/31200] Training Loss: 2.3940
# [Epoch:   1/ 15] [data: 19328/31200] Training Loss: 2.2056
# [Epoch:   1/ 15] [data: 19456/31200] Training Loss: 2.2569
# [Epoch:   1/ 15] [data: 19584/31200] Training Loss: 2.2208
# [Epoch:   1/ 15] [data: 19712/31200] Training Loss: 2.1420
# [Epoch:   1/ 15] [data: 19840/31200] Training Loss: 2.2765
# [Epoch:   1/ 15] [data: 19968/31200] Training Loss: 2.2346
# [Epoch:   1/ 15] [data: 20096/31200] Training Loss: 2.1607
# [Epoch:   1/ 15] [data: 20224/31200] Training Loss: 2.1510
# [Epoch:   1/ 15] [data: 20352/31200] Training Loss: 2.2138
# [Epoch:   1/ 15] [data: 20480/31200] Training Loss: 2.1518
# [Epoch:   1/ 15] [data: 20608/31200] Training Loss: 2.1839
# [Epoch:   1/ 15] [data: 20736/31200] Training Loss: 2.0625
# [Epoch:   1/ 15] [data: 20864/31200] Training Loss: 2.3396
# [Epoch:   1/ 15] [data: 20992/31200] Training Loss: 2.1063
# [Epoch:   1/ 15] [data: 21120/31200] Training Loss: 2.0815
# [Epoch:   1/ 15] [data: 21248/31200] Training Loss: 2.0407
# [Epoch:   1/ 15] [data: 21376/31200] Training Loss: 2.1015
# [Epoch:   1/ 15] [data: 21504/31200] Training Loss: 1.9503
# [Epoch:   1/ 15] [data: 21632/31200] Training Loss: 1.9216
# [Epoch:   1/ 15] [data: 21760/31200] Training Loss: 2.0676
# [Epoch:   1/ 15] [data: 21888/31200] Training Loss: 1.9780
# [Epoch:   1/ 15] [data: 22016/31200] Training Loss: 1.9562
# [Epoch:   1/ 15] [data: 22144/31200] Training Loss: 1.9698
# [Epoch:   1/ 15] [data: 22272/31200] Training Loss: 1.8764
# [Epoch:   1/ 15] [data: 22400/31200] Training Loss: 1.9237
# [Epoch:   1/ 15] [data: 22528/31200] Training Loss: 2.1468
# [Epoch:   1/ 15] [data: 22656/31200] Training Loss: 1.8540
# [Epoch:   1/ 15] [data: 22784/31200] Training Loss: 1.9971
# [Epoch:   1/ 15] [data: 22912/31200] Training Loss: 1.9412
# [Epoch:   1/ 15] [data: 23040/31200] Training Loss: 1.8417
# [Epoch:   1/ 15] [data: 23168/31200] Training Loss: 1.8322
# [Epoch:   1/ 15] [data: 23296/31200] Training Loss: 1.8879
# [Epoch:   1/ 15] [data: 23424/31200] Training Loss: 1.8535
# [Epoch:   1/ 15] [data: 23552/31200] Training Loss: 1.9133
# [Epoch:   1/ 15] [data: 23680/31200] Training Loss: 1.7458
# [Epoch:   1/ 15] [data: 23808/31200] Training Loss: 1.8556
# [Epoch:   1/ 15] [data: 23936/31200] Training Loss: 1.8000
# [Epoch:   1/ 15] [data: 24064/31200] Training Loss: 1.8442
# [Epoch:   1/ 15] [data: 24192/31200] Training Loss: 1.7985
# [Epoch:   1/ 15] [data: 24320/31200] Training Loss: 1.7550
# [Epoch:   1/ 15] [data: 24448/31200] Training Loss: 1.7084
# [Epoch:   1/ 15] [data: 24576/31200] Training Loss: 1.7415
# [Epoch:   1/ 15] [data: 24704/31200] Training Loss: 1.7401
# [Epoch:   1/ 15] [data: 24832/31200] Training Loss: 1.6321
# [Epoch:   1/ 15] [data: 24960/31200] Training Loss: 1.8285
# [Epoch:   1/ 15] [data: 25088/31200] Training Loss: 1.6811
# [Epoch:   1/ 15] [data: 25216/31200] Training Loss: 1.8018
# [Epoch:   1/ 15] [data: 25344/31200] Training Loss: 1.6060
# [Epoch:   1/ 15] [data: 25472/31200] Training Loss: 1.7960
# [Epoch:   1/ 15] [data: 25600/31200] Training Loss: 1.6973
# [Epoch:   1/ 15] [data: 25728/31200] Training Loss: 1.5582
# [Epoch:   1/ 15] [data: 25856/31200] Training Loss: 1.7377
# [Epoch:   1/ 15] [data: 25984/31200] Training Loss: 1.7056
# [Epoch:   1/ 15] [data: 26112/31200] Training Loss: 1.6886
# [Epoch:   1/ 15] [data: 26240/31200] Training Loss: 1.7536
# [Epoch:   1/ 15] [data: 26368/31200] Training Loss: 1.6312
# [Epoch:   1/ 15] [data: 26496/31200] Training Loss: 1.5358
# [Epoch:   1/ 15] [data: 26624/31200] Training Loss: 1.6741
# [Epoch:   1/ 15] [data: 26752/31200] Training Loss: 1.5235
# [Epoch:   1/ 15] [data: 26880/31200] Training Loss: 1.4868
# [Epoch:   1/ 15] [data: 27008/31200] Training Loss: 1.5993
# [Epoch:   1/ 15] [data: 27136/31200] Training Loss: 1.4657
# [Epoch:   1/ 15] [data: 27264/31200] Training Loss: 1.5532
# [Epoch:   1/ 15] [data: 27392/31200] Training Loss: 1.5465
# [Epoch:   1/ 15] [data: 27520/31200] Training Loss: 1.4321
# [Epoch:   1/ 15] [data: 27648/31200] Training Loss: 1.4198
# [Epoch:   1/ 15] [data: 27776/31200] Training Loss: 1.5667
# [Epoch:   1/ 15] [data: 27904/31200] Training Loss: 1.3564
# [Epoch:   1/ 15] [data: 28032/31200] Training Loss: 1.5797
# [Epoch:   1/ 15] [data: 28160/31200] Training Loss: 1.5490
# [Epoch:   1/ 15] [data: 28288/31200] Training Loss: 1.4141
# [Epoch:   1/ 15] [data: 28416/31200] Training Loss: 1.3664
# [Epoch:   1/ 15] [data: 28544/31200] Training Loss: 1.4490
# [Epoch:   1/ 15] [data: 28672/31200] Training Loss: 1.3416
# [Epoch:   1/ 15] [data: 28800/31200] Training Loss: 1.4081
# [Epoch:   1/ 15] [data: 28928/31200] Training Loss: 1.4325
# [Epoch:   1/ 15] [data: 29056/31200] Training Loss: 1.3518
# [Epoch:   1/ 15] [data: 29184/31200] Training Loss: 1.5151
# [Epoch:   1/ 15] [data: 29312/31200] Training Loss: 1.3409
# [Epoch:   1/ 15] [data: 29440/31200] Training Loss: 1.5613
# [Epoch:   1/ 15] [data: 29568/31200] Training Loss: 1.2879
# [Epoch:   1/ 15] [data: 29696/31200] Training Loss: 1.3437
# [Epoch:   1/ 15] [data: 29824/31200] Training Loss: 1.3862
# [Epoch:   1/ 15] [data: 29952/31200] Training Loss: 1.4452
# [Epoch:   1/ 15] [data: 30080/31200] Training Loss: 1.3571
# [Epoch:   1/ 15] [data: 30208/31200] Training Loss: 1.3106
# [Epoch:   1/ 15] [data: 30336/31200] Training Loss: 1.3801
# [Epoch:   1/ 15] [data: 30464/31200] Training Loss: 1.2934
# [Epoch:   1/ 15] [data: 30592/31200] Training Loss: 1.2971
# [Epoch:   1/ 15] [data: 30720/31200] Training Loss: 1.3377
# [Epoch:   1/ 15] [data: 30848/31200] Training Loss: 1.2994
# [Epoch:   1/ 15] [data: 30976/31200] Training Loss: 1.3611
# [Epoch:   1/ 15] [data: 31104/31200] Training Loss: 1.3954
# [Epoch:   1/ 15] [data: 31232/31200] Training Loss: 1.3921
# [Epoch:   1/ 15] Training Loss: 2.8740, Validation Loss: 1.3100, Training Acc: 0.493, Validation Acc: 0.820, Time Cost: 1106.895 s
# [Epoch:   2/ 15] [data: 128/31200] Training Loss: 1.2206
# [Epoch:   2/ 15] [data: 256/31200] Training Loss: 1.4596
# [Epoch:   2/ 15] [data: 384/31200] Training Loss: 1.0605
# [Epoch:   2/ 15] [data: 512/31200] Training Loss: 1.2266
# [Epoch:   2/ 15] [data: 640/31200] Training Loss: 1.2391
# [Epoch:   2/ 15] [data: 768/31200] Training Loss: 1.2987
# [Epoch:   2/ 15] [data: 896/31200] Training Loss: 1.2341
# [Epoch:   2/ 15] [data: 1024/31200] Training Loss: 1.3504
# [Epoch:   2/ 15] [data: 1152/31200] Training Loss: 1.3607
# [Epoch:   2/ 15] [data: 1280/31200] Training Loss: 1.3182
# [Epoch:   2/ 15] [data: 1408/31200] Training Loss: 1.1437
# [Epoch:   2/ 15] [data: 1536/31200] Training Loss: 1.2382
# [Epoch:   2/ 15] [data: 1664/31200] Training Loss: 1.1529
# [Epoch:   2/ 15] [data: 1792/31200] Training Loss: 1.2585
# [Epoch:   2/ 15] [data: 1920/31200] Training Loss: 1.1440
# [Epoch:   2/ 15] [data: 2048/31200] Training Loss: 1.2983
# [Epoch:   2/ 15] [data: 2176/31200] Training Loss: 1.1123
# [Epoch:   2/ 15] [data: 2304/31200] Training Loss: 1.0866
# [Epoch:   2/ 15] [data: 2432/31200] Training Loss: 1.1409
# [Epoch:   2/ 15] [data: 2560/31200] Training Loss: 1.1614
# [Epoch:   2/ 15] [data: 2688/31200] Training Loss: 1.1422
# [Epoch:   2/ 15] [data: 2816/31200] Training Loss: 1.1686
# [Epoch:   2/ 15] [data: 2944/31200] Training Loss: 1.2107
# [Epoch:   2/ 15] [data: 3072/31200] Training Loss: 1.1179
# [Epoch:   2/ 15] [data: 3200/31200] Training Loss: 0.9830
# [Epoch:   2/ 15] [data: 3328/31200] Training Loss: 1.2095
# [Epoch:   2/ 15] [data: 3456/31200] Training Loss: 1.1449
# [Epoch:   2/ 15] [data: 3584/31200] Training Loss: 1.0892
# [Epoch:   2/ 15] [data: 3712/31200] Training Loss: 1.1358
# [Epoch:   2/ 15] [data: 3840/31200] Training Loss: 1.0731
# [Epoch:   2/ 15] [data: 3968/31200] Training Loss: 1.0885
# [Epoch:   2/ 15] [data: 4096/31200] Training Loss: 0.9379
# [Epoch:   2/ 15] [data: 4224/31200] Training Loss: 1.0888
# [Epoch:   2/ 15] [data: 4352/31200] Training Loss: 1.1114
# [Epoch:   2/ 15] [data: 4480/31200] Training Loss: 0.9127
# [Epoch:   2/ 15] [data: 4608/31200] Training Loss: 1.0367
# [Epoch:   2/ 15] [data: 4736/31200] Training Loss: 1.0634
# [Epoch:   2/ 15] [data: 4864/31200] Training Loss: 1.0955
# [Epoch:   2/ 15] [data: 4992/31200] Training Loss: 0.9984
# [Epoch:   2/ 15] [data: 5120/31200] Training Loss: 0.9458
# [Epoch:   2/ 15] [data: 5248/31200] Training Loss: 1.0814
# [Epoch:   2/ 15] [data: 5376/31200] Training Loss: 1.0295
# [Epoch:   2/ 15] [data: 5504/31200] Training Loss: 1.0562
# [Epoch:   2/ 15] [data: 5632/31200] Training Loss: 1.0950
# [Epoch:   2/ 15] [data: 5760/31200] Training Loss: 1.0805
# [Epoch:   2/ 15] [data: 5888/31200] Training Loss: 1.0396
# [Epoch:   2/ 15] [data: 6016/31200] Training Loss: 0.9551
# [Epoch:   2/ 15] [data: 6144/31200] Training Loss: 0.9497
# [Epoch:   2/ 15] [data: 6272/31200] Training Loss: 0.9406
# [Epoch:   2/ 15] [data: 6400/31200] Training Loss: 0.8852
# [Epoch:   2/ 15] [data: 6528/31200] Training Loss: 0.9841
# [Epoch:   2/ 15] [data: 6656/31200] Training Loss: 1.0029
# [Epoch:   2/ 15] [data: 6784/31200] Training Loss: 0.9230
# [Epoch:   2/ 15] [data: 6912/31200] Training Loss: 0.9832
# [Epoch:   2/ 15] [data: 7040/31200] Training Loss: 0.9803
# [Epoch:   2/ 15] [data: 7168/31200] Training Loss: 1.0458
# [Epoch:   2/ 15] [data: 7296/31200] Training Loss: 1.0125
# [Epoch:   2/ 15] [data: 7424/31200] Training Loss: 1.0493
# [Epoch:   2/ 15] [data: 7552/31200] Training Loss: 0.8701
# [Epoch:   2/ 15] [data: 7680/31200] Training Loss: 0.8783
# [Epoch:   2/ 15] [data: 7808/31200] Training Loss: 0.8748
# [Epoch:   2/ 15] [data: 7936/31200] Training Loss: 0.9563
# [Epoch:   2/ 15] [data: 8064/31200] Training Loss: 0.9619
# [Epoch:   2/ 15] [data: 8192/31200] Training Loss: 0.9562
# [Epoch:   2/ 15] [data: 8320/31200] Training Loss: 0.9054
# [Epoch:   2/ 15] [data: 8448/31200] Training Loss: 0.9360
# [Epoch:   2/ 15] [data: 8576/31200] Training Loss: 0.7877
# [Epoch:   2/ 15] [data: 8704/31200] Training Loss: 0.8562
# [Epoch:   2/ 15] [data: 8832/31200] Training Loss: 0.8349
# [Epoch:   2/ 15] [data: 8960/31200] Training Loss: 0.9057
# [Epoch:   2/ 15] [data: 9088/31200] Training Loss: 0.9234
# [Epoch:   2/ 15] [data: 9216/31200] Training Loss: 1.0550
# [Epoch:   2/ 15] [data: 9344/31200] Training Loss: 0.9075
# [Epoch:   2/ 15] [data: 9472/31200] Training Loss: 1.0262
# [Epoch:   2/ 15] [data: 9600/31200] Training Loss: 0.8256
# [Epoch:   2/ 15] [data: 9728/31200] Training Loss: 0.7756
# [Epoch:   2/ 15] [data: 9856/31200] Training Loss: 0.8517
# [Epoch:   2/ 15] [data: 9984/31200] Training Loss: 0.9170
# [Epoch:   2/ 15] [data: 10112/31200] Training Loss: 0.8120
# [Epoch:   2/ 15] [data: 10240/31200] Training Loss: 0.7650
# [Epoch:   2/ 15] [data: 10368/31200] Training Loss: 0.7890
# [Epoch:   2/ 15] [data: 10496/31200] Training Loss: 0.8191
# [Epoch:   2/ 15] [data: 10624/31200] Training Loss: 0.8182
# [Epoch:   2/ 15] [data: 10752/31200] Training Loss: 0.8815
# [Epoch:   2/ 15] [data: 10880/31200] Training Loss: 0.8861
# [Epoch:   2/ 15] [data: 11008/31200] Training Loss: 0.8710
# [Epoch:   2/ 15] [data: 11136/31200] Training Loss: 0.8725
# [Epoch:   2/ 15] [data: 11264/31200] Training Loss: 0.9324
# [Epoch:   2/ 15] [data: 11392/31200] Training Loss: 0.8060
# [Epoch:   2/ 15] [data: 11520/31200] Training Loss: 0.9615
# [Epoch:   2/ 15] [data: 11648/31200] Training Loss: 0.7815
# [Epoch:   2/ 15] [data: 11776/31200] Training Loss: 0.8518
# [Epoch:   2/ 15] [data: 11904/31200] Training Loss: 0.7994
# [Epoch:   2/ 15] [data: 12032/31200] Training Loss: 0.8227
# [Epoch:   2/ 15] [data: 12160/31200] Training Loss: 0.8073
# [Epoch:   2/ 15] [data: 12288/31200] Training Loss: 0.7958
# [Epoch:   2/ 15] [data: 12416/31200] Training Loss: 0.7737
# [Epoch:   2/ 15] [data: 12544/31200] Training Loss: 0.7861
# [Epoch:   2/ 15] [data: 12672/31200] Training Loss: 0.7874
# [Epoch:   2/ 15] [data: 12800/31200] Training Loss: 0.8812
# [Epoch:   2/ 15] [data: 12928/31200] Training Loss: 0.8292
# [Epoch:   2/ 15] [data: 13056/31200] Training Loss: 0.7223
# [Epoch:   2/ 15] [data: 13184/31200] Training Loss: 0.7046
# [Epoch:   2/ 15] [data: 13312/31200] Training Loss: 0.8245
# [Epoch:   2/ 15] [data: 13440/31200] Training Loss: 0.8619
# [Epoch:   2/ 15] [data: 13568/31200] Training Loss: 0.8490
# [Epoch:   2/ 15] [data: 13696/31200] Training Loss: 0.7620
# [Epoch:   2/ 15] [data: 13824/31200] Training Loss: 0.8031
# [Epoch:   2/ 15] [data: 13952/31200] Training Loss: 0.7348
# [Epoch:   2/ 15] [data: 14080/31200] Training Loss: 0.6403
# [Epoch:   2/ 15] [data: 14208/31200] Training Loss: 0.7182
# [Epoch:   2/ 15] [data: 14336/31200] Training Loss: 0.7589
# [Epoch:   2/ 15] [data: 14464/31200] Training Loss: 0.7845
# [Epoch:   2/ 15] [data: 14592/31200] Training Loss: 0.6473
# [Epoch:   2/ 15] [data: 14720/31200] Training Loss: 0.7699
# [Epoch:   2/ 15] [data: 14848/31200] Training Loss: 0.7811
# [Epoch:   2/ 15] [data: 14976/31200] Training Loss: 0.6301
# [Epoch:   2/ 15] [data: 15104/31200] Training Loss: 0.7102
# [Epoch:   2/ 15] [data: 15232/31200] Training Loss: 0.8044
# [Epoch:   2/ 15] [data: 15360/31200] Training Loss: 0.6799
# [Epoch:   2/ 15] [data: 15488/31200] Training Loss: 0.6925
# [Epoch:   2/ 15] [data: 15616/31200] Training Loss: 0.7255
# [Epoch:   2/ 15] [data: 15744/31200] Training Loss: 0.7117
# [Epoch:   2/ 15] [data: 15872/31200] Training Loss: 0.6282
# [Epoch:   2/ 15] [data: 16000/31200] Training Loss: 0.6844
# [Epoch:   2/ 15] [data: 16128/31200] Training Loss: 0.7593
# [Epoch:   2/ 15] [data: 16256/31200] Training Loss: 0.6888
# [Epoch:   2/ 15] [data: 16384/31200] Training Loss: 0.6204
# [Epoch:   2/ 15] [data: 16512/31200] Training Loss: 0.7557
# [Epoch:   2/ 15] [data: 16640/31200] Training Loss: 0.6502
# [Epoch:   2/ 15] [data: 16768/31200] Training Loss: 0.7182
# [Epoch:   2/ 15] [data: 16896/31200] Training Loss: 0.5751
# [Epoch:   2/ 15] [data: 17024/31200] Training Loss: 0.6604
# [Epoch:   2/ 15] [data: 17152/31200] Training Loss: 0.5972
# [Epoch:   2/ 15] [data: 17280/31200] Training Loss: 0.6948
# [Epoch:   2/ 15] [data: 17408/31200] Training Loss: 0.6192
# [Epoch:   2/ 15] [data: 17536/31200] Training Loss: 0.5516
# [Epoch:   2/ 15] [data: 17664/31200] Training Loss: 0.6221
# [Epoch:   2/ 15] [data: 17792/31200] Training Loss: 0.7038
# [Epoch:   2/ 15] [data: 17920/31200] Training Loss: 0.7734
# [Epoch:   2/ 15] [data: 18048/31200] Training Loss: 0.6020
# [Epoch:   2/ 15] [data: 18176/31200] Training Loss: 0.5126
# [Epoch:   2/ 15] [data: 18304/31200] Training Loss: 0.5680
# [Epoch:   2/ 15] [data: 18432/31200] Training Loss: 0.7014
# [Epoch:   2/ 15] [data: 18560/31200] Training Loss: 0.6234
# [Epoch:   2/ 15] [data: 18688/31200] Training Loss: 0.7036
# [Epoch:   2/ 15] [data: 18816/31200] Training Loss: 0.5719
# [Epoch:   2/ 15] [data: 18944/31200] Training Loss: 0.7192
# [Epoch:   2/ 15] [data: 19072/31200] Training Loss: 0.6797
# [Epoch:   2/ 15] [data: 19200/31200] Training Loss: 0.6885
# [Epoch:   2/ 15] [data: 19328/31200] Training Loss: 0.6338
# [Epoch:   2/ 15] [data: 19456/31200] Training Loss: 0.6228
# [Epoch:   2/ 15] [data: 19584/31200] Training Loss: 0.6221
# [Epoch:   2/ 15] [data: 19712/31200] Training Loss: 0.6110
# [Epoch:   2/ 15] [data: 19840/31200] Training Loss: 0.6370
# [Epoch:   2/ 15] [data: 19968/31200] Training Loss: 0.5631
# [Epoch:   2/ 15] [data: 20096/31200] Training Loss: 0.6712
# [Epoch:   2/ 15] [data: 20224/31200] Training Loss: 0.6251
# [Epoch:   2/ 15] [data: 20352/31200] Training Loss: 0.6592
# [Epoch:   2/ 15] [data: 20480/31200] Training Loss: 0.5925
# [Epoch:   2/ 15] [data: 20608/31200] Training Loss: 0.6160
# [Epoch:   2/ 15] [data: 20736/31200] Training Loss: 0.5572
# [Epoch:   2/ 15] [data: 20864/31200] Training Loss: 0.6367
# [Epoch:   2/ 15] [data: 20992/31200] Training Loss: 0.5752
# [Epoch:   2/ 15] [data: 21120/31200] Training Loss: 0.5920
# [Epoch:   2/ 15] [data: 21248/31200] Training Loss: 0.5593
# [Epoch:   2/ 15] [data: 21376/31200] Training Loss: 0.5198
# [Epoch:   2/ 15] [data: 21504/31200] Training Loss: 0.4809
# [Epoch:   2/ 15] [data: 21632/31200] Training Loss: 0.5349
# [Epoch:   2/ 15] [data: 21760/31200] Training Loss: 0.6022
# [Epoch:   2/ 15] [data: 21888/31200] Training Loss: 0.6052
# [Epoch:   2/ 15] [data: 22016/31200] Training Loss: 0.5620
# [Epoch:   2/ 15] [data: 22144/31200] Training Loss: 0.5645
# [Epoch:   2/ 15] [data: 22272/31200] Training Loss: 0.5156
# [Epoch:   2/ 15] [data: 22400/31200] Training Loss: 0.6487
# [Epoch:   2/ 15] [data: 22528/31200] Training Loss: 0.7700
# [Epoch:   2/ 15] [data: 22656/31200] Training Loss: 0.6195
# [Epoch:   2/ 15] [data: 22784/31200] Training Loss: 0.5738
# [Epoch:   2/ 15] [data: 22912/31200] Training Loss: 0.5502
# [Epoch:   2/ 15] [data: 23040/31200] Training Loss: 0.5309
# [Epoch:   2/ 15] [data: 23168/31200] Training Loss: 0.5823
# [Epoch:   2/ 15] [data: 23296/31200] Training Loss: 0.5826
# [Epoch:   2/ 15] [data: 23424/31200] Training Loss: 0.5734
# [Epoch:   2/ 15] [data: 23552/31200] Training Loss: 0.6143
# [Epoch:   2/ 15] [data: 23680/31200] Training Loss: 0.5254
# [Epoch:   2/ 15] [data: 23808/31200] Training Loss: 0.5859
# [Epoch:   2/ 15] [data: 23936/31200] Training Loss: 0.5281
# [Epoch:   2/ 15] [data: 24064/31200] Training Loss: 0.6110
# [Epoch:   2/ 15] [data: 24192/31200] Training Loss: 0.5832
# [Epoch:   2/ 15] [data: 24320/31200] Training Loss: 0.5434
# [Epoch:   2/ 15] [data: 24448/31200] Training Loss: 0.4264
# [Epoch:   2/ 15] [data: 24576/31200] Training Loss: 0.5536
# [Epoch:   2/ 15] [data: 24704/31200] Training Loss: 0.5731
# [Epoch:   2/ 15] [data: 24832/31200] Training Loss: 0.4769
# [Epoch:   2/ 15] [data: 24960/31200] Training Loss: 0.6483
# [Epoch:   2/ 15] [data: 25088/31200] Training Loss: 0.4696
# [Epoch:   2/ 15] [data: 25216/31200] Training Loss: 0.5930
# [Epoch:   2/ 15] [data: 25344/31200] Training Loss: 0.4540
# [Epoch:   2/ 15] [data: 25472/31200] Training Loss: 0.5729
# [Epoch:   2/ 15] [data: 25600/31200] Training Loss: 0.5352
# [Epoch:   2/ 15] [data: 25728/31200] Training Loss: 0.4553
# [Epoch:   2/ 15] [data: 25856/31200] Training Loss: 0.5814
# [Epoch:   2/ 15] [data: 25984/31200] Training Loss: 0.5669
# [Epoch:   2/ 15] [data: 26112/31200] Training Loss: 0.5565
# [Epoch:   2/ 15] [data: 26240/31200] Training Loss: 0.5738
# [Epoch:   2/ 15] [data: 26368/31200] Training Loss: 0.5453
# [Epoch:   2/ 15] [data: 26496/31200] Training Loss: 0.4334
# [Epoch:   2/ 15] [data: 26624/31200] Training Loss: 0.5639
# [Epoch:   2/ 15] [data: 26752/31200] Training Loss: 0.4227
# [Epoch:   2/ 15] [data: 26880/31200] Training Loss: 0.4445
# [Epoch:   2/ 15] [data: 27008/31200] Training Loss: 0.5547
# [Epoch:   2/ 15] [data: 27136/31200] Training Loss: 0.4553
# [Epoch:   2/ 15] [data: 27264/31200] Training Loss: 0.4995
# [Epoch:   2/ 15] [data: 27392/31200] Training Loss: 0.5211
# [Epoch:   2/ 15] [data: 27520/31200] Training Loss: 0.4323
# [Epoch:   2/ 15] [data: 27648/31200] Training Loss: 0.4191
# [Epoch:   2/ 15] [data: 27776/31200] Training Loss: 0.4935
# [Epoch:   2/ 15] [data: 27904/31200] Training Loss: 0.4011
# [Epoch:   2/ 15] [data: 28032/31200] Training Loss: 0.5285
# [Epoch:   2/ 15] [data: 28160/31200] Training Loss: 0.5225
# [Epoch:   2/ 15] [data: 28288/31200] Training Loss: 0.4257
# [Epoch:   2/ 15] [data: 28416/31200] Training Loss: 0.3994
# [Epoch:   2/ 15] [data: 28544/31200] Training Loss: 0.4693
# [Epoch:   2/ 15] [data: 28672/31200] Training Loss: 0.4194
# [Epoch:   2/ 15] [data: 28800/31200] Training Loss: 0.4806
# [Epoch:   2/ 15] [data: 28928/31200] Training Loss: 0.4739
# [Epoch:   2/ 15] [data: 29056/31200] Training Loss: 0.4511
# [Epoch:   2/ 15] [data: 29184/31200] Training Loss: 0.5463
# [Epoch:   2/ 15] [data: 29312/31200] Training Loss: 0.4154
# [Epoch:   2/ 15] [data: 29440/31200] Training Loss: 0.5234
# [Epoch:   2/ 15] [data: 29568/31200] Training Loss: 0.4232
# [Epoch:   2/ 15] [data: 29696/31200] Training Loss: 0.4710
# [Epoch:   2/ 15] [data: 29824/31200] Training Loss: 0.4687
# [Epoch:   2/ 15] [data: 29952/31200] Training Loss: 0.5055
# [Epoch:   2/ 15] [data: 30080/31200] Training Loss: 0.4719
# [Epoch:   2/ 15] [data: 30208/31200] Training Loss: 0.4329
# [Epoch:   2/ 15] [data: 30336/31200] Training Loss: 0.4655
# [Epoch:   2/ 15] [data: 30464/31200] Training Loss: 0.3964
# [Epoch:   2/ 15] [data: 30592/31200] Training Loss: 0.4234
# [Epoch:   2/ 15] [data: 30720/31200] Training Loss: 0.4059
# [Epoch:   2/ 15] [data: 30848/31200] Training Loss: 0.4603
# [Epoch:   2/ 15] [data: 30976/31200] Training Loss: 0.4365
# [Epoch:   2/ 15] [data: 31104/31200] Training Loss: 0.5280
# [Epoch:   2/ 15] [data: 31232/31200] Training Loss: 0.4928
# [Epoch:   2/ 15] Training Loss: 0.7590, Validation Loss: 0.4668, Training Acc: 0.891, Validation Acc: 0.926, Time Cost: 1129.727 s
# [Epoch:   3/ 15] [data: 128/31200] Training Loss: 0.3664
# [Epoch:   3/ 15] [data: 256/31200] Training Loss: 0.5507
# [Epoch:   3/ 15] [data: 384/31200] Training Loss: 0.3213
# [Epoch:   3/ 15] [data: 512/31200] Training Loss: 0.4270
# [Epoch:   3/ 15] [data: 640/31200] Training Loss: 0.4498
# [Epoch:   3/ 15] [data: 768/31200] Training Loss: 0.4646
# [Epoch:   3/ 15] [data: 896/31200] Training Loss: 0.3995
# [Epoch:   3/ 15] [data: 1024/31200] Training Loss: 0.5232
# [Epoch:   3/ 15] [data: 1152/31200] Training Loss: 0.5820
# [Epoch:   3/ 15] [data: 1280/31200] Training Loss: 0.4430
# [Epoch:   3/ 15] [data: 1408/31200] Training Loss: 0.4152
# [Epoch:   3/ 15] [data: 1536/31200] Training Loss: 0.4678
# [Epoch:   3/ 15] [data: 1664/31200] Training Loss: 0.4076
# [Epoch:   3/ 15] [data: 1792/31200] Training Loss: 0.4559
# [Epoch:   3/ 15] [data: 1920/31200] Training Loss: 0.4572
# [Epoch:   3/ 15] [data: 2048/31200] Training Loss: 0.5524
# [Epoch:   3/ 15] [data: 2176/31200] Training Loss: 0.3827
# [Epoch:   3/ 15] [data: 2304/31200] Training Loss: 0.4163
# [Epoch:   3/ 15] [data: 2432/31200] Training Loss: 0.3981
# [Epoch:   3/ 15] [data: 2560/31200] Training Loss: 0.4152
# [Epoch:   3/ 15] [data: 2688/31200] Training Loss: 0.3899
# [Epoch:   3/ 15] [data: 2816/31200] Training Loss: 0.4199
# [Epoch:   3/ 15] [data: 2944/31200] Training Loss: 0.4652
# [Epoch:   3/ 15] [data: 3072/31200] Training Loss: 0.3921
# [Epoch:   3/ 15] [data: 3200/31200] Training Loss: 0.2983
# [Epoch:   3/ 15] [data: 3328/31200] Training Loss: 0.4365
# [Epoch:   3/ 15] [data: 3456/31200] Training Loss: 0.3786
# [Epoch:   3/ 15] [data: 3584/31200] Training Loss: 0.4173
# [Epoch:   3/ 15] [data: 3712/31200] Training Loss: 0.4787
# [Epoch:   3/ 15] [data: 3840/31200] Training Loss: 0.3923
# [Epoch:   3/ 15] [data: 3968/31200] Training Loss: 0.3708
# [Epoch:   3/ 15] [data: 4096/31200] Training Loss: 0.3457
# [Epoch:   3/ 15] [data: 4224/31200] Training Loss: 0.3601
# [Epoch:   3/ 15] [data: 4352/31200] Training Loss: 0.4048
# [Epoch:   3/ 15] [data: 4480/31200] Training Loss: 0.3458
# [Epoch:   3/ 15] [data: 4608/31200] Training Loss: 0.3912
# [Epoch:   3/ 15] [data: 4736/31200] Training Loss: 0.4008
# [Epoch:   3/ 15] [data: 4864/31200] Training Loss: 0.4213
# [Epoch:   3/ 15] [data: 4992/31200] Training Loss: 0.4035
# [Epoch:   3/ 15] [data: 5120/31200] Training Loss: 0.3403
# [Epoch:   3/ 15] [data: 5248/31200] Training Loss: 0.3858
# [Epoch:   3/ 15] [data: 5376/31200] Training Loss: 0.3663
# [Epoch:   3/ 15] [data: 5504/31200] Training Loss: 0.4199
# [Epoch:   3/ 15] [data: 5632/31200] Training Loss: 0.4273
# [Epoch:   3/ 15] [data: 5760/31200] Training Loss: 0.4059
# [Epoch:   3/ 15] [data: 5888/31200] Training Loss: 0.3682
# [Epoch:   3/ 15] [data: 6016/31200] Training Loss: 0.3305
# [Epoch:   3/ 15] [data: 6144/31200] Training Loss: 0.3452
# [Epoch:   3/ 15] [data: 6272/31200] Training Loss: 0.3349
# [Epoch:   3/ 15] [data: 6400/31200] Training Loss: 0.2971
# [Epoch:   3/ 15] [data: 6528/31200] Training Loss: 0.3870
# [Epoch:   3/ 15] [data: 6656/31200] Training Loss: 0.3895
# [Epoch:   3/ 15] [data: 6784/31200] Training Loss: 0.3490
# [Epoch:   3/ 15] [data: 6912/31200] Training Loss: 0.3753
# [Epoch:   3/ 15] [data: 7040/31200] Training Loss: 0.3799
# [Epoch:   3/ 15] [data: 7168/31200] Training Loss: 0.4625
# [Epoch:   3/ 15] [data: 7296/31200] Training Loss: 0.4583
# [Epoch:   3/ 15] [data: 7424/31200] Training Loss: 0.4133
# [Epoch:   3/ 15] [data: 7552/31200] Training Loss: 0.3172
# [Epoch:   3/ 15] [data: 7680/31200] Training Loss: 0.3518
# [Epoch:   3/ 15] [data: 7808/31200] Training Loss: 0.3564
# [Epoch:   3/ 15] [data: 7936/31200] Training Loss: 0.4062
# [Epoch:   3/ 15] [data: 8064/31200] Training Loss: 0.3564
# [Epoch:   3/ 15] [data: 8192/31200] Training Loss: 0.3715
# [Epoch:   3/ 15] [data: 8320/31200] Training Loss: 0.3341
# [Epoch:   3/ 15] [data: 8448/31200] Training Loss: 0.3727
# [Epoch:   3/ 15] [data: 8576/31200] Training Loss: 0.3132
# [Epoch:   3/ 15] [data: 8704/31200] Training Loss: 0.3098
# [Epoch:   3/ 15] [data: 8832/31200] Training Loss: 0.3199
# [Epoch:   3/ 15] [data: 8960/31200] Training Loss: 0.3428
# [Epoch:   3/ 15] [data: 9088/31200] Training Loss: 0.3658
# [Epoch:   3/ 15] [data: 9216/31200] Training Loss: 0.4865
# [Epoch:   3/ 15] [data: 9344/31200] Training Loss: 0.4016
# [Epoch:   3/ 15] [data: 9472/31200] Training Loss: 0.3827
# [Epoch:   3/ 15] [data: 9600/31200] Training Loss: 0.3368
# [Epoch:   3/ 15] [data: 9728/31200] Training Loss: 0.2818
# [Epoch:   3/ 15] [data: 9856/31200] Training Loss: 0.3494
# [Epoch:   3/ 15] [data: 9984/31200] Training Loss: 0.3793
# [Epoch:   3/ 15] [data: 10112/31200] Training Loss: 0.3356
# [Epoch:   3/ 15] [data: 10240/31200] Training Loss: 0.2709
# [Epoch:   3/ 15] [data: 10368/31200] Training Loss: 0.3280
# [Epoch:   3/ 15] [data: 10496/31200] Training Loss: 0.2913
# [Epoch:   3/ 15] [data: 10624/31200] Training Loss: 0.3203
# [Epoch:   3/ 15] [data: 10752/31200] Training Loss: 0.4100
# [Epoch:   3/ 15] [data: 10880/31200] Training Loss: 0.3740
# [Epoch:   3/ 15] [data: 11008/31200] Training Loss: 0.3649
# [Epoch:   3/ 15] [data: 11136/31200] Training Loss: 0.3455
# [Epoch:   3/ 15] [data: 11264/31200] Training Loss: 0.3729
# [Epoch:   3/ 15] [data: 11392/31200] Training Loss: 0.3369
# [Epoch:   3/ 15] [data: 11520/31200] Training Loss: 0.4309
# [Epoch:   3/ 15] [data: 11648/31200] Training Loss: 0.3086
# [Epoch:   3/ 15] [data: 11776/31200] Training Loss: 0.3264
# [Epoch:   3/ 15] [data: 11904/31200] Training Loss: 0.3129
# [Epoch:   3/ 15] [data: 12032/31200] Training Loss: 0.3747
# [Epoch:   3/ 15] [data: 12160/31200] Training Loss: 0.3594
# [Epoch:   3/ 15] [data: 12288/31200] Training Loss: 0.3424
# [Epoch:   3/ 15] [data: 12416/31200] Training Loss: 0.3020
# [Epoch:   3/ 15] [data: 12544/31200] Training Loss: 0.3182
# [Epoch:   3/ 15] [data: 12672/31200] Training Loss: 0.3253
# [Epoch:   3/ 15] [data: 12800/31200] Training Loss: 0.3728
# [Epoch:   3/ 15] [data: 12928/31200] Training Loss: 0.3486
# [Epoch:   3/ 15] [data: 13056/31200] Training Loss: 0.3029
# [Epoch:   3/ 15] [data: 13184/31200] Training Loss: 0.2763
# [Epoch:   3/ 15] [data: 13312/31200] Training Loss: 0.3473
# [Epoch:   3/ 15] [data: 13440/31200] Training Loss: 0.4546
# [Epoch:   3/ 15] [data: 13568/31200] Training Loss: 0.3560
# [Epoch:   3/ 15] [data: 13696/31200] Training Loss: 0.3278
# [Epoch:   3/ 15] [data: 13824/31200] Training Loss: 0.3406
# [Epoch:   3/ 15] [data: 13952/31200] Training Loss: 0.3129
# [Epoch:   3/ 15] [data: 14080/31200] Training Loss: 0.2309
# [Epoch:   3/ 15] [data: 14208/31200] Training Loss: 0.3040
# [Epoch:   3/ 15] [data: 14336/31200] Training Loss: 0.3507
# [Epoch:   3/ 15] [data: 14464/31200] Training Loss: 0.3152
# [Epoch:   3/ 15] [data: 14592/31200] Training Loss: 0.2469
# [Epoch:   3/ 15] [data: 14720/31200] Training Loss: 0.3488
# [Epoch:   3/ 15] [data: 14848/31200] Training Loss: 0.3550
# [Epoch:   3/ 15] [data: 14976/31200] Training Loss: 0.2629
# [Epoch:   3/ 15] [data: 15104/31200] Training Loss: 0.3519
# [Epoch:   3/ 15] [data: 15232/31200] Training Loss: 0.3827
# [Epoch:   3/ 15] [data: 15360/31200] Training Loss: 0.3040
# [Epoch:   3/ 15] [data: 15488/31200] Training Loss: 0.2966
# [Epoch:   3/ 15] [data: 15616/31200] Training Loss: 0.3200
# [Epoch:   3/ 15] [data: 15744/31200] Training Loss: 0.2907
# [Epoch:   3/ 15] [data: 15872/31200] Training Loss: 0.2496
# [Epoch:   3/ 15] [data: 16000/31200] Training Loss: 0.3032
# [Epoch:   3/ 15] [data: 16128/31200] Training Loss: 0.3321
# [Epoch:   3/ 15] [data: 16256/31200] Training Loss: 0.2936
# [Epoch:   3/ 15] [data: 16384/31200] Training Loss: 0.2675
# [Epoch:   3/ 15] [data: 16512/31200] Training Loss: 0.3325
# [Epoch:   3/ 15] [data: 16640/31200] Training Loss: 0.3006
# [Epoch:   3/ 15] [data: 16768/31200] Training Loss: 0.3239
# [Epoch:   3/ 15] [data: 16896/31200] Training Loss: 0.2181
# [Epoch:   3/ 15] [data: 17024/31200] Training Loss: 0.2897
# [Epoch:   3/ 15] [data: 17152/31200] Training Loss: 0.2410
# [Epoch:   3/ 15] [data: 17280/31200] Training Loss: 0.3356
# [Epoch:   3/ 15] [data: 17408/31200] Training Loss: 0.2685
# [Epoch:   3/ 15] [data: 17536/31200] Training Loss: 0.2393
# [Epoch:   3/ 15] [data: 17664/31200] Training Loss: 0.2569
# [Epoch:   3/ 15] [data: 17792/31200] Training Loss: 0.3160
# [Epoch:   3/ 15] [data: 17920/31200] Training Loss: 0.3929
# [Epoch:   3/ 15] [data: 18048/31200] Training Loss: 0.2627
# [Epoch:   3/ 15] [data: 18176/31200] Training Loss: 0.2176
# [Epoch:   3/ 15] [data: 18304/31200] Training Loss: 0.2487
# [Epoch:   3/ 15] [data: 18432/31200] Training Loss: 0.3046
# [Epoch:   3/ 15] [data: 18560/31200] Training Loss: 0.2740
# [Epoch:   3/ 15] [data: 18688/31200] Training Loss: 0.3303
# [Epoch:   3/ 15] [data: 18816/31200] Training Loss: 0.2467
# [Epoch:   3/ 15] [data: 18944/31200] Training Loss: 0.3520
# [Epoch:   3/ 15] [data: 19072/31200] Training Loss: 0.3488
# [Epoch:   3/ 15] [data: 19200/31200] Training Loss: 0.3300
# [Epoch:   3/ 15] [data: 19328/31200] Training Loss: 0.2971
# [Epoch:   3/ 15] [data: 19456/31200] Training Loss: 0.3036
# [Epoch:   3/ 15] [data: 19584/31200] Training Loss: 0.2455
# [Epoch:   3/ 15] [data: 19712/31200] Training Loss: 0.2750
# [Epoch:   3/ 15] [data: 19840/31200] Training Loss: 0.2993
# [Epoch:   3/ 15] [data: 19968/31200] Training Loss: 0.2605
# [Epoch:   3/ 15] [data: 20096/31200] Training Loss: 0.3715
# [Epoch:   3/ 15] [data: 20224/31200] Training Loss: 0.2823
# [Epoch:   3/ 15] [data: 20352/31200] Training Loss: 0.3033
# [Epoch:   3/ 15] [data: 20480/31200] Training Loss: 0.2467
# [Epoch:   3/ 15] [data: 20608/31200] Training Loss: 0.3147
# [Epoch:   3/ 15] [data: 20736/31200] Training Loss: 0.2590
# [Epoch:   3/ 15] [data: 20864/31200] Training Loss: 0.2934
# [Epoch:   3/ 15] [data: 20992/31200] Training Loss: 0.2402
# [Epoch:   3/ 15] [data: 21120/31200] Training Loss: 0.2625
# [Epoch:   3/ 15] [data: 21248/31200] Training Loss: 0.2325
# [Epoch:   3/ 15] [data: 21376/31200] Training Loss: 0.1980
# [Epoch:   3/ 15] [data: 21504/31200] Training Loss: 0.2061
# [Epoch:   3/ 15] [data: 21632/31200] Training Loss: 0.2467
# [Epoch:   3/ 15] [data: 21760/31200] Training Loss: 0.3060
# [Epoch:   3/ 15] [data: 21888/31200] Training Loss: 0.2974
# [Epoch:   3/ 15] [data: 22016/31200] Training Loss: 0.2818
# [Epoch:   3/ 15] [data: 22144/31200] Training Loss: 0.2802
# [Epoch:   3/ 15] [data: 22272/31200] Training Loss: 0.2263
# [Epoch:   3/ 15] [data: 22400/31200] Training Loss: 0.3241
# [Epoch:   3/ 15] [data: 22528/31200] Training Loss: 0.4050
# [Epoch:   3/ 15] [data: 22656/31200] Training Loss: 0.3090
# [Epoch:   3/ 15] [data: 22784/31200] Training Loss: 0.2880
# [Epoch:   3/ 15] [data: 22912/31200] Training Loss: 0.2753
# [Epoch:   3/ 15] [data: 23040/31200] Training Loss: 0.2435
# [Epoch:   3/ 15] [data: 23168/31200] Training Loss: 0.2735
# [Epoch:   3/ 15] [data: 23296/31200] Training Loss: 0.3007
# [Epoch:   3/ 15] [data: 23424/31200] Training Loss: 0.2886
# [Epoch:   3/ 15] [data: 23552/31200] Training Loss: 0.3069
# [Epoch:   3/ 15] [data: 23680/31200] Training Loss: 0.2709
# [Epoch:   3/ 15] [data: 23808/31200] Training Loss: 0.2974
# [Epoch:   3/ 15] [data: 23936/31200] Training Loss: 0.2467
# [Epoch:   3/ 15] [data: 24064/31200] Training Loss: 0.3207
# [Epoch:   3/ 15] [data: 24192/31200] Training Loss: 0.2993
# [Epoch:   3/ 15] [data: 24320/31200] Training Loss: 0.2729
# [Epoch:   3/ 15] [data: 24448/31200] Training Loss: 0.1795
# [Epoch:   3/ 15] [data: 24576/31200] Training Loss: 0.2703
# [Epoch:   3/ 15] [data: 24704/31200] Training Loss: 0.3003
# [Epoch:   3/ 15] [data: 24832/31200] Training Loss: 0.2273
# [Epoch:   3/ 15] [data: 24960/31200] Training Loss: 0.3657
# [Epoch:   3/ 15] [data: 25088/31200] Training Loss: 0.2272
# [Epoch:   3/ 15] [data: 25216/31200] Training Loss: 0.3015
# [Epoch:   3/ 15] [data: 25344/31200] Training Loss: 0.2232
# [Epoch:   3/ 15] [data: 25472/31200] Training Loss: 0.3117
# [Epoch:   3/ 15] [data: 25600/31200] Training Loss: 0.2851
# [Epoch:   3/ 15] [data: 25728/31200] Training Loss: 0.2144
# [Epoch:   3/ 15] [data: 25856/31200] Training Loss: 0.3184
# [Epoch:   3/ 15] [data: 25984/31200] Training Loss: 0.2847
# [Epoch:   3/ 15] [data: 26112/31200] Training Loss: 0.2800
# [Epoch:   3/ 15] [data: 26240/31200] Training Loss: 0.3231
# [Epoch:   3/ 15] [data: 26368/31200] Training Loss: 0.2848
# [Epoch:   3/ 15] [data: 26496/31200] Training Loss: 0.2210
# [Epoch:   3/ 15] [data: 26624/31200] Training Loss: 0.3253
# [Epoch:   3/ 15] [data: 26752/31200] Training Loss: 0.1789
# [Epoch:   3/ 15] [data: 26880/31200] Training Loss: 0.2173
# [Epoch:   3/ 15] [data: 27008/31200] Training Loss: 0.2644
# [Epoch:   3/ 15] [data: 27136/31200] Training Loss: 0.2293
# [Epoch:   3/ 15] [data: 27264/31200] Training Loss: 0.2592
# [Epoch:   3/ 15] [data: 27392/31200] Training Loss: 0.2840
# [Epoch:   3/ 15] [data: 27520/31200] Training Loss: 0.2001
# [Epoch:   3/ 15] [data: 27648/31200] Training Loss: 0.1976
# [Epoch:   3/ 15] [data: 27776/31200] Training Loss: 0.2326
# [Epoch:   3/ 15] [data: 27904/31200] Training Loss: 0.1932
# [Epoch:   3/ 15] [data: 28032/31200] Training Loss: 0.2632
# [Epoch:   3/ 15] [data: 28160/31200] Training Loss: 0.2671
# [Epoch:   3/ 15] [data: 28288/31200] Training Loss: 0.2032
# [Epoch:   3/ 15] [data: 28416/31200] Training Loss: 0.2040
# [Epoch:   3/ 15] [data: 28544/31200] Training Loss: 0.2207
# [Epoch:   3/ 15] [data: 28672/31200] Training Loss: 0.1975
# [Epoch:   3/ 15] [data: 28800/31200] Training Loss: 0.2413
# [Epoch:   3/ 15] [data: 28928/31200] Training Loss: 0.2371
# [Epoch:   3/ 15] [data: 29056/31200] Training Loss: 0.2358
# [Epoch:   3/ 15] [data: 29184/31200] Training Loss: 0.3107
# [Epoch:   3/ 15] [data: 29312/31200] Training Loss: 0.2003
# [Epoch:   3/ 15] [data: 29440/31200] Training Loss: 0.2921
# [Epoch:   3/ 15] [data: 29568/31200] Training Loss: 0.2218
# [Epoch:   3/ 15] [data: 29696/31200] Training Loss: 0.2455
# [Epoch:   3/ 15] [data: 29824/31200] Training Loss: 0.2372
# [Epoch:   3/ 15] [data: 29952/31200] Training Loss: 0.2800
# [Epoch:   3/ 15] [data: 30080/31200] Training Loss: 0.2433
# [Epoch:   3/ 15] [data: 30208/31200] Training Loss: 0.2269
# [Epoch:   3/ 15] [data: 30336/31200] Training Loss: 0.2430
# [Epoch:   3/ 15] [data: 30464/31200] Training Loss: 0.1984
# [Epoch:   3/ 15] [data: 30592/31200] Training Loss: 0.2060
# [Epoch:   3/ 15] [data: 30720/31200] Training Loss: 0.1933
# [Epoch:   3/ 15] [data: 30848/31200] Training Loss: 0.2530
# [Epoch:   3/ 15] [data: 30976/31200] Training Loss: 0.2025
# [Epoch:   3/ 15] [data: 31104/31200] Training Loss: 0.3029
# [Epoch:   3/ 15] [data: 31232/31200] Training Loss: 0.2579
# [Epoch:   3/ 15] Training Loss: 0.3207, Validation Loss: 0.2663, Training Acc: 0.948, Validation Acc: 0.949, Time Cost: 1138.359 s
# [Epoch:   4/ 15] [data: 128/31200] Training Loss: 0.1884
# [Epoch:   4/ 15] [data: 256/31200] Training Loss: 0.3320
# [Epoch:   4/ 15] [data: 384/31200] Training Loss: 0.1580
# [Epoch:   4/ 15] [data: 512/31200] Training Loss: 0.2118
# [Epoch:   4/ 15] [data: 640/31200] Training Loss: 0.2405
# [Epoch:   4/ 15] [data: 768/31200] Training Loss: 0.2451
# [Epoch:   4/ 15] [data: 896/31200] Training Loss: 0.2072
# [Epoch:   4/ 15] [data: 1024/31200] Training Loss: 0.3112
# [Epoch:   4/ 15] [data: 1152/31200] Training Loss: 0.3469
# [Epoch:   4/ 15] [data: 1280/31200] Training Loss: 0.2306
# [Epoch:   4/ 15] [data: 1408/31200] Training Loss: 0.2299
# [Epoch:   4/ 15] [data: 1536/31200] Training Loss: 0.2827
# [Epoch:   4/ 15] [data: 1664/31200] Training Loss: 0.2261
# [Epoch:   4/ 15] [data: 1792/31200] Training Loss: 0.2332
# [Epoch:   4/ 15] [data: 1920/31200] Training Loss: 0.2819
# [Epoch:   4/ 15] [data: 2048/31200] Training Loss: 0.3508
# [Epoch:   4/ 15] [data: 2176/31200] Training Loss: 0.1960
# [Epoch:   4/ 15] [data: 2304/31200] Training Loss: 0.2162
# [Epoch:   4/ 15] [data: 2432/31200] Training Loss: 0.1990
# [Epoch:   4/ 15] [data: 2560/31200] Training Loss: 0.2333
# [Epoch:   4/ 15] [data: 2688/31200] Training Loss: 0.1929
# [Epoch:   4/ 15] [data: 2816/31200] Training Loss: 0.2351
# [Epoch:   4/ 15] [data: 2944/31200] Training Loss: 0.2711
# [Epoch:   4/ 15] [data: 3072/31200] Training Loss: 0.2112
# [Epoch:   4/ 15] [data: 3200/31200] Training Loss: 0.1442
# [Epoch:   4/ 15] [data: 3328/31200] Training Loss: 0.2384
# [Epoch:   4/ 15] [data: 3456/31200] Training Loss: 0.1877
# [Epoch:   4/ 15] [data: 3584/31200] Training Loss: 0.2429
# [Epoch:   4/ 15] [data: 3712/31200] Training Loss: 0.2842
# [Epoch:   4/ 15] [data: 3840/31200] Training Loss: 0.2330
# [Epoch:   4/ 15] [data: 3968/31200] Training Loss: 0.1955
# [Epoch:   4/ 15] [data: 4096/31200] Training Loss: 0.1876
# [Epoch:   4/ 15] [data: 4224/31200] Training Loss: 0.1811
# [Epoch:   4/ 15] [data: 4352/31200] Training Loss: 0.2140
# [Epoch:   4/ 15] [data: 4480/31200] Training Loss: 0.1977
# [Epoch:   4/ 15] [data: 4608/31200] Training Loss: 0.2177
# [Epoch:   4/ 15] [data: 4736/31200] Training Loss: 0.2267
# [Epoch:   4/ 15] [data: 4864/31200] Training Loss: 0.2291
# [Epoch:   4/ 15] [data: 4992/31200] Training Loss: 0.2486
# [Epoch:   4/ 15] [data: 5120/31200] Training Loss: 0.1918
# [Epoch:   4/ 15] [data: 5248/31200] Training Loss: 0.1953
# [Epoch:   4/ 15] [data: 5376/31200] Training Loss: 0.1986
# [Epoch:   4/ 15] [data: 5504/31200] Training Loss: 0.2518
# [Epoch:   4/ 15] [data: 5632/31200] Training Loss: 0.2665
# [Epoch:   4/ 15] [data: 5760/31200] Training Loss: 0.2346
# [Epoch:   4/ 15] [data: 5888/31200] Training Loss: 0.1941
# [Epoch:   4/ 15] [data: 6016/31200] Training Loss: 0.1645
# [Epoch:   4/ 15] [data: 6144/31200] Training Loss: 0.1800
# [Epoch:   4/ 15] [data: 6272/31200] Training Loss: 0.1898
# [Epoch:   4/ 15] [data: 6400/31200] Training Loss: 0.1402
# [Epoch:   4/ 15] [data: 6528/31200] Training Loss: 0.2316
# [Epoch:   4/ 15] [data: 6656/31200] Training Loss: 0.2153
# [Epoch:   4/ 15] [data: 6784/31200] Training Loss: 0.1971
# [Epoch:   4/ 15] [data: 6912/31200] Training Loss: 0.2123
# [Epoch:   4/ 15] [data: 7040/31200] Training Loss: 0.2035
# [Epoch:   4/ 15] [data: 7168/31200] Training Loss: 0.2932
# [Epoch:   4/ 15] [data: 7296/31200] Training Loss: 0.3084
# [Epoch:   4/ 15] [data: 7424/31200] Training Loss: 0.2230
# [Epoch:   4/ 15] [data: 7552/31200] Training Loss: 0.1742
# [Epoch:   4/ 15] [data: 7680/31200] Training Loss: 0.1934
# [Epoch:   4/ 15] [data: 7808/31200] Training Loss: 0.2134
# [Epoch:   4/ 15] [data: 7936/31200] Training Loss: 0.2473
# [Epoch:   4/ 15] [data: 8064/31200] Training Loss: 0.1741
# [Epoch:   4/ 15] [data: 8192/31200] Training Loss: 0.2038
# [Epoch:   4/ 15] [data: 8320/31200] Training Loss: 0.1656
# [Epoch:   4/ 15] [data: 8448/31200] Training Loss: 0.2051
# [Epoch:   4/ 15] [data: 8576/31200] Training Loss: 0.1857
# [Epoch:   4/ 15] [data: 8704/31200] Training Loss: 0.1700
# [Epoch:   4/ 15] [data: 8832/31200] Training Loss: 0.1654
# [Epoch:   4/ 15] [data: 8960/31200] Training Loss: 0.1844
# [Epoch:   4/ 15] [data: 9088/31200] Training Loss: 0.1995
# [Epoch:   4/ 15] [data: 9216/31200] Training Loss: 0.2994
# [Epoch:   4/ 15] [data: 9344/31200] Training Loss: 0.2454
# [Epoch:   4/ 15] [data: 9472/31200] Training Loss: 0.2113
# [Epoch:   4/ 15] [data: 9600/31200] Training Loss: 0.1912
# [Epoch:   4/ 15] [data: 9728/31200] Training Loss: 0.1553
# [Epoch:   4/ 15] [data: 9856/31200] Training Loss: 0.2070
# [Epoch:   4/ 15] [data: 9984/31200] Training Loss: 0.2099
# [Epoch:   4/ 15] [data: 10112/31200] Training Loss: 0.2046
# [Epoch:   4/ 15] [data: 10240/31200] Training Loss: 0.1272
# [Epoch:   4/ 15] [data: 10368/31200] Training Loss: 0.1969
# [Epoch:   4/ 15] [data: 10496/31200] Training Loss: 0.1381
# [Epoch:   4/ 15] [data: 10624/31200] Training Loss: 0.1830
# [Epoch:   4/ 15] [data: 10752/31200] Training Loss: 0.2640
# [Epoch:   4/ 15] [data: 10880/31200] Training Loss: 0.2019
# [Epoch:   4/ 15] [data: 11008/31200] Training Loss: 0.2069
# [Epoch:   4/ 15] [data: 11136/31200] Training Loss: 0.1986
# [Epoch:   4/ 15] [data: 11264/31200] Training Loss: 0.2053
# [Epoch:   4/ 15] [data: 11392/31200] Training Loss: 0.2050
# [Epoch:   4/ 15] [data: 11520/31200] Training Loss: 0.2697
# [Epoch:   4/ 15] [data: 11648/31200] Training Loss: 0.1662
# [Epoch:   4/ 15] [data: 11776/31200] Training Loss: 0.1638
# [Epoch:   4/ 15] [data: 11904/31200] Training Loss: 0.1678
# [Epoch:   4/ 15] [data: 12032/31200] Training Loss: 0.2403
# [Epoch:   4/ 15] [data: 12160/31200] Training Loss: 0.2286
# [Epoch:   4/ 15] [data: 12288/31200] Training Loss: 0.2178
# [Epoch:   4/ 15] [data: 12416/31200] Training Loss: 0.1656
# [Epoch:   4/ 15] [data: 12544/31200] Training Loss: 0.1758
# [Epoch:   4/ 15] [data: 12672/31200] Training Loss: 0.1800
# [Epoch:   4/ 15] [data: 12800/31200] Training Loss: 0.2308
# [Epoch:   4/ 15] [data: 12928/31200] Training Loss: 0.2235
# [Epoch:   4/ 15] [data: 13056/31200] Training Loss: 0.1852
# [Epoch:   4/ 15] [data: 13184/31200] Training Loss: 0.1640
# [Epoch:   4/ 15] [data: 13312/31200] Training Loss: 0.1990
# [Epoch:   4/ 15] [data: 13440/31200] Training Loss: 0.2996
# [Epoch:   4/ 15] [data: 13568/31200] Training Loss: 0.2080
# [Epoch:   4/ 15] [data: 13696/31200] Training Loss: 0.1948
# [Epoch:   4/ 15] [data: 13824/31200] Training Loss: 0.1994
# [Epoch:   4/ 15] [data: 13952/31200] Training Loss: 0.1878
# [Epoch:   4/ 15] [data: 14080/31200] Training Loss: 0.1294
# [Epoch:   4/ 15] [data: 14208/31200] Training Loss: 0.1691
# [Epoch:   4/ 15] [data: 14336/31200] Training Loss: 0.2232
# [Epoch:   4/ 15] [data: 14464/31200] Training Loss: 0.1697
# [Epoch:   4/ 15] [data: 14592/31200] Training Loss: 0.1356
# [Epoch:   4/ 15] [data: 14720/31200] Training Loss: 0.2104
# [Epoch:   4/ 15] [data: 14848/31200] Training Loss: 0.2284
# [Epoch:   4/ 15] [data: 14976/31200] Training Loss: 0.1412
# [Epoch:   4/ 15] [data: 15104/31200] Training Loss: 0.2184
# [Epoch:   4/ 15] [data: 15232/31200] Training Loss: 0.2345
# [Epoch:   4/ 15] [data: 15360/31200] Training Loss: 0.1838
# [Epoch:   4/ 15] [data: 15488/31200] Training Loss: 0.1525
# [Epoch:   4/ 15] [data: 15616/31200] Training Loss: 0.1823
# [Epoch:   4/ 15] [data: 15744/31200] Training Loss: 0.1533
# [Epoch:   4/ 15] [data: 15872/31200] Training Loss: 0.1490
# [Epoch:   4/ 15] [data: 16000/31200] Training Loss: 0.1733
# [Epoch:   4/ 15] [data: 16128/31200] Training Loss: 0.2163
# [Epoch:   4/ 15] [data: 16256/31200] Training Loss: 0.1683
# [Epoch:   4/ 15] [data: 16384/31200] Training Loss: 0.1684
# [Epoch:   4/ 15] [data: 16512/31200] Training Loss: 0.1909
# [Epoch:   4/ 15] [data: 16640/31200] Training Loss: 0.1880
# [Epoch:   4/ 15] [data: 16768/31200] Training Loss: 0.1880
# [Epoch:   4/ 15] [data: 16896/31200] Training Loss: 0.1232
# [Epoch:   4/ 15] [data: 17024/31200] Training Loss: 0.1884
# [Epoch:   4/ 15] [data: 17152/31200] Training Loss: 0.1340
# [Epoch:   4/ 15] [data: 17280/31200] Training Loss: 0.2088
# [Epoch:   4/ 15] [data: 17408/31200] Training Loss: 0.1453
# [Epoch:   4/ 15] [data: 17536/31200] Training Loss: 0.1448
# [Epoch:   4/ 15] [data: 17664/31200] Training Loss: 0.1507
# [Epoch:   4/ 15] [data: 17792/31200] Training Loss: 0.2015
# [Epoch:   4/ 15] [data: 17920/31200] Training Loss: 0.2679
# [Epoch:   4/ 15] [data: 18048/31200] Training Loss: 0.1619
# [Epoch:   4/ 15] [data: 18176/31200] Training Loss: 0.1313
# [Epoch:   4/ 15] [data: 18304/31200] Training Loss: 0.1463
# [Epoch:   4/ 15] [data: 18432/31200] Training Loss: 0.1540
# [Epoch:   4/ 15] [data: 18560/31200] Training Loss: 0.1560
# [Epoch:   4/ 15] [data: 18688/31200] Training Loss: 0.2072
# [Epoch:   4/ 15] [data: 18816/31200] Training Loss: 0.1638
# [Epoch:   4/ 15] [data: 18944/31200] Training Loss: 0.2193
# [Epoch:   4/ 15] [data: 19072/31200] Training Loss: 0.2388
# [Epoch:   4/ 15] [data: 19200/31200] Training Loss: 0.2060
# [Epoch:   4/ 15] [data: 19328/31200] Training Loss: 0.1681
# [Epoch:   4/ 15] [data: 19456/31200] Training Loss: 0.1996
# [Epoch:   4/ 15] [data: 19584/31200] Training Loss: 0.1375
# [Epoch:   4/ 15] [data: 19712/31200] Training Loss: 0.1640
# [Epoch:   4/ 15] [data: 19840/31200] Training Loss: 0.1836
# [Epoch:   4/ 15] [data: 19968/31200] Training Loss: 0.1524
# [Epoch:   4/ 15] [data: 20096/31200] Training Loss: 0.2355
# [Epoch:   4/ 15] [data: 20224/31200] Training Loss: 0.1641
# [Epoch:   4/ 15] [data: 20352/31200] Training Loss: 0.1768
# [Epoch:   4/ 15] [data: 20480/31200] Training Loss: 0.1367
# [Epoch:   4/ 15] [data: 20608/31200] Training Loss: 0.2176
# [Epoch:   4/ 15] [data: 20736/31200] Training Loss: 0.1472
# [Epoch:   4/ 15] [data: 20864/31200] Training Loss: 0.1608
# [Epoch:   4/ 15] [data: 20992/31200] Training Loss: 0.1369
# [Epoch:   4/ 15] [data: 21120/31200] Training Loss: 0.1593
# [Epoch:   4/ 15] [data: 21248/31200] Training Loss: 0.1248
# [Epoch:   4/ 15] [data: 21376/31200] Training Loss: 0.1085
# [Epoch:   4/ 15] [data: 21504/31200] Training Loss: 0.1256
# [Epoch:   4/ 15] [data: 21632/31200] Training Loss: 0.1550
# [Epoch:   4/ 15] [data: 21760/31200] Training Loss: 0.2011
# [Epoch:   4/ 15] [data: 21888/31200] Training Loss: 0.1852
# [Epoch:   4/ 15] [data: 22016/31200] Training Loss: 0.1879
# [Epoch:   4/ 15] [data: 22144/31200] Training Loss: 0.1728
# [Epoch:   4/ 15] [data: 22272/31200] Training Loss: 0.1322
# [Epoch:   4/ 15] [data: 22400/31200] Training Loss: 0.2110
# [Epoch:   4/ 15] [data: 22528/31200] Training Loss: 0.2858
# [Epoch:   4/ 15] [data: 22656/31200] Training Loss: 0.1888
# [Epoch:   4/ 15] [data: 22784/31200] Training Loss: 0.1869
# [Epoch:   4/ 15] [data: 22912/31200] Training Loss: 0.1846
# [Epoch:   4/ 15] [data: 23040/31200] Training Loss: 0.1552
# [Epoch:   4/ 15] [data: 23168/31200] Training Loss: 0.1715
# [Epoch:   4/ 15] [data: 23296/31200] Training Loss: 0.2166
# [Epoch:   4/ 15] [data: 23424/31200] Training Loss: 0.1887
# [Epoch:   4/ 15] [data: 23552/31200] Training Loss: 0.2059
# [Epoch:   4/ 15] [data: 23680/31200] Training Loss: 0.1851
# [Epoch:   4/ 15] [data: 23808/31200] Training Loss: 0.1981
# [Epoch:   4/ 15] [data: 23936/31200] Training Loss: 0.1406
# [Epoch:   4/ 15] [data: 24064/31200] Training Loss: 0.2090
# [Epoch:   4/ 15] [data: 24192/31200] Training Loss: 0.1940
# [Epoch:   4/ 15] [data: 24320/31200] Training Loss: 0.1866
# [Epoch:   4/ 15] [data: 24448/31200] Training Loss: 0.1025
# [Epoch:   4/ 15] [data: 24576/31200] Training Loss: 0.1727
# [Epoch:   4/ 15] [data: 24704/31200] Training Loss: 0.2073
# [Epoch:   4/ 15] [data: 24832/31200] Training Loss: 0.1393
# [Epoch:   4/ 15] [data: 24960/31200] Training Loss: 0.2688
# [Epoch:   4/ 15] [data: 25088/31200] Training Loss: 0.1330
# [Epoch:   4/ 15] [data: 25216/31200] Training Loss: 0.1915
# [Epoch:   4/ 15] [data: 25344/31200] Training Loss: 0.1380
# [Epoch:   4/ 15] [data: 25472/31200] Training Loss: 0.2151
# [Epoch:   4/ 15] [data: 25600/31200] Training Loss: 0.2002
# [Epoch:   4/ 15] [data: 25728/31200] Training Loss: 0.1366
# [Epoch:   4/ 15] [data: 25856/31200] Training Loss: 0.2111
# [Epoch:   4/ 15] [data: 25984/31200] Training Loss: 0.1709
# [Epoch:   4/ 15] [data: 26112/31200] Training Loss: 0.1476
# [Epoch:   4/ 15] [data: 26240/31200] Training Loss: 0.2080
# [Epoch:   4/ 15] [data: 26368/31200] Training Loss: 0.1843
# [Epoch:   4/ 15] [data: 26496/31200] Training Loss: 0.1459
# [Epoch:   4/ 15] [data: 26624/31200] Training Loss: 0.2075
# [Epoch:   4/ 15] [data: 26752/31200] Training Loss: 0.1027
# [Epoch:   4/ 15] [data: 26880/31200] Training Loss: 0.1273
# [Epoch:   4/ 15] [data: 27008/31200] Training Loss: 0.1667
# [Epoch:   4/ 15] [data: 27136/31200] Training Loss: 0.1451
# [Epoch:   4/ 15] [data: 27264/31200] Training Loss: 0.1678
# [Epoch:   4/ 15] [data: 27392/31200] Training Loss: 0.1745
# [Epoch:   4/ 15] [data: 27520/31200] Training Loss: 0.1174
# [Epoch:   4/ 15] [data: 27648/31200] Training Loss: 0.1261
# [Epoch:   4/ 15] [data: 27776/31200] Training Loss: 0.1512
# [Epoch:   4/ 15] [data: 27904/31200] Training Loss: 0.1210
# [Epoch:   4/ 15] [data: 28032/31200] Training Loss: 0.1535
# [Epoch:   4/ 15] [data: 28160/31200] Training Loss: 0.1720
# [Epoch:   4/ 15] [data: 28288/31200] Training Loss: 0.1209
# [Epoch:   4/ 15] [data: 28416/31200] Training Loss: 0.1285
# [Epoch:   4/ 15] [data: 28544/31200] Training Loss: 0.1301
# [Epoch:   4/ 15] [data: 28672/31200] Training Loss: 0.1120
# [Epoch:   4/ 15] [data: 28800/31200] Training Loss: 0.1592
# [Epoch:   4/ 15] [data: 28928/31200] Training Loss: 0.1431
# [Epoch:   4/ 15] [data: 29056/31200] Training Loss: 0.1390
# [Epoch:   4/ 15] [data: 29184/31200] Training Loss: 0.2190
# [Epoch:   4/ 15] [data: 29312/31200] Training Loss: 0.1307
# [Epoch:   4/ 15] [data: 29440/31200] Training Loss: 0.1993
# [Epoch:   4/ 15] [data: 29568/31200] Training Loss: 0.1331
# [Epoch:   4/ 15] [data: 29696/31200] Training Loss: 0.1551
# [Epoch:   4/ 15] [data: 29824/31200] Training Loss: 0.1455
# [Epoch:   4/ 15] [data: 29952/31200] Training Loss: 0.1918
# [Epoch:   4/ 15] [data: 30080/31200] Training Loss: 0.1447

# %%
total_acc = 0.0
total_loss = 0.0
total = 0.0
i = 0
model = best_model
model.eval()
with torch.no_grad():
    while i < len(test_data):
        test_inputs, test_labels = get_batch(test_data, i, BATCH_SIZE)
        i += BATCH_SIZE
        if USE_GPU:
            test_inputs, test_labels = test_inputs.cuda(), test_labels.cuda()

        model.batch_size = len(test_labels)
        model.hidden = model.init_hidden()
        output = model(test_inputs)

        loss = loss_function(output, Variable(test_labels))

        _, predicted = torch.max(output.data, 1)
        total_acc += (predicted == test_labels).sum()
        total += len(test_labels)
        total_loss += loss.item() * len(test_inputs)
    print("Testing results(Acc):", total_acc.item() / total)

torch.save(model.state_dict(), 'astnn_classify_best.pt')

# %%
torch.save(model.state_dict(), 'astnn_classify.pt')

# %%
# train.py

import pandas as pd
import random
import torch
import time
import numpy as np
from gensim.models.word2vec import Word2Vec
from model import BatchProgramClassifier
from torch.autograd import Variable
from torch.utils.data import DataLoader
import os
import sys


def get_batch(dataset, idx, bs):
    tmp = dataset.iloc[idx: idx+bs]
    data, labels = [], []
    for _, item in tmp.iterrows():
        data.append(item[1])
        labels.append(item[2]-1)
    return data, torch.LongTensor(labels)


root = 'data/'
train_data = pd.read_pickle(root+'train/blocks.pkl')
val_data = pd.read_pickle(root + 'dev/blocks.pkl')
test_data = pd.read_pickle(root+'test/blocks.pkl')

word2vec = Word2Vec.load(root+"train/embedding/node_w2v_128").wv
embeddings = np.zeros((word2vec.syn0.shape[0] + 1, word2vec.syn0.shape[1]), dtype="float32")
embeddings[:word2vec.syn0.shape[0]] = word2vec.syn0

HIDDEN_DIM = 100
ENCODE_DIM = 128
LABELS = 104
EPOCHS = 15
BATCH_SIZE = 64
USE_GPU = True
MAX_TOKENS = word2vec.syn0.shape[0]
EMBEDDING_DIM = word2vec.syn0.shape[1]

model = BatchProgramClassifier(EMBEDDING_DIM,HIDDEN_DIM,MAX_TOKENS+1,ENCODE_DIM,LABELS,BATCH_SIZE,
                               USE_GPU, embeddings)
if USE_GPU:
    model.cuda()

parameters = model.parameters()
optimizer = torch.optim.Adamax(parameters)
loss_function = torch.nn.CrossEntropyLoss()

train_loss_ = []
val_loss_ = []
train_acc_ = []
val_acc_ = []
best_acc = 0.0
print('Start training...')
# training procedure
best_model = model
for epoch in range(EPOCHS):
    start_time = time.time()

    total_acc = 0.0
    total_loss = 0.0
    total = 0.0
    i = 0
    while i < len(train_data):
        batch = get_batch(train_data, i, BATCH_SIZE)
        i += BATCH_SIZE
        train_inputs, train_labels = batch
        if USE_GPU:
            train_inputs, train_labels = train_inputs, train_labels.cuda()

        model.zero_grad()
        model.batch_size = len(train_labels)
        model.hidden = model.init_hidden()
        output = model(train_inputs)

        loss = loss_function(output, Variable(train_labels))
        loss.backward()
        optimizer.step()

        # calc training acc
        _, predicted = torch.max(output.data, 1)
        total_acc += (predicted == train_labels).sum()
        total += len(train_labels)
        total_loss += loss.item()*len(train_inputs)

    train_loss_.append(total_loss / total)
    train_acc_.append(total_acc.item() / total)
    # validation epoch
    total_acc = 0.0
    total_loss = 0.0
    total = 0.0
    i = 0
    while i < len(val_data):
        batch = get_batch(val_data, i, BATCH_SIZE)
        i += BATCH_SIZE
        val_inputs, val_labels = batch
        if USE_GPU:
            val_inputs, val_labels = val_inputs, val_labels.cuda()

        model.batch_size = len(val_labels)
        model.hidden = model.init_hidden()
        output = model(val_inputs)

        loss = loss_function(output, Variable(val_labels))

        # calc valing acc
        _, predicted = torch.max(output.data, 1)
        total_acc += (predicted == val_labels).sum()
        total += len(val_labels)
        total_loss += loss.item()*len(val_inputs)
    val_loss_.append(total_loss / total)
    val_acc_.append(total_acc.item() / total)
    end_time = time.time()
    if total_acc/total > best_acc:
        best_model = model
    print('[Epoch: %3d/%3d] Training Loss: %.4f, Validation Loss: %.4f,'
          ' Training Acc: %.3f, Validation Acc: %.3f, Time Cost: %.3f s'
          % (epoch + 1, EPOCHS, train_loss_[epoch], val_loss_[epoch],
             train_acc_[epoch], val_acc_[epoch], end_time - start_time))

total_acc = 0.0
total_loss = 0.0
total = 0.0
i = 0
model = best_model
while i < len(test_data):
    batch = get_batch(test_data, i, BATCH_SIZE)
    i += BATCH_SIZE
    test_inputs, test_labels = batch
    if USE_GPU:
        test_inputs, test_labels = test_inputs, test_labels.cuda()

    model.batch_size = len(test_labels)
    model.hidden = model.init_hidden()
    output = model(test_inputs)

    loss = loss_function(output, Variable(test_labels))

    _, predicted = torch.max(output.data, 1)
    total_acc += (predicted == test_labels).sum()
    total += len(test_labels)
    total_loss += loss.item() * len(test_inputs)
print("Testing results(Acc):", total_acc.item() / total)

# %% [markdown]
# # generate preprocessed data

# %%
import pandas as pd
import os
def parse_source(root, output_file, option):
    path = root+output_file
    if os.path.exists(path) and option is 'existing':
        source = pd.read_pickle(path)
    else:
        from pycparser import c_parser
        parser = c_parser.CParser()
        source = pd.read_pickle(root+'programs.pkl')

        source.columns = ['id', 'code', 'label']
        source['code'] = source['code'].apply(parser.parse)

        source.to_pickle(path)
    return source

#s = parse_source(root='data/', output_file='ast.pkl',option='existing')

# %%
def split_data(root,ratio):
    data = pd.read_pickle(root+'ast.pkl')
    data_num = len(data)
    ratios = [int(r) for r in ratio.split(':')]
    train_split = int(ratios[0]/sum(ratios)*data_num)
    val_split = train_split + int(ratios[1]/sum(ratios)*data_num)
    data = data.sample(frac=1, random_state=666)
    train = data.iloc[:train_split] 
    dev = data.iloc[train_split:val_split] 
    test = data.iloc[val_split:] 

    def check_or_create(path):
        if not os.path.exists(path):
            os.mkdir(path)
    train_path = root+'train/'
    check_or_create(train_path)
    train_file_path = train_path+'train_.pkl'
    train.to_pickle(train_file_path)

    dev_path = root+'dev/'
    check_or_create(dev_path)
    dev_file_path = dev_path+'dev_.pkl'
    dev.to_pickle(dev_file_path)

    test_path = root+'test/'
    check_or_create(test_path)
    test_file_path = test_path+'test_.pkl'
    test.to_pickle(test_file_path)

def dictionary_and_embedding(root, input_file, size):
    if not input_file:
        input_file = 'data/train/train_.pkl'
    trees = pd.read_pickle(input_file)
    if not os.path.exists(root+'train/embedding'):
        os.mkdir(root+'train/embedding')
    from prepare_data import get_sequences

    def trans_to_sequences(ast):
        sequence = []
        get_sequences(ast, sequence)
        return sequence
    corpus = trees['code'].apply(trans_to_sequences)  # every row of corpus is list of str
    str_corpus = [' '.join(c) for c in corpus]  # str_corpus is list of str
    trees['code'] = pd.Series(str_corpus)  
    # the first saveral ones are alway the same in every row, can we delete them ?
    trees.to_csv(root+'train/programs_ns.tsv')  # tsv?

    from gensim.models.word2vec import Word2Vec
    w2v = Word2Vec(corpus, size=size, workers=16, sg=1, min_count=3)
    w2v.save(root+'train/embedding/node_w2v_' + str(size))    

def generate_block_seqs(root,data_path,part,size=128):
    from prepare_data import get_blocks as func
    from gensim.models.word2vec import Word2Vec

    word2vec = Word2Vec.load(root+'train/embedding/node_w2v_' + str(size)).wv
    vocab = word2vec.vocab
    max_token = word2vec.vectors.shape[0]
    # Attribute `syn0` will be removed in 4.0.0, use self.vectors instead

    def tree_to_index(node):
        token = node.token
        result = [vocab[token].index if token in vocab else max_token]
        children = node.children
        for child in children:
            result.append(tree_to_index(child))
        return result

    def trans2seq(r):
        blocks = []
        func(r, blocks)
        tree = []
        for b in blocks:
            btree = tree_to_index(b)
            tree.append(btree)
        return tree
    trees = pd.read_pickle(data_path)
    trees['code'] = trees['code'].apply(trans2seq)
    trees.to_pickle(root+part+'/blocks.pkl')

generate_block_seqs(root='data/', data_path='data/train/train_.pkl', part='train')
generate_block_seqs(root='data/', data_path='data/dev/dev_.pkl', part='dev')
generate_block_seqs(root='data/', data_path='data/test/test_.pkl', part='test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-128-aef5fca83b82> in <module>
#      80
#      81 generate_block_seqs(root='data/', data_path='data/train/train_.pkl', part='train')
# ---> 82 generate_block_seqs(root='data/', data_path='data/train/dev_.pkl', part='dev')
#      83 generate_block_seqs(root='data/', data_path='data/train/test_.pkl', part='test')
#
# <ipython-input-128-aef5fca83b82> in generate_block_seqs(root, data_path, part, size)
#      75             tree.append(btree)
#      76         return tree
# ---> 77     trees = pd.read_pickle(data_path)
#      78     trees['code'] = trees['code'].apply(trans2seq)
#      79     trees.to_pickle(root+part+'/blocks.pkl')
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression)
#     168     if not isinstance(fp_or_buf, str) and compression == "infer":
#     169         compression = None
# --> 170     f, fh = get_handle(fp_or_buf, "rb", compression=compression, is_text=False)
#     171
#     172     # 1) try standard library Pickle
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     459         else:
#     460             # Binary mode
# --> 461             f = open(path_or_buf, mode)
#     462         handles.append(f)
#     463
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train/dev_.pkl'

# %%
# source code

import pandas as pd
import os

class Pipeline:
    def __init__(self,  ratio, root):
        self.ratio = ratio
        self.root = root
        self.sources = None
        self.train_file_path = None
        self.dev_file_path = None
        self.test_file_path = None
        self.size = None

    # parse source code
    def parse_source(self, output_file, option):
        path = self.root+output_file
        if os.path.exists(path) and option is 'existing':
            source = pd.read_pickle(path)
        else:
            from pycparser import c_parser
            parser = c_parser.CParser()
            source = pd.read_pickle(self.root+'programs.pkl')

            source.columns = ['id', 'code', 'label']
            source['code'] = source['code'].apply(parser.parse)

            source.to_pickle(path)
        self.sources = source
        return source

    # split data for training, developing and testing
    def split_data(self):
        data = self.sources
        data_num = len(data)
        ratios = [int(r) for r in self.ratio.split(':')]
        train_split = int(ratios[0]/sum(ratios)*data_num)
        val_split = train_split + int(ratios[1]/sum(ratios)*data_num)
        data = data.sample(frac=1, random_state=666)
        train = data.iloc[:train_split] 
        dev = data.iloc[train_split:val_split] 
        test = data.iloc[val_split:] 

        def check_or_create(path):
            if not os.path.exists(path):
                os.mkdir(path)
        train_path = self.root+'train/'
        check_or_create(train_path)
        self.train_file_path = train_path+'train_.pkl'
        train.to_pickle(self.train_file_path)

        dev_path = self.root+'dev/'
        check_or_create(dev_path)
        self.dev_file_path = dev_path+'dev_.pkl'
        dev.to_pickle(self.dev_file_path)

        test_path = self.root+'test/'
        check_or_create(test_path)
        self.test_file_path = test_path+'test_.pkl'
        test.to_pickle(self.test_file_path)

    # construct dictionary and train word embedding
    def dictionary_and_embedding(self, input_file, size):
        self.size = size
        if not input_file:
            input_file = self.train_file_path
        trees = pd.read_pickle(input_file)
        if not os.path.exists(self.root+'train/embedding'):
            os.mkdir(self.root+'train/embedding')
        from prepare_data import get_sequences

        def trans_to_sequences(ast):
            sequence = []
            get_sequences(ast, sequence)
            return sequence
        corpus = trees['code'].apply(trans_to_sequences)  # every row of corpus is list of str
        str_corpus = [' '.join(c) for c in corpus]  # str_corpus is list of str
        trees['code'] = pd.Series(str_corpus)  
        # the first saveral ones are alway the same in every row, can we delete them ?
        trees.to_csv(self.root+'train/programs_ns.tsv')

        from gensim.models.word2vec import Word2Vec
        w2v = Word2Vec(corpus, size=size, workers=16, sg=1, min_count=3)
        w2v.save(self.root+'train/embedding/node_w2v_' + str(size))

    # generate block sequences with index representations
    def generate_block_seqs(self,data_path,part):
        from prepare_data import get_blocks as func
        from gensim.models.word2vec import Word2Vec

        word2vec = Word2Vec.load(self.root+'train/embedding/node_w2v_' + str(self.size)).wv
        vocab = word2vec.vocab
        max_token = word2vec.vectors.shape[0]
        # Attribute `syn0` will be removed in 4.0.0, use self.vectors instead

        def tree_to_index(node):
            token = node.token
            result = [vocab[token].index if token in vocab else max_token]
            children = node.children
            for child in children:
                result.append(tree_to_index(child))
            return result

        def trans2seq(r):
            blocks = []
            func(r, blocks)
            tree = []
            for b in blocks:
                btree = tree_to_index(b)
                tree.append(btree)
            return tree
        trees = pd.read_pickle(data_path)
        trees['code'] = trees['code'].apply(trans2seq)
        trees.to_pickle(self.root+part+'/blocks.pkl')

    # run for processing data to train
    def run(self):
        print('parse source code...')
        self.parse_source(output_file='ast.pkl',option='existing')
        print('split data...')
        self.split_data()
        print('train word embedding...')
        self.dictionary_and_embedding(None,128)
        print('generate block sequences...')
        self.generate_block_seqs(self.train_file_path, 'train')
        self.generate_block_seqs(self.dev_file_path, 'dev')
        self.generate_block_seqs(self.test_file_path, 'test')


ppl = Pipeline('3:1:1', 'data/')
ppl.run()
